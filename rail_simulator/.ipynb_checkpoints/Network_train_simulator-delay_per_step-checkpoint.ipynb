# %%
import config
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib
import random
import time
from network import *
from utility import *
from train import *
import simpy
import logging
import math
import copy

# %%
# %matplotlib notebook
plt.ion()

# %%
env = simpy.Environment()

# %%
N = Network(config.STATIONS_FILENAME, config.RAILWAY_FILENAME , env)

# %%
def create_statistic_proc(env , logger , stat_time , N , trains):
    '''
    Create statistic in the log file every stat_time
    @parameters:
    env : simpy environment
    logger : log file where need to create the log
    stat_time : time after which log is to be created
    N         : network
    trains    : trains in the network
    '''
    while True :
        yield env.timeout(20)

        #create statistics
        not_yet_started = 0
        running = 0
        Completed_resource_not_freed = 0
        Completed = 0

        for t in trains:
            status = t.status()
            if (status == 'not_yet_started'):
                not_yet_started += 1
            elif (status == 'running'):
                running += 1
            elif(status == 'Completed_resource_not_freed'):
                Completed_resource_not_freed += 1
            else:
                Completed += 1
        
        if (len(trains) == Completed):
            config.TRAINS_COMPLETED_JOURNEY = True

        logger.info("Time : {} Number of trains not yet started - {}".format(env.now , not_yet_started))
        logger.info("Time : {} Number of running trains - {}".format(env.now , running))
        logger.info("Time : {} Number of trains Completed but resource not freed - {}".format(env.now , Completed_resource_not_freed))
        logger.info("Time : {} Number of trains which have Completed journey - {}".format(env.now , Completed))

# %%
#utility function
def update_graph (env , interval , train_to_color = None):
    '''
    This function will simulate the whole process on a GUI
    This function is going to be used as the process
    @parameters
    env : simpy environment
    total_time : total time for the simulation
    '''
    fig = plt.figure(figsize = (6 , 6))
    ax = fig.add_subplot(111)
    fig.show()
    fig.canvas.draw()
    
    while True:
        #Draw graph
        
        N.draw_railway_network(ax  = ax , suppress_station_info= False , 
                               suppress_track_info= False , suppress_edge_label=False , 
                               train_to_color=train_to_color)


        #yield interval time
        yield env.timeout(interval)
        time.sleep(0.5)
        
        #log info
        plt.title("Time {}".format(env.now))
        
        #Paint the canvas
        fig.canvas.draw()

# %%
def deadlock_detection_process (env , deadlock_time):
    '''
    For creating deadlock detection process
    '''
    global DEADLOCK
    while True:
        
        #Invoke this deadlock process after every 20 iterations
        
        yield env.timeout(deadlock_time)
        logger.info("Time : {} Checking Deadlock".format(env.now))
        config.DEADLOCK , _ = deadlock_detection(N , trains)

# %%
def compute_loss_one_train (t):
    '''
    This function should be called after the successful completion of the train
    @Parameter : Name of the train 
    @Return : Loss for the train  
    '''
    p = t.priority
    loss = 0
    
    #for each station in the path
    for route , log in zip(t.route , t.log):
        d , t1 , t2 = route
        _ , t3 , t4 = log
        
        #Compute the loss, for the arrival (may arrive before the assigned time)
        #and departure (always after the assigned time)
        if t3 >= t1:
            loss += (t3 - t1)
        if (t4 >= t2):
            loss += (t4 - t2)

    return loss / p

# %%
def compute_loss (trains):
    '''
    Takes all the trains in the network after completing the journey and then computes the value of J
    '''
    total_loss = 0
    total_departures = 0

    #for each train compute the loss, and return the total loss
    for t in trains:
        total_departures += 2*len(t.route)
        total_loss += compute_loss_one_train(t)
        
    total_loss = total_loss / total_departures
    return total_loss

# %%
def get_state_vector (train_name , b = 2 , l= 6 , R = 3 , w_c = 1 , w_d = 1):
    #get the train
    t = name_train_map[train_name]
    
    #find the current position 
    current = t.current_index * 2;
    if (not t.station_or_not):
        current += 1
            
    #get the local neighbors
    res =t.all_resources[ max(0 , current - b) : min(current + l+1 , len(t.all_resources )) ]
    state_vector = [0 for _ in range(len(res))]
    res_to_index = {}
    for i in range(len(res)):
        res_to_index[res[i]] = i

    #position of the train in the local space
    if (t.current == '_'):
        t1_pos = 0 
    else:
        t1_pos = res_to_index[t.current]
    

    #go through each local resource
    for t2_pos , r in enumerate(res):
        #check if the resource is station or track and get the corresponding details
        if type(r) is not str:
            s = N.get_track_details(r[0],r[1])

        else:
            s = N.get_station_details(r)
        
        towards = 0                                          #train converging towards the given train  
        away = 0                                             #trains diverging from the given train
        total = len(s.train_running)                         #total number of trains
        
        #for each train in one of the local resource 
        for running_train in s.train_running:

            if not running_train == '_':
                
                #find the next position of the train and depict wether it is moving towards or away from the resource
                t2 = name_train_map[running_train]
                index = t2.current_index * 2 
                if not (t2.station_or_not):
                    index += 1
                
                #if train is not at the last destination
                if ( index + 1 < len(t2.all_resources) ):
                    #get the next resource and find it's position
                    next_res = t2.all_resources[index + 1]
                    
                    #depending on the position, check if the train is toward or away from the current trian.
                    if next_res in res_to_index:
                        t2_next_pos = res_to_index[t2.all_resources[index + 1]]
                        if abs(t2_next_pos - t1_pos) < abs(t2_pos - t1_pos):
                            towards+=1
                        else:
                            away+=1

                    elif type(next_res) is not str and (next_res[1] , next_res[0]) in res_to_index:
                        t2_next_pos = res_to_index[(next_res[1] , next_res[0]) ]
                        if abs(t2_next_pos - t1_pos) < abs(t2_pos - t1_pos):
                            towards+=1
                        else:
                            away+=1

                    else :
                        away+=1
                else :
                    away+=1
                    
        #construct the state vector
        state_vector[t2_pos] = int(R - 1 - min (R-1 , math.floor(total - w_c * towards - w_d * away)))
    
    #make it equal to the size of the state vector
    if (current - b < 0):
        temp_list = [0] * abs(current-b)
        temp_list.extend(state_vector)
        state_vector = temp_list

    if (current + l + 1 > len(t.all_resources)):
        state_vector.extend([0] * (current + l + 1 - len(t.all_resources)) )
        
    #include the priority of the train in the state vector
    state_vector.insert(0 , t.priority)
    
    return state_vector

# %%
def state_vector_to_index (state_vector , b = 2 , l = 6 , total_priority = 3 , R = 3):
    '''
    This function takes the state vector and convert it into index used for storing purpose
    state vector is a list
    '''
    temp = 1
    ans = 0
    for i in range(1 , len(state_vector)):
        ans += temp * state_vector[i]
        temp *= R
        
    x = R ** (l + b + 1)
    return ans + (state_vector[0]-1) * x

# %%
def index_to_state_vector (index , b = 2 , l = 6 , R = 3 , total_priority = 3):
    '''
    Given th index , it returns the state vector
    '''
    state_vector = [0]
    x = R ** (l + b + 1)
    state_vector[0] = index//x + 1
    index = index % x
    
    while index:
        index, r = divmod(index, 3)
        state_vector.append(r)
        
    state_vector.extend( [0] * (l + b + 2 - len(state_vector)) )
    return state_vector

# %%
trains = read_trains(config.TRAINS_FILENAME , N , env)

# %%
name_train_map = {}                #Map from train name to train object; note key can be changed to train_id 
for t in trains:
    name_train_map[t.name] = t

# %%
#Define a map from train to color to which it belongs 
#Note this feature considers only 10 trains into account
colors = ['red' , 'saddlebrown' , 'forestgreen','dimgray' , 'darkcyan' , 'royalblue' , 'magenta' , 'darkorange' ] 
permanent_color = 'lightcoral'

train_to_color = {}
if (len(trains) <= 8):
    for i,t in enumerate(trains):
        train_to_color[t.name] = colors[i]
else:
    for i,t in enumerate(trains):
        train_to_color[t.name] = permanent_color
        
print(train_to_color)
# Out:
# {'Train001': 'red', 'Train002': 'saddlebrown', 'Train003': 'forestgreen', 'Train004': 'dimgray', 'Train011': 'darkcyan', 'Train012': 'royalblue', 'Train013': 'magenta', 'Train014': 'darkorange'}

# %%
logger = setup_logger("main_log_file" ,"Logs/log.log")

# %% [markdown]
# # Simulation and Algorithm

# %%
#hyperparameters
pho = 0.25
minimum_J = 1000000
total_priority = 3
R = 3
l = 1
b = 0
w_c = 1
w_d = 1
total_episodes = 1000
w = 0.25

tau = 0.9
alpha = 0.1

EPS_START = 1.0
EPS_END = 0.1
EPS_STEPS = 300

gamma = 0.9

CURRENT_EPISODE = 0
TERMINATE = False

TOTAL_STEPS = 0

# %%
#Variables
total_states = total_priority * (R ** (l + b + 1))

#map for the train most recent state space
train_state_space_map = {} 
train_action_terminated = {}
reward_for_train = {}

for key , value in  name_train_map.items():
    train_state_space_map[key] = '-'
    train_action_terminated[key] = False
    reward_for_train[key] = []
#for the Q-values
Q_values = np.zeros((total_states , 2))
Q_values_100 = None

# %%
def epsilon_greedy (state_space , epsilon = None):
    '''
    Given the state space, pick the action according to epsilon-greedy policy.    
    '''
   #given the state space, it will select the action according to epsilon greedy policy
    actions = ['move' , 'wait']
    
    #compute epsilon
    if (epsilon is None):
        if (CURRENT_EPISODE > EPS_STEPS):
            epsilon = EPS_END
        else:
            epsilon = ((EPS_END - EPS_START) / EPS_STEPS) * CURRENT_EPISODE + EPS_START
        
    #check if the action is random or greedy
    random = np.random.choice([True , False ] , 1 , p = [epsilon , 1 - epsilon])

    #pick the action at random
    if (random):
        action = np.random.choice(actions , 1 , p = [0.5 , 0.5])
        return action[0]
    else:
        
        #pick the action greedily
        if (Q_values_100 is None):
            q_1 = Q_values[state_vector_to_index(state_space) , 0]
            q_2 = Q_values[state_vector_to_index(state_space) , 1]
        else:
            q_1 = Q_values_100[state_vector_to_index(state_space) , 0]
            q_2 = Q_values_100[state_vector_to_index(state_space) , 1]
        
        if (q_1 >= q_2):
            return 'move'
        else:
            return 'wait'

# %%
def get_reward (train):
    #get the status of the train
    status = train.status()
    if (status == 'not_yet_started'):
        return 0

    else:
        #if the train is on the station, take the departure time
        current_index = train.current_index

        if (train.station_or_not):
            return min(0,-(train.log[current_index][1] - train.route[current_index][1]))
        else:
            return min(0,-(train.log[current_index][2] - train.route[current_index][2]))

# %%
total_reward = []
INVALID_MOVES = 0

# %%
def choose_action_algo (env ,N ,name_train_map):
    
    '''
    This function will choose the action for the trains that need action at the
    particular simulation time
    
    This will also check if the move is valid or not.
    '''
    
    actions = ['move' , 'wait']
    
    global TERMINATE , TOTAL_STEPS , total_reward , INVALID_MOVES
    
    while True :
        #This line is extremely important
        #As this line will wait for all the events upto this current simulation point to complete first
        #and then this will execute
        for _ in range(4*len(name_train_map)):
            yield env.timeout(0)
        
        #Check if the trains need action
        if (len(config.TRAINS_NEEDING_ACTION) == 0):
            yield env.timeout(1)
        
        else:
            
            #Pick the train that needs the action most
            time ,name = pick_most_suitable_action(name_train_map , N , env)
            t = name_train_map[name]

            #construct the state vector
            state_vector = get_state_vector(name , b = b , l = l , R = R , w_c = w_c , w_d = w_d)
            action = epsilon_greedy(state_vector , epsilon = 0.1 )
            
            action_index = 0
            if action == 'wait':
                action_index = 1
                
            if action == 'move' and not (t.is_move_valid(env)):
                INVALID_MOVES += 1
                TERMINATE = True
            else:
                TERMINATE = False
            
            reward = get_reward(t)

            if not (train_state_space_map[name] == '-'):
                #computing the Q_values
                if (train_action_terminated[name] == True):
                    reward = -10000
                    
                reward_for_train[name].append((action , reward , state_vector 
                                               , Q_values[state_vector_to_index(state_vector) , 0]
                                               , Q_values[state_vector_to_index(state_vector) , 1]))
                    
                total_reward.append(reward)
                #update the Q-values
                prev_state_vector , prev_action = train_state_space_map[name]
                Q_t1 = Q_values[state_vector_to_index(prev_state_vector) , prev_action]
                Q_t2 = Q_values[state_vector_to_index(state_vector) , action_index]
                Q_t1 = Q_t1 +  alpha * ((reward + gamma * Q_t2  - Q_t1))
                Q_values[state_vector_to_index(prev_state_vector) , prev_action] = Q_t1
                
            
            train_state_space_map[name] = (state_vector , action_index)
            TOTAL_STEPS += 1
            if (TERMINATE):
                train_action_terminated[name] = True
                continue
            else:
                train_action_terminated[name] = False
                
                

            env.process(t.act_simulate(env , action))
            
            config.TRAINS_NEEDING_ACTION.remove((time,  name) )

# %%
# sim_proc = env.process(update_graph(env , 1 , train_to_color =train_to_color))
def start_episode():
    '''
    Reset everything at the start of the episode
    '''
    env = simpy.Environment()
    N.reset(env)
    for t in trains:
        t.reset(env , N)
    
        
    dead_proc = env.process(deadlock_detection_process(env , 20))
    stat_proc = env.process(create_statistic_proc(env , logger , 20 , N , trains))

    for t in trains:
        proc = env.process(t.put_train_on_track(env))

    proc_act = env.process(choose_action_algo(env , N, name_train_map))
    return env,N

# %%
#For plotting and storing info
J_plot = []
minimum_J_plot = []

#for logging about the total success, deadlock and completed episodes
total_deadlock = 0
completed_episodes = 0
terminated = 0

#Run for the required number of episodes
for episode in range(total_episodes):

    #reset the episode
    INVALID_MOVES = 0
    config.TRAINS_NEEDING_ACTION = []
    total_reward = []
    TOTAL_STEPS = 0
    env , N = start_episode()    
    config.DEADLOCK = True
    config.TRAINS_COMPLETED_JOURNEY = False
    config.CURRENT_SIMULATION_TIME = 0
    
    for key , value in reward_for_train.items():
        reward_for_train[key] = []
    
    TERMINATE = False
    CURRENT_EPISODE += 1

    #mark the seen to all zero for the current episode
    seen = np.zeros((total_states , 2))
    
    #This loop is not needed as such
    for time in range(0 , config.TOTAL_SIMULATION_TIME , 1):
            
        if (config.DEADLOCK== False):
            logger.warning("Time : {} Terminating Simulation. Deadlock detected".format(env.now))
#             print("Terminating Simulation : Deadlock detected")
            total_deadlock += 1 
            
            break

        if (config.TRAINS_COMPLETED_JOURNEY == True):
            logger.info("Time : {} All trains completed journey. Terminating Simulation".format(env.now))
            #print("Terminating Simulation : All trains completed journey")
            break

        config.CURRENT_SIMULATION_TIME += 1

        #Run the simulation
        env.run(until = config.CURRENT_SIMULATION_TIME)

    
    if (config.TRAINS_COMPLETED_JOURNEY):
        completed_episodes += 1
        J = compute_loss(trains)
        J_plot.append(J)
        minimum_J = min(J , minimum_J)
        minimum_J_plot.append(minimum_J)
        
    if (config.DEADLOCK == False):
        print("Episode : {} Ended in deadlock".format(episode))
    else:
        print('*' * 50)
        print ("Episode : {} , J : {:.5f} , total_time {} , total_deadlock - {}".format( episode ,J , 
                                                        config.CURRENT_SIMULATION_TIME,  total_deadlock ))

        reward_sum = np.sum(np.array(total_reward))
        temp = (reward_sum + INVALID_MOVES * 100)/(TOTAL_STEPS - INVALID_MOVES)
        print("Episode : {} Total reward {} , total_steps {}, average reward {:.2f} , invalid_moves {} , reward_step {:.2f}".format(
        episode, reward_sum , TOTAL_STEPS , reward_sum/TOTAL_STEPS, INVALID_MOVES , temp )   )
    
    
    
    
    if (episode == 900):
        Q_values_100 = copy.deepcopy(Q_values)
# Out:
# **************************************************
# Episode : 0 , J : 20.02500 , total_time 61 , total_deadlock - 0
# Episode : 0 Total reward -123963 , total_steps 337, average reward -367.84 , invalid_moves 12 , reward_step -377.73
# **************************************************
# Episode : 1 , J : 54.85000 , total_time 161 , total_deadlock - 0
# Episode : 1 Total reward -305177 , total_steps 929, average reward -328.50 , invalid_moves 27 , reward_step -335.34
# **************************************************
# Episode : 2 , J : 13.65000 , total_time 121 , total_deadlock - 0
# Episode : 2 Total reward -6311 , total_steps 380, average reward -16.61 , invalid_moves 0 , reward_step -16.61
# **************************************************
# Episode : 3 , J : 48.03750 , total_time 121 , total_deadlock - 0
# Episode : 3 Total reward -24720 , total_steps 667, average reward -37.06 , invalid_moves 1 , reward_step -36.97
# **************************************************
# Episode : 4 , J : 4.05000 , total_time 41 , total_deadlock - 0
# Episode : 4 Total reward -587 , total_steps 177, average reward -3.32 , invalid_moves 0 , reward_step -3.32
# **************************************************
# Episode : 5 , J : 18.65000 , total_time 121 , total_deadlock - 0
# Episode : 5 Total reward -3837 , total_steps 338, average reward -11.35 , invalid_moves 0 , reward_step -11.35
# **************************************************
# Episode : 6 , J : 20.13750 , total_time 101 , total_deadlock - 0
# Episode : 6 Total reward -26153 , total_steps 454, average reward -57.61 , invalid_moves 2 , reward_step -57.42
# **************************************************
# Episode : 7 , J : 21.67500 , total_time 121 , total_deadlock - 0
# Episode : 7 Total reward -5233 , total_steps 359, average reward -14.58 , invalid_moves 0 , reward_step -14.58
# **************************************************
# Episode : 8 , J : 15.27500 , total_time 101 , total_deadlock - 0
# Episode : 8 Total reward -68391 , total_steps 539, average reward -126.88 , invalid_moves 6 , reward_step -127.19
# **************************************************
# Episode : 9 , J : 78.88750 , total_time 201 , total_deadlock - 0
# Episode : 9 Total reward -224564 , total_steps 1163, average reward -193.09 , invalid_moves 16 , reward_step -194.39
# **************************************************
# Episode : 10 , J : 15.21250 , total_time 101 , total_deadlock - 0
# Episode : 10 Total reward -13029 , total_steps 325, average reward -40.09 , invalid_moves 1 , reward_step -39.90
# **************************************************
# Episode : 11 , J : 20.33750 , total_time 101 , total_deadlock - 0
# Episode : 11 Total reward -5426 , total_steps 402, average reward -13.50 , invalid_moves 0 , reward_step -13.50
# **************************************************
# Episode : 12 , J : 26.07500 , total_time 121 , total_deadlock - 0
# Episode : 12 Total reward -5763 , total_steps 394, average reward -14.63 , invalid_moves 0 , reward_step -14.63
# **************************************************
# Episode : 13 , J : 14.88750 , total_time 121 , total_deadlock - 0
# Episode : 13 Total reward -4367 , total_steps 389, average reward -11.23 , invalid_moves 0 , reward_step -11.23
# **************************************************
# Episode : 14 , J : 28.63750 , total_time 141 , total_deadlock - 0
# Episode : 14 Total reward -8904 , total_steps 489, average reward -18.21 , invalid_moves 0 , reward_step -18.21
# **************************************************
# Episode : 15 , J : 12.30000 , total_time 81 , total_deadlock - 0
# Episode : 15 Total reward -2339 , total_steps 292, average reward -8.01 , invalid_moves 0 , reward_step -8.01
# **************************************************
# Episode : 16 , J : 36.16250 , total_time 161 , total_deadlock - 0
# Episode : 16 Total reward -22336 , total_steps 521, average reward -42.87 , invalid_moves 1 , reward_step -42.76
# **************************************************
# Episode : 17 , J : 133.68750 , total_time 321 , total_deadlock - 0
# Episode : 17 Total reward -627940 , total_steps 1891, average reward -332.07 , invalid_moves 47 , reward_step -337.98
# **************************************************
# Episode : 18 , J : 35.28750 , total_time 141 , total_deadlock - 0
# Episode : 18 Total reward -130959 , total_steps 680, average reward -192.59 , invalid_moves 11 , reward_step -194.11
# **************************************************
# Episode : 19 , J : 86.26250 , total_time 241 , total_deadlock - 0
# Episode : 19 Total reward -405885 , total_steps 1272, average reward -319.09 , invalid_moves 34 , reward_step -325.11
# **************************************************
# Episode : 20 , J : 47.05000 , total_time 201 , total_deadlock - 0
# Episode : 20 Total reward -136160 , total_steps 979, average reward -139.08 , invalid_moves 9 , reward_step -139.44
# **************************************************
# Episode : 21 , J : 121.90000 , total_time 321 , total_deadlock - 0
# Episode : 21 Total reward -505645 , total_steps 1780, average reward -284.07 , invalid_moves 35 , reward_step -287.76
# **************************************************
# Episode : 22 , J : 8.75000 , total_time 81 , total_deadlock - 0
# Episode : 22 Total reward -21667 , total_steps 228, average reward -95.03 , invalid_moves 2 , reward_step -94.99
# **************************************************
# Episode : 23 , J : 12.06250 , total_time 141 , total_deadlock - 0
# Episode : 23 Total reward -2485 , total_steps 322, average reward -7.72 , invalid_moves 0 , reward_step -7.72
# **************************************************
# Episode : 24 , J : 21.28750 , total_time 61 , total_deadlock - 0
# Episode : 24 Total reward -3427 , total_steps 332, average reward -10.32 , invalid_moves 0 , reward_step -10.32
# **************************************************
# Episode : 25 , J : 18.96250 , total_time 121 , total_deadlock - 0
# Episode : 25 Total reward -3683 , total_steps 304, average reward -12.12 , invalid_moves 0 , reward_step -12.12
# **************************************************
# Episode : 26 , J : 18.48750 , total_time 101 , total_deadlock - 0
# Episode : 26 Total reward -3291 , total_steps 312, average reward -10.55 , invalid_moves 0 , reward_step -10.55
# **************************************************
# Episode : 27 , J : 16.90000 , total_time 141 , total_deadlock - 0
# Episode : 27 Total reward -4946 , total_steps 342, average reward -14.46 , invalid_moves 0 , reward_step -14.46
# **************************************************
# Episode : 28 , J : 24.78750 , total_time 81 , total_deadlock - 0
# Episode : 28 Total reward -2883 , total_steps 343, average reward -8.41 , invalid_moves 0 , reward_step -8.41
# **************************************************
# Episode : 29 , J : 17.20000 , total_time 101 , total_deadlock - 0
# Episode : 29 Total reward -3518 , total_steps 309, average reward -11.39 , invalid_moves 0 , reward_step -11.39
# **************************************************
# Episode : 30 , J : 18.78750 , total_time 101 , total_deadlock - 0
# Episode : 30 Total reward -4509 , total_steps 344, average reward -13.11 , invalid_moves 0 , reward_step -13.11
# **************************************************
# Episode : 31 , J : 13.66250 , total_time 101 , total_deadlock - 0
# Episode : 31 Total reward -2275 , total_steps 276, average reward -8.24 , invalid_moves 0 , reward_step -8.24
# **************************************************
# Episode : 32 , J : 24.63750 , total_time 141 , total_deadlock - 0
# Episode : 32 Total reward -7629 , total_steps 440, average reward -17.34 , invalid_moves 0 , reward_step -17.34
# **************************************************
# Episode : 33 , J : 15.25000 , total_time 101 , total_deadlock - 0
# Episode : 33 Total reward -4072 , total_steps 349, average reward -11.67 , invalid_moves 0 , reward_step -11.67
# **************************************************
# Episode : 34 , J : 82.53750 , total_time 221 , total_deadlock - 0
# Episode : 34 Total reward -238170 , total_steps 1241, average reward -191.92 , invalid_moves 16 , reward_step -193.12
# **************************************************
# Episode : 35 , J : 37.71250 , total_time 181 , total_deadlock - 0
# Episode : 35 Total reward -36126 , total_steps 721, average reward -50.11 , invalid_moves 1 , reward_step -50.04
# **************************************************
# Episode : 36 , J : 57.96250 , total_time 201 , total_deadlock - 0
# Episode : 36 Total reward -34667 , total_steps 841, average reward -41.22 , invalid_moves 0 , reward_step -41.22
# **************************************************
# Episode : 37 , J : 16.15000 , total_time 101 , total_deadlock - 0
# Episode : 37 Total reward -3636 , total_steps 321, average reward -11.33 , invalid_moves 0 , reward_step -11.33
# **************************************************
# Episode : 38 , J : 9.86250 , total_time 41 , total_deadlock - 0
# Episode : 38 Total reward -1036 , total_steps 198, average reward -5.23 , invalid_moves 0 , reward_step -5.23
# **************************************************
# Episode : 39 , J : 21.91250 , total_time 121 , total_deadlock - 0
# Episode : 39 Total reward -3685 , total_steps 335, average reward -11.00 , invalid_moves 0 , reward_step -11.00
# **************************************************
# Episode : 40 , J : 24.71250 , total_time 121 , total_deadlock - 0
# Episode : 40 Total reward -7026 , total_steps 430, average reward -16.34 , invalid_moves 0 , reward_step -16.34
# **************************************************
# Episode : 41 , J : 62.07500 , total_time 221 , total_deadlock - 0
# Episode : 41 Total reward -364371 , total_steps 1343, average reward -271.31 , invalid_moves 29 , reward_step -275.09
# **************************************************
# Episode : 42 , J : 56.78750 , total_time 221 , total_deadlock - 0
# Episode : 42 Total reward -302645 , total_steps 1021, average reward -296.42 , invalid_moves 25 , reward_step -301.35
# **************************************************
# Episode : 43 , J : 38.82500 , total_time 141 , total_deadlock - 0
# Episode : 43 Total reward -116011 , total_steps 748, average reward -155.09 , invalid_moves 9 , reward_step -155.77
# **************************************************
# Episode : 44 , J : 100.87500 , total_time 321 , total_deadlock - 0
# Episode : 44 Total reward -421678 , total_steps 1488, average reward -283.39 , invalid_moves 30 , reward_step -287.16
# **************************************************
# Episode : 45 , J : 43.78750 , total_time 161 , total_deadlock - 0
# Episode : 45 Total reward -29183 , total_steps 793, average reward -36.80 , invalid_moves 0 , reward_step -36.80
# **************************************************
# Episode : 46 , J : 98.98750 , total_time 301 , total_deadlock - 0
# Episode : 46 Total reward -510059 , total_steps 1612, average reward -316.41 , invalid_moves 39 , reward_step -321.78
# **************************************************
# Episode : 47 , J : 61.48750 , total_time 261 , total_deadlock - 0
# Episode : 47 Total reward -395963 , total_steps 1374, average reward -288.18 , invalid_moves 30 , reward_step -292.38
# Episode : 48 Ended in deadlock
# **************************************************
# Episode : 49 , J : 135.98750 , total_time 321 , total_deadlock - 1
# Episode : 49 Total reward -722581 , total_steps 2100, average reward -344.09 , invalid_moves 52 , reward_step -350.28
# **************************************************
# Episode : 50 , J : 82.30000 , total_time 301 , total_deadlock - 1
# Episode : 50 Total reward -233374 , total_steps 1320, average reward -176.80 , invalid_moves 14 , reward_step -177.62
# **************************************************
# Episode : 51 , J : 88.20000 , total_time 301 , total_deadlock - 1
# Episode : 51 Total reward -437205 , total_steps 1388, average reward -314.99 , invalid_moves 34 , reward_step -320.39
# Episode : 52 Ended in deadlock
# **************************************************
# Episode : 53 , J : 59.73750 , total_time 181 , total_deadlock - 2
# Episode : 53 Total reward -138066 , total_steps 1017, average reward -135.76 , invalid_moves 9 , reward_step -136.08
# **************************************************
# Episode : 54 , J : 142.71250 , total_time 301 , total_deadlock - 2
# Episode : 54 Total reward -721192 , total_steps 1995, average reward -361.50 , invalid_moves 55 , reward_step -368.91
# **************************************************
# Episode : 55 , J : 16.88750 , total_time 121 , total_deadlock - 2
# Episode : 55 Total reward -68077 , total_steps 359, average reward -189.63 , invalid_moves 6 , reward_step -191.15
# **************************************************
# Episode : 56 , J : 153.21250 , total_time 361 , total_deadlock - 2
# Episode : 56 Total reward -933094 , total_steps 2282, average reward -408.89 , invalid_moves 73 , reward_step -419.10
# **************************************************
# Episode : 57 , J : 45.73750 , total_time 201 , total_deadlock - 2
# Episode : 57 Total reward -29887 , total_steps 682, average reward -43.82 , invalid_moves 0 , reward_step -43.82
# **************************************************
# Episode : 58 , J : 48.78750 , total_time 221 , total_deadlock - 2
# Episode : 58 Total reward -35166 , total_steps 796, average reward -44.18 , invalid_moves 0 , reward_step -44.18
# **************************************************
# Episode : 59 , J : 47.63750 , total_time 161 , total_deadlock - 2
# Episode : 59 Total reward -23126 , total_steps 710, average reward -32.57 , invalid_moves 0 , reward_step -32.57
# **************************************************
# Episode : 60 , J : 60.45000 , total_time 181 , total_deadlock - 2
# Episode : 60 Total reward -167026 , total_steps 1015, average reward -164.56 , invalid_moves 12 , reward_step -165.33
# **************************************************
# Episode : 61 , J : 73.10000 , total_time 261 , total_deadlock - 2
# Episode : 61 Total reward -333243 , total_steps 1282, average reward -259.94 , invalid_moves 25 , reward_step -263.12
# **************************************************
# Episode : 62 , J : 96.37500 , total_time 301 , total_deadlock - 2
# Episode : 62 Total reward -413135 , total_steps 1450, average reward -284.92 , invalid_moves 30 , reward_step -288.83
# **************************************************
# Episode : 63 , J : 116.81250 , total_time 301 , total_deadlock - 2
# Episode : 63 Total reward -489913 , total_steps 1615, average reward -303.35 , invalid_moves 36 , reward_step -307.99
# **************************************************
# Episode : 64 , J : 68.17500 , total_time 241 , total_deadlock - 2
# Episode : 64 Total reward -355731 , total_steps 1208, average reward -294.48 , invalid_moves 29 , reward_step -299.26
# **************************************************
# Episode : 65 , J : 83.10000 , total_time 321 , total_deadlock - 2
# Episode : 65 Total reward -318803 , total_steps 1316, average reward -242.25 , invalid_moves 22 , reward_step -244.67
# **************************************************
# Episode : 66 , J : 104.17500 , total_time 301 , total_deadlock - 2
# Episode : 66 Total reward -504948 , total_steps 1636, average reward -308.65 , invalid_moves 37 , reward_step -313.48
# **************************************************
# Episode : 67 , J : 115.28750 , total_time 321 , total_deadlock - 2
# Episode : 67 Total reward -547285 , total_steps 1801, average reward -303.88 , invalid_moves 40 , reward_step -308.51
# **************************************************
# Episode : 68 , J : 90.62500 , total_time 221 , total_deadlock - 2
# Episode : 68 Total reward -247013 , total_steps 1335, average reward -185.03 , invalid_moves 16 , reward_step -186.06
# **************************************************
# Episode : 69 , J : 115.91250 , total_time 321 , total_deadlock - 2
# Episode : 69 Total reward -527711 , total_steps 1838, average reward -287.11 , invalid_moves 36 , reward_step -290.85
# **************************************************
# Episode : 70 , J : 8.55000 , total_time 101 , total_deadlock - 2
# Episode : 70 Total reward -1828 , total_steps 248, average reward -7.37 , invalid_moves 0 , reward_step -7.37
# **************************************************
# Episode : 71 , J : 25.60000 , total_time 101 , total_deadlock - 2
# Episode : 71 Total reward -4640 , total_steps 434, average reward -10.69 , invalid_moves 0 , reward_step -10.69
# **************************************************
# Episode : 72 , J : 18.11250 , total_time 101 , total_deadlock - 2
# Episode : 72 Total reward -4332 , total_steps 375, average reward -11.55 , invalid_moves 0 , reward_step -11.55
# **************************************************
# Episode : 73 , J : 11.36250 , total_time 61 , total_deadlock - 2
# Episode : 73 Total reward -1702 , total_steps 280, average reward -6.08 , invalid_moves 0 , reward_step -6.08
# **************************************************
# Episode : 74 , J : 15.18750 , total_time 61 , total_deadlock - 2
# Episode : 74 Total reward -2262 , total_steps 281, average reward -8.05 , invalid_moves 0 , reward_step -8.05
# **************************************************
# Episode : 75 , J : 7.78750 , total_time 81 , total_deadlock - 2
# Episode : 75 Total reward -1123 , total_steps 227, average reward -4.95 , invalid_moves 0 , reward_step -4.95
# **************************************************
# Episode : 76 , J : 14.31250 , total_time 141 , total_deadlock - 2
# Episode : 76 Total reward -4256 , total_steps 366, average reward -11.63 , invalid_moves 0 , reward_step -11.63
# **************************************************
# Episode : 77 , J : 16.22500 , total_time 81 , total_deadlock - 2
# Episode : 77 Total reward -2687 , total_steps 287, average reward -9.36 , invalid_moves 0 , reward_step -9.36
# **************************************************
# Episode : 78 , J : 21.86250 , total_time 121 , total_deadlock - 2
# Episode : 78 Total reward -39361 , total_steps 487, average reward -80.82 , invalid_moves 3 , reward_step -80.70
# **************************************************
# Episode : 79 , J : 72.21250 , total_time 261 , total_deadlock - 2
# Episode : 79 Total reward -263579 , total_steps 1235, average reward -213.42 , invalid_moves 19 , reward_step -215.20
# **************************************************
# Episode : 80 , J : 62.21250 , total_time 241 , total_deadlock - 2
# Episode : 80 Total reward -330076 , total_steps 1175, average reward -280.92 , invalid_moves 26 , reward_step -285.01
# Episode : 81 Ended in deadlock
# **************************************************
# Episode : 82 , J : 113.43750 , total_time 281 , total_deadlock - 3
# Episode : 82 Total reward -474155 , total_steps 1740, average reward -272.50 , invalid_moves 33 , reward_step -275.84
# **************************************************
# Episode : 83 , J : 21.48750 , total_time 81 , total_deadlock - 3
# Episode : 83 Total reward -3570 , total_steps 349, average reward -10.23 , invalid_moves 0 , reward_step -10.23
# **************************************************
# Episode : 84 , J : 16.23750 , total_time 61 , total_deadlock - 3
# Episode : 84 Total reward -2186 , total_steps 283, average reward -7.72 , invalid_moves 0 , reward_step -7.72
# **************************************************
# Episode : 85 , J : 25.56250 , total_time 161 , total_deadlock - 3
# Episode : 85 Total reward -15953 , total_steps 394, average reward -40.49 , invalid_moves 1 , reward_step -40.34
# **************************************************
# Episode : 86 , J : 69.07500 , total_time 261 , total_deadlock - 3
# Episode : 86 Total reward -220508 , total_steps 1146, average reward -192.42 , invalid_moves 14 , reward_step -193.56
# **************************************************
# Episode : 87 , J : 19.06250 , total_time 161 , total_deadlock - 3
# Episode : 87 Total reward -22098 , total_steps 446, average reward -49.55 , invalid_moves 1 , reward_step -49.43
# **************************************************
# Episode : 88 , J : 122.91250 , total_time 341 , total_deadlock - 3
# Episode : 88 Total reward -590618 , total_steps 1837, average reward -321.51 , invalid_moves 43 , reward_step -326.82
# **************************************************
# Episode : 89 , J : 54.21250 , total_time 301 , total_deadlock - 3
# Episode : 89 Total reward -196490 , total_steps 1038, average reward -189.30 , invalid_moves 13 , reward_step -190.43
# **************************************************
# Episode : 90 , J : 141.23750 , total_time 341 , total_deadlock - 3
# Episode : 90 Total reward -718788 , total_steps 2004, average reward -358.68 , invalid_moves 52 , reward_step -365.57
# **************************************************
# Episode : 91 , J : 31.91250 , total_time 141 , total_deadlock - 3
# Episode : 91 Total reward -27023 , total_steps 644, average reward -41.96 , invalid_moves 1 , reward_step -41.87
# **************************************************
# Episode : 92 , J : 58.21250 , total_time 141 , total_deadlock - 3
# Episode : 92 Total reward -31462 , total_steps 739, average reward -42.57 , invalid_moves 1 , reward_step -42.50
# **************************************************
# Episode : 93 , J : 16.18750 , total_time 101 , total_deadlock - 3
# Episode : 93 Total reward -3812 , total_steps 314, average reward -12.14 , invalid_moves 0 , reward_step -12.14
# **************************************************
# Episode : 94 , J : 69.81250 , total_time 241 , total_deadlock - 3
# Episode : 94 Total reward -300213 , total_steps 1264, average reward -237.51 , invalid_moves 23 , reward_step -240.06
# **************************************************
# Episode : 95 , J : 146.92500 , total_time 321 , total_deadlock - 3
# Episode : 95 Total reward -637492 , total_steps 1954, average reward -326.25 , invalid_moves 47 , reward_step -331.83
# **************************************************
# Episode : 96 , J : 9.17500 , total_time 81 , total_deadlock - 3
# Episode : 96 Total reward -12068 , total_steps 288, average reward -41.90 , invalid_moves 1 , reward_step -41.70
# **************************************************
# Episode : 97 , J : 13.18750 , total_time 181 , total_deadlock - 3
# Episode : 97 Total reward -23663 , total_steps 383, average reward -61.78 , invalid_moves 2 , reward_step -61.58
# **************************************************
# Episode : 98 , J : 42.06250 , total_time 121 , total_deadlock - 3
# Episode : 98 Total reward -7435 , total_steps 518, average reward -14.35 , invalid_moves 0 , reward_step -14.35
# **************************************************
# Episode : 99 , J : 19.65000 , total_time 81 , total_deadlock - 3
# Episode : 99 Total reward -3137 , total_steps 325, average reward -9.65 , invalid_moves 0 , reward_step -9.65
# **************************************************
# Episode : 100 , J : 12.32500 , total_time 81 , total_deadlock - 3
# Episode : 100 Total reward -12888 , total_steps 288, average reward -44.75 , invalid_moves 1 , reward_step -44.56
# **************************************************
# Episode : 101 , J : 63.58750 , total_time 241 , total_deadlock - 3
# Episode : 101 Total reward -351822 , total_steps 1187, average reward -296.40 , invalid_moves 28 , reward_step -301.14
# **************************************************
# Episode : 102 , J : 104.15000 , total_time 281 , total_deadlock - 3
# Episode : 102 Total reward -509514 , total_steps 1700, average reward -299.71 , invalid_moves 38 , reward_step -304.28
# **************************************************
# Episode : 103 , J : 138.47500 , total_time 341 , total_deadlock - 3
# Episode : 103 Total reward -654024 , total_steps 1897, average reward -344.77 , invalid_moves 49 , reward_step -351.26
# **************************************************
# Episode : 104 , J : 21.93750 , total_time 141 , total_deadlock - 3
# Episode : 104 Total reward -10227 , total_steps 515, average reward -19.86 , invalid_moves 0 , reward_step -19.86
# **************************************************
# Episode : 105 , J : 37.40000 , total_time 101 , total_deadlock - 3
# Episode : 105 Total reward -21739 , total_steps 540, average reward -40.26 , invalid_moves 1 , reward_step -40.15
# **************************************************
# Episode : 106 , J : 10.67500 , total_time 41 , total_deadlock - 3
# Episode : 106 Total reward -1209 , total_steps 225, average reward -5.37 , invalid_moves 0 , reward_step -5.37
# **************************************************
# Episode : 107 , J : 17.96250 , total_time 121 , total_deadlock - 3
# Episode : 107 Total reward -3632 , total_steps 327, average reward -11.11 , invalid_moves 0 , reward_step -11.11
# **************************************************
# Episode : 108 , J : 16.33750 , total_time 81 , total_deadlock - 3
# Episode : 108 Total reward -2592 , total_steps 308, average reward -8.42 , invalid_moves 0 , reward_step -8.42
# **************************************************
# Episode : 109 , J : 62.76250 , total_time 201 , total_deadlock - 3
# Episode : 109 Total reward -236124 , total_steps 967, average reward -244.18 , invalid_moves 19 , reward_step -247.07
# **************************************************
# Episode : 110 , J : 66.75000 , total_time 301 , total_deadlock - 3
# Episode : 110 Total reward -346314 , total_steps 1352, average reward -256.15 , invalid_moves 26 , reward_step -259.21
# **************************************************
# Episode : 111 , J : 13.85000 , total_time 81 , total_deadlock - 3
# Episode : 111 Total reward -2369 , total_steps 287, average reward -8.25 , invalid_moves 0 , reward_step -8.25
# **************************************************
# Episode : 112 , J : 10.96250 , total_time 61 , total_deadlock - 3
# Episode : 112 Total reward -1601 , total_steps 245, average reward -6.53 , invalid_moves 0 , reward_step -6.53
# **************************************************
# Episode : 113 , J : 22.65000 , total_time 101 , total_deadlock - 3
# Episode : 113 Total reward -4990 , total_steps 386, average reward -12.93 , invalid_moves 0 , reward_step -12.93
# **************************************************
# Episode : 114 , J : 10.86250 , total_time 61 , total_deadlock - 3
# Episode : 114 Total reward -1434 , total_steps 228, average reward -6.29 , invalid_moves 0 , reward_step -6.29
# **************************************************
# Episode : 115 , J : 14.83750 , total_time 101 , total_deadlock - 3
# Episode : 115 Total reward -3293 , total_steps 265, average reward -12.43 , invalid_moves 0 , reward_step -12.43
# **************************************************
# Episode : 116 , J : 31.48750 , total_time 141 , total_deadlock - 3
# Episode : 116 Total reward -8577 , total_steps 474, average reward -18.09 , invalid_moves 0 , reward_step -18.09
# **************************************************
# Episode : 117 , J : 15.35000 , total_time 121 , total_deadlock - 3
# Episode : 117 Total reward -3858 , total_steps 363, average reward -10.63 , invalid_moves 0 , reward_step -10.63
# **************************************************
# Episode : 118 , J : 21.35000 , total_time 81 , total_deadlock - 3
# Episode : 118 Total reward -4198 , total_steps 363, average reward -11.56 , invalid_moves 0 , reward_step -11.56
# **************************************************
# Episode : 119 , J : 28.41250 , total_time 121 , total_deadlock - 3
# Episode : 119 Total reward -4856 , total_steps 409, average reward -11.87 , invalid_moves 0 , reward_step -11.87
# **************************************************
# Episode : 120 , J : 23.26250 , total_time 81 , total_deadlock - 3
# Episode : 120 Total reward -4056 , total_steps 367, average reward -11.05 , invalid_moves 0 , reward_step -11.05
# **************************************************
# Episode : 121 , J : 19.25000 , total_time 101 , total_deadlock - 3
# Episode : 121 Total reward -3292 , total_steps 318, average reward -10.35 , invalid_moves 0 , reward_step -10.35
# **************************************************
# Episode : 122 , J : 17.18750 , total_time 81 , total_deadlock - 3
# Episode : 122 Total reward -2755 , total_steps 327, average reward -8.43 , invalid_moves 0 , reward_step -8.43
# **************************************************
# Episode : 123 , J : 21.33750 , total_time 81 , total_deadlock - 3
# Episode : 123 Total reward -4232 , total_steps 359, average reward -11.79 , invalid_moves 0 , reward_step -11.79
# **************************************************
# Episode : 124 , J : 83.85000 , total_time 261 , total_deadlock - 3
# Episode : 124 Total reward -408075 , total_steps 1443, average reward -282.80 , invalid_moves 33 , reward_step -287.07
# **************************************************
# Episode : 125 , J : 17.30000 , total_time 201 , total_deadlock - 3
# Episode : 125 Total reward -12335 , total_steps 377, average reward -32.72 , invalid_moves 0 , reward_step -32.72
# Episode : 126 Ended in deadlock
# **************************************************
# Episode : 127 , J : 104.88750 , total_time 261 , total_deadlock - 4
# Episode : 127 Total reward -433614 , total_steps 1541, average reward -281.38 , invalid_moves 32 , reward_step -285.23
# **************************************************
# Episode : 128 , J : 154.13750 , total_time 341 , total_deadlock - 4
# Episode : 128 Total reward -634725 , total_steps 2117, average reward -299.82 , invalid_moves 45 , reward_step -304.16
# **************************************************
# Episode : 129 , J : 27.52500 , total_time 181 , total_deadlock - 4
# Episode : 129 Total reward -53081 , total_steps 701, average reward -75.72 , invalid_moves 3 , reward_step -75.62
# **************************************************
# Episode : 130 , J : 91.27500 , total_time 281 , total_deadlock - 4
# Episode : 130 Total reward -366938 , total_steps 1489, average reward -246.43 , invalid_moves 26 , reward_step -249.03
# **************************************************
# Episode : 131 , J : 28.35000 , total_time 121 , total_deadlock - 4
# Episode : 131 Total reward -5238 , total_steps 462, average reward -11.34 , invalid_moves 0 , reward_step -11.34
# **************************************************
# Episode : 132 , J : 17.95000 , total_time 81 , total_deadlock - 4
# Episode : 132 Total reward -3318 , total_steps 301, average reward -11.02 , invalid_moves 0 , reward_step -11.02
# **************************************************
# Episode : 133 , J : 26.11250 , total_time 101 , total_deadlock - 4
# Episode : 133 Total reward -5362 , total_steps 417, average reward -12.86 , invalid_moves 0 , reward_step -12.86
# **************************************************
# Episode : 134 , J : 28.01250 , total_time 101 , total_deadlock - 4
# Episode : 134 Total reward -4700 , total_steps 380, average reward -12.37 , invalid_moves 0 , reward_step -12.37
# **************************************************
# Episode : 135 , J : 35.05000 , total_time 161 , total_deadlock - 4
# Episode : 135 Total reward -9430 , total_steps 537, average reward -17.56 , invalid_moves 0 , reward_step -17.56
# **************************************************
# Episode : 136 , J : 17.43750 , total_time 81 , total_deadlock - 4
# Episode : 136 Total reward -2308 , total_steps 289, average reward -7.99 , invalid_moves 0 , reward_step -7.99
# **************************************************
# Episode : 137 , J : 37.90000 , total_time 141 , total_deadlock - 4
# Episode : 137 Total reward -8172 , total_steps 519, average reward -15.75 , invalid_moves 0 , reward_step -15.75
# **************************************************
# Episode : 138 , J : 15.93750 , total_time 101 , total_deadlock - 4
# Episode : 138 Total reward -3224 , total_steps 289, average reward -11.16 , invalid_moves 0 , reward_step -11.16
# **************************************************
# Episode : 139 , J : 26.92500 , total_time 81 , total_deadlock - 4
# Episode : 139 Total reward -4671 , total_steps 382, average reward -12.23 , invalid_moves 0 , reward_step -12.23
# **************************************************
# Episode : 140 , J : 15.33750 , total_time 121 , total_deadlock - 4
# Episode : 140 Total reward -3624 , total_steps 315, average reward -11.50 , invalid_moves 0 , reward_step -11.50
# **************************************************
# Episode : 141 , J : 30.35000 , total_time 141 , total_deadlock - 4
# Episode : 141 Total reward -4164 , total_steps 406, average reward -10.26 , invalid_moves 0 , reward_step -10.26
# **************************************************
# Episode : 142 , J : 16.08750 , total_time 61 , total_deadlock - 4
# Episode : 142 Total reward -2365 , total_steps 271, average reward -8.73 , invalid_moves 0 , reward_step -8.73
# Episode : 143 Ended in deadlock
# **************************************************
# Episode : 144 , J : 88.55000 , total_time 241 , total_deadlock - 5
# Episode : 144 Total reward -423661 , total_steps 1514, average reward -279.83 , invalid_moves 32 , reward_step -283.71
# **************************************************
# Episode : 145 , J : 124.43750 , total_time 361 , total_deadlock - 5
# Episode : 145 Total reward -479287 , total_steps 1840, average reward -260.48 , invalid_moves 30 , reward_step -263.14
# **************************************************
# Episode : 146 , J : 131.60000 , total_time 301 , total_deadlock - 5
# Episode : 146 Total reward -481934 , total_steps 1882, average reward -256.08 , invalid_moves 32 , reward_step -258.78
# **************************************************
# Episode : 147 , J : 86.70000 , total_time 221 , total_deadlock - 5
# Episode : 147 Total reward -461443 , total_steps 1405, average reward -328.43 , invalid_moves 37 , reward_step -334.61
# **************************************************
# Episode : 148 , J : 102.17500 , total_time 261 , total_deadlock - 5
# Episode : 148 Total reward -272695 , total_steps 1431, average reward -190.56 , invalid_moves 17 , reward_step -191.65
# **************************************************
# Episode : 149 , J : 34.22500 , total_time 121 , total_deadlock - 5
# Episode : 149 Total reward -6905 , total_steps 500, average reward -13.81 , invalid_moves 0 , reward_step -13.81
# **************************************************
# Episode : 150 , J : 7.66250 , total_time 61 , total_deadlock - 5
# Episode : 150 Total reward -1266 , total_steps 218, average reward -5.81 , invalid_moves 0 , reward_step -5.81
# **************************************************
# Episode : 151 , J : 11.23750 , total_time 81 , total_deadlock - 5
# Episode : 151 Total reward -12326 , total_steps 278, average reward -44.34 , invalid_moves 1 , reward_step -44.14
# **************************************************
# Episode : 152 , J : 25.68750 , total_time 161 , total_deadlock - 5
# Episode : 152 Total reward -9460 , total_steps 486, average reward -19.47 , invalid_moves 0 , reward_step -19.47
# **************************************************
# Episode : 153 , J : 19.88750 , total_time 121 , total_deadlock - 5
# Episode : 153 Total reward -6628 , total_steps 414, average reward -16.01 , invalid_moves 0 , reward_step -16.01
# **************************************************
# Episode : 154 , J : 14.26250 , total_time 61 , total_deadlock - 5
# Episode : 154 Total reward -2006 , total_steps 249, average reward -8.06 , invalid_moves 0 , reward_step -8.06
# **************************************************
# Episode : 155 , J : 33.17500 , total_time 161 , total_deadlock - 5
# Episode : 155 Total reward -31233 , total_steps 598, average reward -52.23 , invalid_moves 1 , reward_step -52.15
# **************************************************
# Episode : 156 , J : 57.65000 , total_time 141 , total_deadlock - 5
# Episode : 156 Total reward -25597 , total_steps 774, average reward -33.07 , invalid_moves 0 , reward_step -33.07
# **************************************************
# Episode : 157 , J : 28.45000 , total_time 161 , total_deadlock - 5
# Episode : 157 Total reward -16026 , total_steps 589, average reward -27.21 , invalid_moves 0 , reward_step -27.21
# **************************************************
# Episode : 158 , J : 55.50000 , total_time 141 , total_deadlock - 5
# Episode : 158 Total reward -29652 , total_steps 807, average reward -36.74 , invalid_moves 0 , reward_step -36.74
# **************************************************
# Episode : 159 , J : 16.73750 , total_time 81 , total_deadlock - 5
# Episode : 159 Total reward -13302 , total_steps 315, average reward -42.23 , invalid_moves 1 , reward_step -42.04
# **************************************************
# Episode : 160 , J : 18.48750 , total_time 101 , total_deadlock - 5
# Episode : 160 Total reward -3634 , total_steps 305, average reward -11.91 , invalid_moves 0 , reward_step -11.91
# **************************************************
# Episode : 161 , J : 18.50000 , total_time 101 , total_deadlock - 5
# Episode : 161 Total reward -26189 , total_steps 309, average reward -84.75 , invalid_moves 2 , reward_step -84.65
# **************************************************
# Episode : 162 , J : 103.33750 , total_time 241 , total_deadlock - 5
# Episode : 162 Total reward -508660 , total_steps 1452, average reward -350.32 , invalid_moves 43 , reward_step -357.96
# **************************************************
# Episode : 163 , J : 65.91250 , total_time 181 , total_deadlock - 5
# Episode : 163 Total reward -289455 , total_steps 1168, average reward -247.82 , invalid_moves 23 , reward_step -250.79
# **************************************************
# Episode : 164 , J : 105.42500 , total_time 281 , total_deadlock - 5
# Episode : 164 Total reward -436451 , total_steps 1502, average reward -290.58 , invalid_moves 33 , reward_step -294.86
# **************************************************
# Episode : 165 , J : 70.67500 , total_time 201 , total_deadlock - 5
# Episode : 165 Total reward -354508 , total_steps 1278, average reward -277.39 , invalid_moves 28 , reward_step -281.37
# **************************************************
# Episode : 166 , J : 120.08750 , total_time 421 , total_deadlock - 5
# Episode : 166 Total reward -522895 , total_steps 1986, average reward -263.29 , invalid_moves 32 , reward_step -265.96
# **************************************************
# Episode : 167 , J : 45.38750 , total_time 241 , total_deadlock - 5
# Episode : 167 Total reward -145333 , total_steps 766, average reward -189.73 , invalid_moves 11 , reward_step -191.04
# **************************************************
# Episode : 168 , J : 89.71250 , total_time 221 , total_deadlock - 5
# Episode : 168 Total reward -361071 , total_steps 1332, average reward -271.07 , invalid_moves 28 , reward_step -274.75
# **************************************************
# Episode : 169 , J : 103.21250 , total_time 321 , total_deadlock - 5
# Episode : 169 Total reward -506651 , total_steps 1697, average reward -298.56 , invalid_moves 37 , reward_step -302.98
# **************************************************
# Episode : 170 , J : 111.43750 , total_time 261 , total_deadlock - 5
# Episode : 170 Total reward -490046 , total_steps 1688, average reward -290.31 , invalid_moves 36 , reward_step -294.46
# **************************************************
# Episode : 171 , J : 71.48750 , total_time 221 , total_deadlock - 5
# Episode : 171 Total reward -257799 , total_steps 1175, average reward -219.40 , invalid_moves 19 , reward_step -221.37
# **************************************************
# Episode : 172 , J : 73.70000 , total_time 181 , total_deadlock - 5
# Episode : 172 Total reward -228171 , total_steps 1092, average reward -208.95 , invalid_moves 17 , reward_step -210.67
# **************************************************
# Episode : 173 , J : 120.33750 , total_time 301 , total_deadlock - 5
# Episode : 173 Total reward -541121 , total_steps 1696, average reward -319.06 , invalid_moves 41 , reward_step -324.48
# Episode : 174 Ended in deadlock
# **************************************************
# Episode : 175 , J : 83.30000 , total_time 221 , total_deadlock - 6
# Episode : 175 Total reward -251850 , total_steps 1215, average reward -207.28 , invalid_moves 18 , reward_step -208.90
# **************************************************
# Episode : 176 , J : 115.08750 , total_time 321 , total_deadlock - 6
# Episode : 176 Total reward -585329 , total_steps 1790, average reward -327.00 , invalid_moves 43 , reward_step -332.59
# **************************************************
# Episode : 177 , J : 129.42500 , total_time 321 , total_deadlock - 6
# Episode : 177 Total reward -636280 , total_steps 1888, average reward -337.01 , invalid_moves 47 , reward_step -343.06
# Episode : 178 Ended in deadlock
# **************************************************
# Episode : 179 , J : 165.68750 , total_time 421 , total_deadlock - 7
# Episode : 179 Total reward -783493 , total_steps 2281, average reward -343.49 , invalid_moves 52 , reward_step -349.17
# **************************************************
# Episode : 180 , J : 13.46250 , total_time 81 , total_deadlock - 7
# Episode : 180 Total reward -2541 , total_steps 297, average reward -8.56 , invalid_moves 0 , reward_step -8.56
# **************************************************
# Episode : 181 , J : 17.58750 , total_time 101 , total_deadlock - 7
# Episode : 181 Total reward -3964 , total_steps 331, average reward -11.98 , invalid_moves 0 , reward_step -11.98
# **************************************************
# Episode : 182 , J : 8.96250 , total_time 61 , total_deadlock - 7
# Episode : 182 Total reward -11445 , total_steps 229, average reward -49.98 , invalid_moves 1 , reward_step -49.76
# **************************************************
# Episode : 183 , J : 14.12500 , total_time 101 , total_deadlock - 7
# Episode : 183 Total reward -3795 , total_steps 356, average reward -10.66 , invalid_moves 0 , reward_step -10.66
# **************************************************
# Episode : 184 , J : 13.12500 , total_time 101 , total_deadlock - 7
# Episode : 184 Total reward -2106 , total_steps 286, average reward -7.36 , invalid_moves 0 , reward_step -7.36
# **************************************************
# Episode : 185 , J : 12.07500 , total_time 81 , total_deadlock - 7
# Episode : 185 Total reward -1674 , total_steps 241, average reward -6.95 , invalid_moves 0 , reward_step -6.95
# **************************************************
# Episode : 186 , J : 23.22500 , total_time 81 , total_deadlock - 7
# Episode : 186 Total reward -3941 , total_steps 366, average reward -10.77 , invalid_moves 0 , reward_step -10.77
# **************************************************
# Episode : 187 , J : 17.15000 , total_time 61 , total_deadlock - 7
# Episode : 187 Total reward -2413 , total_steps 291, average reward -8.29 , invalid_moves 0 , reward_step -8.29
# **************************************************
# Episode : 188 , J : 17.55000 , total_time 101 , total_deadlock - 7
# Episode : 188 Total reward -2615 , total_steps 304, average reward -8.60 , invalid_moves 0 , reward_step -8.60
# **************************************************
# Episode : 189 , J : 19.90000 , total_time 141 , total_deadlock - 7
# Episode : 189 Total reward -7908 , total_steps 451, average reward -17.53 , invalid_moves 0 , reward_step -17.53
# **************************************************
# Episode : 190 , J : 17.80000 , total_time 121 , total_deadlock - 7
# Episode : 190 Total reward -30028 , total_steps 415, average reward -72.36 , invalid_moves 2 , reward_step -72.22
# **************************************************
# Episode : 191 , J : 104.71250 , total_time 221 , total_deadlock - 7
# Episode : 191 Total reward -462640 , total_steps 1631, average reward -283.65 , invalid_moves 35 , reward_step -287.68
# **************************************************
# Episode : 192 , J : 30.57500 , total_time 141 , total_deadlock - 7
# Episode : 192 Total reward -114336 , total_steps 758, average reward -150.84 , invalid_moves 9 , reward_step -151.45
# **************************************************
# Episode : 193 , J : 132.83750 , total_time 321 , total_deadlock - 7
# Episode : 193 Total reward -725209 , total_steps 1871, average reward -387.61 , invalid_moves 57 , reward_step -396.64
# **************************************************
# Episode : 194 , J : 67.75000 , total_time 181 , total_deadlock - 7
# Episode : 194 Total reward -212380 , total_steps 1063, average reward -199.79 , invalid_moves 16 , reward_step -201.32
# **************************************************
# Episode : 195 , J : 137.22500 , total_time 281 , total_deadlock - 7
# Episode : 195 Total reward -612311 , total_steps 1881, average reward -325.52 , invalid_moves 47 , reward_step -331.30
# **************************************************
# Episode : 196 , J : 18.88750 , total_time 61 , total_deadlock - 7
# Episode : 196 Total reward -2153 , total_steps 279, average reward -7.72 , invalid_moves 0 , reward_step -7.72
# **************************************************
# Episode : 197 , J : 20.78750 , total_time 81 , total_deadlock - 7
# Episode : 197 Total reward -3054 , total_steps 326, average reward -9.37 , invalid_moves 0 , reward_step -9.37
# **************************************************
# Episode : 198 , J : 12.45000 , total_time 61 , total_deadlock - 7
# Episode : 198 Total reward -11555 , total_steps 218, average reward -53.00 , invalid_moves 1 , reward_step -52.79
# **************************************************
# Episode : 199 , J : 20.97500 , total_time 121 , total_deadlock - 7
# Episode : 199 Total reward -5101 , total_steps 358, average reward -14.25 , invalid_moves 0 , reward_step -14.25
# **************************************************
# Episode : 200 , J : 94.71250 , total_time 241 , total_deadlock - 7
# Episode : 200 Total reward -346763 , total_steps 1388, average reward -249.83 , invalid_moves 25 , reward_step -252.58
# **************************************************
# Episode : 201 , J : 31.53750 , total_time 161 , total_deadlock - 7
# Episode : 201 Total reward -83524 , total_steps 614, average reward -136.03 , invalid_moves 6 , reward_step -136.39
# **************************************************
# Episode : 202 , J : 125.82500 , total_time 321 , total_deadlock - 7
# Episode : 202 Total reward -503102 , total_steps 1869, average reward -269.18 , invalid_moves 33 , reward_step -272.22
# **************************************************
# Episode : 203 , J : 13.40000 , total_time 61 , total_deadlock - 7
# Episode : 203 Total reward -1829 , total_steps 241, average reward -7.59 , invalid_moves 0 , reward_step -7.59
# **************************************************
# Episode : 204 , J : 17.17500 , total_time 141 , total_deadlock - 7
# Episode : 204 Total reward -12960 , total_steps 378, average reward -34.29 , invalid_moves 1 , reward_step -34.11
# **************************************************
# Episode : 205 , J : 26.50000 , total_time 101 , total_deadlock - 7
# Episode : 205 Total reward -4832 , total_steps 399, average reward -12.11 , invalid_moves 0 , reward_step -12.11
# **************************************************
# Episode : 206 , J : 14.10000 , total_time 81 , total_deadlock - 7
# Episode : 206 Total reward -2567 , total_steps 296, average reward -8.67 , invalid_moves 0 , reward_step -8.67
# **************************************************
# Episode : 207 , J : 15.01250 , total_time 61 , total_deadlock - 7
# Episode : 207 Total reward -11976 , total_steps 273, average reward -43.87 , invalid_moves 1 , reward_step -43.66
# **************************************************
# Episode : 208 , J : 18.43750 , total_time 141 , total_deadlock - 7
# Episode : 208 Total reward -53513 , total_steps 528, average reward -101.35 , invalid_moves 4 , reward_step -101.36
# **************************************************
# Episode : 209 , J : 117.92500 , total_time 301 , total_deadlock - 7
# Episode : 209 Total reward -495749 , total_steps 1719, average reward -288.39 , invalid_moves 36 , reward_step -292.42
# **************************************************
# Episode : 210 , J : 5.12500 , total_time 101 , total_deadlock - 7
# Episode : 210 Total reward -1320 , total_steps 259, average reward -5.10 , invalid_moves 0 , reward_step -5.10
# **************************************************
# Episode : 211 , J : 24.77500 , total_time 181 , total_deadlock - 7
# Episode : 211 Total reward -80442 , total_steps 546, average reward -147.33 , invalid_moves 6 , reward_step -147.86
# **************************************************
# Episode : 212 , J : 97.37500 , total_time 261 , total_deadlock - 7
# ...
# **************************************************
# Episode : 930 , J : 20.95000 , total_time 81 , total_deadlock - 14
# Episode : 930 Total reward -3664 , total_steps 375, average reward -9.77 , invalid_moves 0 , reward_step -9.77
# **************************************************
# Episode : 931 , J : 26.31250 , total_time 141 , total_deadlock - 14
# Episode : 931 Total reward -4109 , total_steps 408, average reward -10.07 , invalid_moves 0 , reward_step -10.07
# **************************************************
# Episode : 932 , J : 13.75000 , total_time 81 , total_deadlock - 14
# Episode : 932 Total reward -2557 , total_steps 298, average reward -8.58 , invalid_moves 0 , reward_step -8.58
# **************************************************
# Episode : 933 , J : 11.32500 , total_time 101 , total_deadlock - 14
# Episode : 933 Total reward -2029 , total_steps 307, average reward -6.61 , invalid_moves 0 , reward_step -6.61
# **************************************************
# Episode : 934 , J : 18.61250 , total_time 81 , total_deadlock - 14
# Episode : 934 Total reward -3076 , total_steps 333, average reward -9.24 , invalid_moves 0 , reward_step -9.24
# **************************************************
# Episode : 935 , J : 20.32500 , total_time 101 , total_deadlock - 14
# Episode : 935 Total reward -4731 , total_steps 406, average reward -11.65 , invalid_moves 0 , reward_step -11.65
# **************************************************
# Episode : 936 , J : 34.96250 , total_time 101 , total_deadlock - 14
# Episode : 936 Total reward -5954 , total_steps 505, average reward -11.79 , invalid_moves 0 , reward_step -11.79
# **************************************************
# Episode : 937 , J : 14.88750 , total_time 81 , total_deadlock - 14
# Episode : 937 Total reward -13252 , total_steps 331, average reward -40.04 , invalid_moves 1 , reward_step -39.85
# **************************************************
# Episode : 938 , J : 10.26250 , total_time 61 , total_deadlock - 14
# Episode : 938 Total reward -1370 , total_steps 226, average reward -6.06 , invalid_moves 0 , reward_step -6.06
# **************************************************
# Episode : 939 , J : 34.28750 , total_time 121 , total_deadlock - 14
# Episode : 939 Total reward -17729 , total_steps 517, average reward -34.29 , invalid_moves 1 , reward_step -34.16
# **************************************************
# Episode : 940 , J : 22.52500 , total_time 101 , total_deadlock - 14
# Episode : 940 Total reward -5054 , total_steps 389, average reward -12.99 , invalid_moves 0 , reward_step -12.99
# **************************************************
# Episode : 941 , J : 22.93750 , total_time 101 , total_deadlock - 14
# Episode : 941 Total reward -14716 , total_steps 419, average reward -35.12 , invalid_moves 1 , reward_step -34.97
# **************************************************
# Episode : 942 , J : 16.31250 , total_time 81 , total_deadlock - 14
# Episode : 942 Total reward -13279 , total_steps 322, average reward -41.24 , invalid_moves 1 , reward_step -41.06
# **************************************************
# Episode : 943 , J : 22.63750 , total_time 81 , total_deadlock - 14
# Episode : 943 Total reward -4258 , total_steps 357, average reward -11.93 , invalid_moves 0 , reward_step -11.93
# **************************************************
# Episode : 944 , J : 11.98750 , total_time 61 , total_deadlock - 14
# Episode : 944 Total reward -21904 , total_steps 245, average reward -89.40 , invalid_moves 2 , reward_step -89.32
# **************************************************
# Episode : 945 , J : 11.50000 , total_time 61 , total_deadlock - 14
# Episode : 945 Total reward -1912 , total_steps 262, average reward -7.30 , invalid_moves 0 , reward_step -7.30
# **************************************************
# Episode : 946 , J : 7.98750 , total_time 61 , total_deadlock - 14
# Episode : 946 Total reward -1501 , total_steps 259, average reward -5.80 , invalid_moves 0 , reward_step -5.80
# **************************************************
# Episode : 947 , J : 17.95000 , total_time 121 , total_deadlock - 14
# Episode : 947 Total reward -26326 , total_steps 462, average reward -56.98 , invalid_moves 2 , reward_step -56.80
# **************************************************
# Episode : 948 , J : 22.11250 , total_time 101 , total_deadlock - 14
# Episode : 948 Total reward -14680 , total_steps 368, average reward -39.89 , invalid_moves 1 , reward_step -39.73
# **************************************************
# Episode : 949 , J : 12.48750 , total_time 101 , total_deadlock - 14
# Episode : 949 Total reward -2040 , total_steps 295, average reward -6.92 , invalid_moves 0 , reward_step -6.92
# **************************************************
# Episode : 950 , J : 26.91250 , total_time 121 , total_deadlock - 14
# Episode : 950 Total reward -6109 , total_steps 401, average reward -15.23 , invalid_moves 0 , reward_step -15.23
# **************************************************
# Episode : 951 , J : 23.53750 , total_time 101 , total_deadlock - 14
# Episode : 951 Total reward -4584 , total_steps 375, average reward -12.22 , invalid_moves 0 , reward_step -12.22
# **************************************************
# Episode : 952 , J : 19.33750 , total_time 81 , total_deadlock - 14
# Episode : 952 Total reward -3840 , total_steps 336, average reward -11.43 , invalid_moves 0 , reward_step -11.43
# **************************************************
# Episode : 953 , J : 20.88750 , total_time 101 , total_deadlock - 14
# Episode : 953 Total reward -3397 , total_steps 360, average reward -9.44 , invalid_moves 0 , reward_step -9.44
# **************************************************
# Episode : 954 , J : 8.70000 , total_time 101 , total_deadlock - 14
# Episode : 954 Total reward -2003 , total_steps 299, average reward -6.70 , invalid_moves 0 , reward_step -6.70
# **************************************************
# Episode : 955 , J : 13.36250 , total_time 81 , total_deadlock - 14
# Episode : 955 Total reward -2758 , total_steps 292, average reward -9.45 , invalid_moves 0 , reward_step -9.45
# **************************************************
# Episode : 956 , J : 27.98750 , total_time 121 , total_deadlock - 14
# Episode : 956 Total reward -7533 , total_steps 439, average reward -17.16 , invalid_moves 0 , reward_step -17.16
# **************************************************
# Episode : 957 , J : 10.36250 , total_time 61 , total_deadlock - 14
# Episode : 957 Total reward -1294 , total_steps 234, average reward -5.53 , invalid_moves 0 , reward_step -5.53
# **************************************************
# Episode : 958 , J : 13.48750 , total_time 41 , total_deadlock - 14
# Episode : 958 Total reward -1588 , total_steps 241, average reward -6.59 , invalid_moves 0 , reward_step -6.59
# **************************************************
# Episode : 959 , J : 19.20000 , total_time 81 , total_deadlock - 14
# Episode : 959 Total reward -23209 , total_steps 301, average reward -77.11 , invalid_moves 2 , reward_step -76.95
# **************************************************
# Episode : 960 , J : 16.77500 , total_time 81 , total_deadlock - 14
# Episode : 960 Total reward -4553 , total_steps 370, average reward -12.31 , invalid_moves 0 , reward_step -12.31
# **************************************************
# Episode : 961 , J : 33.01250 , total_time 101 , total_deadlock - 14
# Episode : 961 Total reward -6490 , total_steps 450, average reward -14.42 , invalid_moves 0 , reward_step -14.42
# **************************************************
# Episode : 962 , J : 14.51250 , total_time 81 , total_deadlock - 14
# Episode : 962 Total reward -2464 , total_steps 311, average reward -7.92 , invalid_moves 0 , reward_step -7.92
# **************************************************
# Episode : 963 , J : 21.86250 , total_time 81 , total_deadlock - 14
# Episode : 963 Total reward -2726 , total_steps 329, average reward -8.29 , invalid_moves 0 , reward_step -8.29
# **************************************************
# Episode : 964 , J : 11.98750 , total_time 101 , total_deadlock - 14
# Episode : 964 Total reward -3099 , total_steps 342, average reward -9.06 , invalid_moves 0 , reward_step -9.06
# **************************************************
# Episode : 965 , J : 18.58750 , total_time 101 , total_deadlock - 14
# Episode : 965 Total reward -4001 , total_steps 352, average reward -11.37 , invalid_moves 0 , reward_step -11.37
# **************************************************
# Episode : 966 , J : 11.76250 , total_time 61 , total_deadlock - 14
# Episode : 966 Total reward -2153 , total_steps 285, average reward -7.55 , invalid_moves 0 , reward_step -7.55
# **************************************************
# Episode : 967 , J : 12.20000 , total_time 121 , total_deadlock - 14
# Episode : 967 Total reward -33391 , total_steps 400, average reward -83.48 , invalid_moves 3 , reward_step -83.35
# **************************************************
# Episode : 968 , J : 16.22500 , total_time 81 , total_deadlock - 14
# Episode : 968 Total reward -2746 , total_steps 325, average reward -8.45 , invalid_moves 0 , reward_step -8.45
# **************************************************
# Episode : 969 , J : 13.31250 , total_time 81 , total_deadlock - 14
# Episode : 969 Total reward -2806 , total_steps 358, average reward -7.84 , invalid_moves 0 , reward_step -7.84
# **************************************************
# Episode : 970 , J : 12.15000 , total_time 81 , total_deadlock - 14
# Episode : 970 Total reward -12163 , total_steps 315, average reward -38.61 , invalid_moves 1 , reward_step -38.42
# **************************************************
# Episode : 971 , J : 15.65000 , total_time 101 , total_deadlock - 14
# Episode : 971 Total reward -3235 , total_steps 312, average reward -10.37 , invalid_moves 0 , reward_step -10.37
# **************************************************
# Episode : 972 , J : 10.23750 , total_time 61 , total_deadlock - 14
# Episode : 972 Total reward -1457 , total_steps 236, average reward -6.17 , invalid_moves 0 , reward_step -6.17
# **************************************************
# Episode : 973 , J : 18.82500 , total_time 81 , total_deadlock - 14
# Episode : 973 Total reward -3904 , total_steps 355, average reward -11.00 , invalid_moves 0 , reward_step -11.00
# **************************************************
# Episode : 974 , J : 23.30000 , total_time 141 , total_deadlock - 14
# Episode : 974 Total reward -15622 , total_steps 407, average reward -38.38 , invalid_moves 1 , reward_step -38.23
# Episode : 975 Ended in deadlock
# **************************************************
# Episode : 976 , J : 14.01250 , total_time 141 , total_deadlock - 15
# Episode : 976 Total reward -2859 , total_steps 370, average reward -7.73 , invalid_moves 0 , reward_step -7.73
# **************************************************
# Episode : 977 , J : 15.82500 , total_time 101 , total_deadlock - 15
# Episode : 977 Total reward -3989 , total_steps 414, average reward -9.64 , invalid_moves 0 , reward_step -9.64
# **************************************************
# Episode : 978 , J : 12.75000 , total_time 81 , total_deadlock - 15
# Episode : 978 Total reward -12777 , total_steps 350, average reward -36.51 , invalid_moves 1 , reward_step -36.32
# **************************************************
# Episode : 979 , J : 24.46250 , total_time 81 , total_deadlock - 15
# Episode : 979 Total reward -3311 , total_steps 387, average reward -8.56 , invalid_moves 0 , reward_step -8.56
# **************************************************
# Episode : 980 , J : 14.30000 , total_time 61 , total_deadlock - 15
# Episode : 980 Total reward -1713 , total_steps 262, average reward -6.54 , invalid_moves 0 , reward_step -6.54
# **************************************************
# Episode : 981 , J : 15.60000 , total_time 161 , total_deadlock - 15
# Episode : 981 Total reward -13091 , total_steps 423, average reward -30.95 , invalid_moves 1 , reward_step -30.78
# **************************************************
# Episode : 982 , J : 24.52500 , total_time 101 , total_deadlock - 15
# Episode : 982 Total reward -6115 , total_steps 434, average reward -14.09 , invalid_moves 0 , reward_step -14.09
# **************************************************
# Episode : 983 , J : 39.12500 , total_time 241 , total_deadlock - 15
# Episode : 983 Total reward -13983 , total_steps 541, average reward -25.85 , invalid_moves 0 , reward_step -25.85
# **************************************************
# Episode : 984 , J : 20.67500 , total_time 61 , total_deadlock - 15
# Episode : 984 Total reward -3116 , total_steps 344, average reward -9.06 , invalid_moves 0 , reward_step -9.06
# **************************************************
# Episode : 985 , J : 31.85000 , total_time 101 , total_deadlock - 15
# Episode : 985 Total reward -16655 , total_steps 464, average reward -35.89 , invalid_moves 1 , reward_step -35.76
# **************************************************
# Episode : 986 , J : 8.46250 , total_time 101 , total_deadlock - 15
# Episode : 986 Total reward -1737 , total_steps 292, average reward -5.95 , invalid_moves 0 , reward_step -5.95
# **************************************************
# Episode : 987 , J : 18.03750 , total_time 81 , total_deadlock - 15
# Episode : 987 Total reward -3871 , total_steps 342, average reward -11.32 , invalid_moves 0 , reward_step -11.32
# **************************************************
# Episode : 988 , J : 14.51250 , total_time 81 , total_deadlock - 15
# Episode : 988 Total reward -2098 , total_steps 255, average reward -8.23 , invalid_moves 0 , reward_step -8.23
# **************************************************
# Episode : 989 , J : 9.40000 , total_time 101 , total_deadlock - 15
# Episode : 989 Total reward -2299 , total_steps 279, average reward -8.24 , invalid_moves 0 , reward_step -8.24
# **************************************************
# Episode : 990 , J : 15.72500 , total_time 121 , total_deadlock - 15
# Episode : 990 Total reward -4269 , total_steps 380, average reward -11.23 , invalid_moves 0 , reward_step -11.23
# **************************************************
# Episode : 991 , J : 12.96250 , total_time 141 , total_deadlock - 15
# Episode : 991 Total reward -3376 , total_steps 342, average reward -9.87 , invalid_moves 0 , reward_step -9.87
# **************************************************
# Episode : 992 , J : 22.93750 , total_time 61 , total_deadlock - 15
# Episode : 992 Total reward -33041 , total_steps 337, average reward -98.04 , invalid_moves 3 , reward_step -98.03
# **************************************************
# Episode : 993 , J : 13.57500 , total_time 81 , total_deadlock - 15
# Episode : 993 Total reward -12962 , total_steps 310, average reward -41.81 , invalid_moves 1 , reward_step -41.62
# **************************************************
# Episode : 994 , J : 24.13750 , total_time 81 , total_deadlock - 15
# Episode : 994 Total reward -3781 , total_steps 388, average reward -9.74 , invalid_moves 0 , reward_step -9.74
# **************************************************
# Episode : 995 , J : 21.88750 , total_time 161 , total_deadlock - 15
# Episode : 995 Total reward -4426 , total_steps 489, average reward -9.05 , invalid_moves 0 , reward_step -9.05
# **************************************************
# Episode : 996 , J : 18.30000 , total_time 101 , total_deadlock - 15
# Episode : 996 Total reward -4098 , total_steps 337, average reward -12.16 , invalid_moves 0 , reward_step -12.16
# **************************************************
# Episode : 997 , J : 18.57500 , total_time 81 , total_deadlock - 15
# Episode : 997 Total reward -4110 , total_steps 346, average reward -11.88 , invalid_moves 0 , reward_step -11.88
# **************************************************
# Episode : 998 , J : 14.00000 , total_time 61 , total_deadlock - 15
# Episode : 998 Total reward -1677 , total_steps 237, average reward -7.08 , invalid_moves 0 , reward_step -7.08
# **************************************************
# Episode : 999 , J : 8.93750 , total_time 61 , total_deadlock - 15
# Episode : 999 Total reward -1418 , total_steps 222, average reward -6.39 , invalid_moves 0 , reward_step -6.39

# %%
reward_for_train
# Out:
# {'Train001': [('wait', 0, [1, 0, 0], -277.15197534294657, -207.49398077828332),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -207.49398077828332),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -191.4639698888898),
#   ('move', 0, [1, 0, 0], -240.12924398191984, -176.6723623890801),
#   ('move', -3, [1, 0, 1], -301.4430936695782, -452.7571024250498),
#   ('move', -3, [1, 2, 0], -263.1316019384591, -299.9913983867555),
#   ('move', -3, [1, 0, 1], -289.8344098038349, -452.7571024250498),
#   ('move', -3, [1, 2, 0], -263.20353862695833, -299.9913983867555),
#   ('wait', -3, [1, 0, 2], -12652.231447998101, -337.75849207708006),
#   ('move', -3, [1, 2, 1], -292.8539960472058, -1338.2685740620523),
#   ('move', -4, [1, 2, 0], -274.6072178957541, -299.9913983867555),
#   ('move', -4, [1, 1, 1], -299.7787182492755, -699.6220610478425),
#   ('move', -4, [1, 2, 0], -271.910777756308, -294.9642285461477),
#   ('wait', -4, [1, 0, 0], -253.22364152290703, -162.90287566829798),
#   ('wait', -4, [1, 0, 0], -252.71908234638855, -161.273846911615),
#   ('wait', -4, [1, 1, 0], -251.5058474938022, -208.7731600213955),
#   ('move', -4, [1, 1, 0], -251.5058474938022, -208.7731600213955)],
#  'Train002': [('wait', 0, [1, 0, 0], -268.1112360786974, -207.49398077828332),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -205.41904097050048),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -189.54933019000092),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -180.61675810854487),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -173.8024305963228),
#   ('move', 0, [1, 0, 0], -250.5799017640052, -163.63153832408295),
#   ('move', -5, [1, 0, 1], -289.8344098038349, -452.7571024250498),
#   ('move', -5, [1, 2, 0], -263.20353862695833, -299.9913983867555),
#   ('move', -5, [1, 0, 1], -269.8875147994793, -452.7571024250498),
#   ('move', -5, [1, 2, 1], -292.8539960472058, -1338.2685740620523),
#   ('wait', -5, [1, 0, 2], -12652.231447998101, -327.9331074884844),
#   ('wait', -5, [1, 0, 2], -12652.231447998101, -321.82439784059403),
#   ('move', -5, [1, 0, 1], -268.222370553409, -452.7571024250498),
#   ('move', -7, [1, 2, 0], -257.4850008075824, -294.9642285461477),
#   ('move', -7, [1, 0, 1], -254.31580448792243, -452.7571024250498),
#   ('move', -7, [1, 2, 1], -286.47138257120343, -1338.2685740620523),
#   ('wait', -7, [1, 0, 0], -254.629598543158, -171.66797952129204),
#   ('wait', -7, [1, 0, 0], -254.629598543158, -169.44678672881832),
#   ('move', -7, [1, 0, 0], -254.629598543158, -166.29511771618567)],
#  'Train003': [('wait', 0, [1, 0, 0], -259.97457074087316, -207.49398077828332),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -203.36485056079547),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -187.6538368881009),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -178.81059052745942),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -172.06440629035959),
#   ('wait', 0, [1, 0, 0], -250.5799017640052, -169.82057565043513),
#   ('wait', 0, [1, 0, 0], -250.5799017640052, -169.3682618059005),
#   ('wait', 0, [1, 0, 0], -253.48140450529996, -170.23073880297596),
#   ('wait', 0, [1, 0, 0], -253.63263055839994, -165.17471562978875),
#   ('wait', 0, [1, 0, 0], -253.63263055839994, -160.2688614008684),
#   ('wait', 0, [1, 0, 0], -253.63263055839994, -163.97022733584544),
#   ('wait', 0, [1, 0, 0], -253.22364152290703, -160.7072198118621),
#   ('move', 0, [1, 0, 0], -253.22364152290703, -157.50914613760602),
#   ('move', -12, [1, 0, 1], -262.4200552863579, -452.7571024250498),
#   ('move', -12, [1, 2, 0], -247.32096836477044, -294.9642285461477),
#   ('move', -12, [1, 0, 1], -255.3666484705385, -452.7571024250498),
#   ('move', -12, [1, 2, 0], -239.5104240708707, -294.9642285461477),
#   ('wait', -12, [1, 0, 2], -12652.231447998101, -313.34417665983636),
#   ('move', -12, [1, 0, 1], -245.49268443630086, -430.9528862824978),
#   ('move', -13, [1, 2, 0], -238.41659378201322, -294.9642285461477),
#   ('move', -13, [1, 0, 1], -240.45095733825062, -430.9528862824978),
#   ('wait', -13, [1, 2, 0], -232.55641931826122, -294.9642285461477),
#   ('move', -13, [1, 2, 0], -232.6835151820572, -294.9642285461477),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -177.92642647159278),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -177.92642647159278),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -177.54716220687686),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -177.1716905848081),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -176.79997367896001),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -176.43197394217043),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -174.555907884114),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -179.90091801569346),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -178.90688974718117),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -177.93264264121225),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -176.97778305265214),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -176.04192516990437),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -175.1246908590233),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -181.41276342427398),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -180.99863579003124),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -180.58864943213092),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -180.18276293780963),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -179.78093530843154),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -179.38312595534723),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -178.98929469579375),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -178.59940174883582),
#   ('wait', -14, [1, 0, 0], -254.629598543158, -178.21340773134744),
#   ('move', -14, [1, 0, 0], -254.629598543158, -177.83127365403396)],
#  'Train004': [('wait', 0, [1, 0, 0], -259.97457074087316, -207.49398077828332),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -201.33120205518753),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -185.7772985192199),
#   ('move', 0, [1, 0, 0], -240.12924398191984, -177.02248462218483),
#   ('wait', -3, [1, 0, 2], -12652.231447998101, -345.42581723793637),
#   ('move', -3, [1, 0, 1], -295.28062847708173, -452.7571024250498),
#   ('move', -4, [1, 2, 0], -263.1316019384591, -299.9913983867555),
#   ('move', -4, [1, 0, 1], -276.6596278181107, -452.7571024250498),
#   ('move', -4, [1, 2, 0], -262.18255126789245, -299.9913983867555),
#   ('wait', -4, [1, 1, 2], -15164.2573021042, -374.6915508135403),
#   ('move', -4, [1, 1, 1], -305.36183215320915, -699.6220610478425),
#   ('move', -5, [1, 2, 0], -271.70077012652575, -299.9913983867555),
#   ('move', -5, [1, 0, 1], -268.222370553409, -452.7571024250498),
#   ('move', -5, [1, 2, 0], -257.4850008075824, -294.9642285461477),
#   ('wait', -5, [1, 0, 0], -252.71908234638855, -160.06110844249886),
#   ('wait', -5, [1, 1, 0], -251.5058474938022, -208.7731600213955),
#   ('wait', -5, [1, 0, 0], -254.629598543158, -171.66797952129204),
#   ('wait', -5, [1, 0, 0], -254.629598543158, -171.66797952129204),
#   ('wait', -5, [1, 0, 0], -254.629598543158, -168.45231886153013),
#   ('move', -5, [1, 0, 0], -254.629598543158, -172.34944711531682)],
#  'Train011': [('wait', 0, [1, 0, 0], -252.65157193683135, -207.49398077828332),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -199.31789003463567),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -183.91952553402768),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -180.93186811833914),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -170.34376222745598),
#   ('wait', 0, [1, 0, 0], -250.5799017640052, -168.1223698939308),
#   ('wait', 0, [1, 0, 0], -250.5799017640052, -167.6745791878415),
#   ('wait', 0, [1, 0, 0], -253.48140450529996, -168.5284314149462),
#   ('wait', 0, [1, 0, 0], -253.63263055839994, -163.52296847349086),
#   ('move', 0, [1, 0, 0], -253.63263055839994, -158.6661727868597),
#   ('move', -9, [1, 0, 1], -267.26971133718985, -452.7571024250498),
#   ('move', -9, [1, 2, 1], -289.82890112175636, -1338.2685740620523),
#   ('wait', -9, [1, 0, 2], -12652.231447998101, -311.83555182577607),
#   ('move', -9, [1, 0, 1], -262.4200552863579, -452.7571024250498),
#   ('move', -10, [1, 2, 0], -247.32096836477044, -294.9642285461477),
#   ('wait', -10, [1, 0, 2], -12652.231447998101, -301.773374935091),
#   ('wait', -10, [1, 0, 1], -249.68326777725508, -452.7571024250498),
#   ('move', -10, [1, 0, 1], -249.68326777725508, -452.7571024250498),
#   ('move', -12, [1, 2, 0], -238.41659378201322, -294.9642285461477),
#   ('move', -12, [1, 0, 1], -243.70090943305198, -430.9528862824978),
#   ('move', -12, [1, 2, 0], -237.2702964764826, -294.9642285461477),
#   ('wait', -12, [1, 1, 0], -251.5058474938022, -205.78835142124464),
#   ('wait', -12, [1, 1, 0], -251.5058474938022, -203.18616322796188),
#   ('wait', -12, [1, 1, 0], -251.5058474938022, -202.5227839244742),
#   ('wait', -12, [1, 1, 0], -251.5058474938022, -200.48058052437716),
#   ('wait', -12, [1, 1, 0], -251.5058474938022, -197.88822680222262),
#   ('wait', -12, [1, 1, 0], -251.5058474938022, -195.37286857796983),
#   ('wait', -12, [1, 1, 0], -251.5058474938022, -192.93221900833555),
#   ('wait', -12, [1, 0, 0], -254.629598543158, -176.43197394217043),
#   ('wait', -12, [1, 0, 0], -254.629598543158, -175.1069776607212),
#   ('wait', -12, [1, 0, 0], -254.629598543158, -180.50597779362977),
#   ('wait', -12, [1, 0, 0], -254.629598543158, -179.50190883553654),
#   ('wait', -12, [1, 0, 0], -254.629598543158, -178.51782084970935),
#   ('wait', -12, [1, 0, 0], -254.629598543158, -177.55331621480013),
#   ('wait', -12, [1, 0, 0], -254.629598543158, -176.60800522212563),
#   ('wait', -12, [1, 0, 0], -254.629598543158, -175.68150591820535),
#   ('move', -12, [1, 0, 0], -254.629598543158, -174.77344395043306)],
#  'Train012': [('wait', 0, [1, 0, 0], -246.0608730131937, -207.49398077828332),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -197.32471113428932),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -182.0803302786874),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -179.12254943715575),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -168.64032460518143),
#   ('wait', 0, [1, 0, 0], -250.5799017640052, -166.4411461949915),
#   ('move', 0, [1, 0, 0], -250.5799017640052, -165.99783339596308),
#   ('move', -6, [1, 0, 1], -276.6596278181107, -452.7571024250498),
#   ('move', -6, [1, 2, 0], -262.18255126789245, -299.9913983867555),
#   ('wait', -6, [1, 0, 2], -12652.231447998101, -330.6395025136206),
#   ('wait', -6, [1, 0, 2], -12652.231447998101, -330.6395025136206),
#   ('move', -6, [1, 2, 1], -289.82890112175636, -1338.2685740620523),
#   ('move', -8, [1, 2, 0], -271.910777756308, -294.9642285461477),
#   ('move', -8, [1, 0, 1], -262.4200552863579, -452.7571024250498),
#   ('move', -8, [1, 2, 0], -247.32096836477044, -294.9642285461477),
#   ('move', -8, [1, 0, 1], -255.3666484705385, -452.7571024250498),
#   ('move', -8, [1, 2, 0], -239.5104240708707, -294.9642285461477),
#   ('wait', -8, [1, 0, 0], -254.629598543158, -168.45231886153013),
#   ('wait', -8, [1, 0, 0], -254.629598543158, -173.28226981345134),
#   ('wait', -8, [1, 0, 0], -254.629598543158, -177.44585460994267),
#   ('wait', -8, [1, 0, 0], -254.629598543158, -175.40668210320482),
#   ('wait', -8, [1, 1, 0], -251.5058474938022, -205.78835142124464),
#   ('wait', -8, [1, 1, 0], -251.5058474938022, -204.4304679070322),
#   ('wait', -8, [1, 1, 0], -251.5058474938022, -203.7603878024992),
#   ('wait', -8, [1, 1, 0], -251.5058474938022, -201.69755608522945),
#   ('wait', -8, [1, 1, 0], -251.5058474938022, -199.07901697194205),
#   ('wait', -8, [1, 1, 0], -251.5058474938022, -196.5382510888584),
#   ('wait', -8, [1, 1, 0], -251.5058474938022, -194.07294849326823),
#   ('wait', -8, [1, 0, 0], -254.629598543158, -176.43197394217043),
#   ('wait', -8, [1, 0, 0], -254.629598543158, -176.0676542027487),
#   ('move', -8, [1, 0, 0], -254.629598543158, -174.21034880527284)],
#  'Train013': [('wait', 0, [1, 0, 0], -246.0608730131937, -207.49398077828332),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -195.35146402294643),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -180.2595269759005),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -177.3313239427842),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -166.95392135912962),
#   ('wait', 0, [1, 0, 0], -250.5799017640052, -164.77673473304156),
#   ('wait', 0, [1, 0, 0], -250.5799017640052, -171.95024121512725),
#   ('wait', 0, [1, 0, 0], -253.48140450529996, -166.84314710079673),
#   ('wait', 0, [1, 0, 0], -253.63263055839994, -161.88773878875594),
#   ('wait', 0, [1, 0, 0], -253.63263055839994, -165.62649225842972),
#   ('wait', 0, [1, 0, 0], -253.63263055839994, -162.33052506248697),
#   ('wait', 0, [1, 0, 0], -253.22364152290703, -159.10014761374347),
#   ('wait', 0, [1, 0, 0], -253.22364152290703, -164.54835926090706),
#   ('wait', 0, [1, 0, 0], -253.22364152290703, -162.90287566829798),
#   ('move', 0, [1, 0, 0], -252.71908234638855, -160.06110844249886),
#   ('move', -14, [1, 2, 1], -286.47138257120343, -1338.2685740620523),
#   ('move', -14, [1, 2, 0], -239.5104240708707, -294.9642285461477),
#   ('move', -14, [1, 0, 1], -249.68326777725508, -430.9528862824978),
#   ('move', -14, [1, 2, 0], -238.41659378201322, -294.9642285461477),
#   ('move', -14, [1, 0, 1], -243.70090943305198, -430.9528862824978),
#   ('move', -14, [1, 2, 0], -237.2702964764826, -294.9642285461477),
#   ('move', -14, [1, 0, 1], -244.25264217357886, -430.9528862824978),
#   ('move', -14, [1, 2, 1], -269.5328643902778, -1338.2685740620523),
#   ('wait', -14, [1, 1, 0], -251.5058474938022, -201.69755608522945),
#   ('wait', -14, [1, 1, 0], -251.5058474938022, -199.6757747191334),
#   ('wait', -14, [1, 1, 0], -251.5058474938022, -197.1093445342004),
#   ('wait', -14, [1, 1, 0], -251.5058474938022, -194.61913989219013),
#   ('move', -14, [1, 1, 0], -251.5058474938022, -192.20289681825219)],
#  'Train014': [('wait', 0, [1, 0, 0], -246.0608730131937, -207.49398077828332),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -193.39794938271697),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -178.45693170614152),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -175.55801070335636),
#   ('wait', 0, [1, 0, 0], -240.12924398191984, -165.28438214553833),
#   ('move', 0, [1, 0, 0], -250.5799017640052, -163.12896738571115),
#   ('move', -5, [1, 0, 1], -289.8344098038349, -452.7571024250498),
#   ('move', -5, [1, 2, 0], -263.20353862695833, -299.9913983867555),
#   ('move', -5, [1, 0, 1], -269.8875147994793, -452.7571024250498),
#   ('move', -5, [1, 2, 0], -263.6291938933722, -299.9913983867555),
#   ('move', -5, [1, 0, 1], -267.26971133718985, -452.7571024250498),
#   ('wait', -5, [1, 2, 0], -271.70077012652575, -299.9913983867555),
#   ('move', -5, [1, 2, 0], -271.910777756308, -299.9913983867555),
#   ('wait', -6, [1, 0, 2], -12652.231447998101, -305.16980161897067),
#   ('move', -6, [1, 1, 1], -294.6728164224157, -699.6220610478425),
#   ('move', -7, [1, 2, 0], -246.17729393220642, -294.9642285461477),
#   ('wait', -7, [1, 0, 0], -254.629598543158, -171.66797952129204),
#   ('wait', -7, [1, 0, 0], -254.629598543158, -170.45129972607913),
#   ('wait', -7, [1, 0, 0], -254.629598543158, -167.26779567291481),
#   ('wait', -7, [1, 0, 0], -254.629598543158, -178.53116627266937),
#   ('wait', -7, [1, 0, 0], -254.629598543158, -176.47139606384326),
#   ('wait', -7, [1, 1, 0], -251.5058474938022, -205.78835142124464),
#   ('wait', -7, [1, 1, 0], -251.5058474938022, -205.78835142124464),
#   ('move', -7, [1, 2, 0], -232.6835151820572, -287.7093220579181)]}

# %%
for i in range(9):
    print(index_to_state_vector(i, b=b , l=l, R = R , total_priority = total_priority) , Q_values[i , :])
# Out:
# [1, 0, 0] [-254.62959854 -184.36481016]
# [1, 1, 0] [-251.50584749 -191.67455561]
# [1, 2, 0] [-226.82854205 -287.70932206]
# [1, 0, 1] [-245.48533575 -430.95288628]
# [1, 1, 1] [-288.06149123 -699.62206105]
# [1, 2, 1] [ -262.132358   -1338.26857406]
# [1, 0, 2] [-12652.231448     -305.30410059]
# [1, 1, 2] [-15164.2573021    -365.10496063]
# [1, 2, 2] [-14892.1412829   -1635.08300925]

# %%
# Out:
# 0

# %%
for t in trains:
    t.print_details()
# Out:
# **************************************************
# Train ID : 8
# Name :Train001
# Priority : 1
# Average speed : 1
# Route of the train
#             Alpha : 0 - 1
#             Bravo : 2 - 3
#             Charlie : 4 - 5
#             Delta : 6 - 7
#             Echo : 8 - 9
# Train has completed the journey
# ______Printing log________
#             Alpha : 117 176
#             Bravo : 177 178
#             Charlie : 179 180
#             Delta : 181 182
#             Echo : 183 184
# **************************************************
# **************************************************
# Train ID : 8
# Name :Train002
# Priority : 1
# Average speed : 1
# Route of the train
#             Alpha : 0 - 1
#             Bravo : 2 - 3
#             Charlie : 4 - 5
#             Delta : 6 - 7
#             Echo : 8 - 9
# Train not yet started
# **************************************************
# **************************************************
# Train ID : 8
# Name :Train003
# Priority : 1
# Average speed : 1
# Route of the train
#             Alpha : 0 - 1
#             Bravo : 2 - 3
#             Charlie : 4 - 5
#             Delta : 6 - 7
#             Echo : 8 - 9
# Train has completed the journey
# ______Printing log________
#             Alpha : 125 223
#             Bravo : 224 225
#             Charlie : 226 227
#             Delta : 228 229
#             Echo : 230 231
# **************************************************
# **************************************************
# Train ID : 8
# Name :Train004
# Priority : 1
# Average speed : 1
# Route of the train
#             Alpha : 0 - 1
#             Bravo : 2 - 3
#             Charlie : 4 - 5
#             Delta : 6 - 7
#             Echo : 8 - 9
# Train has completed the journey
# ______Printing log________
#             Alpha : 177 231
#             Bravo : 232 233
#             Charlie : 234 236
#             Delta : 237 238
#             Echo : 239 240
# **************************************************
# **************************************************
# Train ID : 8
# Name :Train011
# Priority : 1
# Average speed : 1
# Route of the train
#             Echo : 0 - 1
#             Delta : 2 - 3
#             Charlie : 4 - 5
#             Bravo : 6 - 7
#             Alpha : 8 - 9
# Train has completed the journey
# ______Printing log________
#             Echo : 277 278
#             Delta : 279 280
#             Charlie : 281 282
#             Bravo : 283 284
#             Alpha : 285 286
# **************************************************
# **************************************************
# Train ID : 8
# Name :Train012
# Priority : 1
# Average speed : 1
# Route of the train
#             Echo : 0 - 1
#             Delta : 2 - 3
#             Charlie : 4 - 5
#             Bravo : 6 - 7
#             Alpha : 8 - 9
# Train has completed the journey
# ______Printing log________
#             Echo : 17 217
#             Delta : 218 219
#             Charlie : 220 221
#             Bravo : 222 224
#             Alpha : 225 226
# **************************************************
# **************************************************
# Train ID : 8
# Name :Train013
# Priority : 1
# Average speed : 1
# Route of the train
#             Echo : 0 - 1
#             Delta : 2 - 3
#             Charlie : 4 - 5
#             Bravo : 6 - 7
#             Alpha : 8 - 9
# Train not yet started
# **************************************************
# **************************************************
# Train ID : 8
# Name :Train014
# Priority : 1
# Average speed : 1
# Route of the train
#             Echo : 0 - 1
#             Delta : 2 - 3
#             Charlie : 4 - 5
#             Bravo : 6 - 7
#             Alpha : 8 - 9
# Train has completed the journey
# ______Printing log________
#             Echo : 122 231
#             Delta : 232 233
#             Charlie : 234 235
#             Bravo : 236 237
#             Alpha : 238 239
# **************************************************

# %% [markdown]
# # Resource Usage

# %%
G,train_nodes , station_nodes , track_nodes = create_resource_usage_graph(trains , N)

# %%
fig = plt.figure(figsize = (6 , 6))
ax = fig.add_subplot(111)
draw_network_usage_graph(G,train_nodes , station_nodes , track_nodes, N,ax)
# Out:
# <img src="data:image/png;base64,..." width="600">
# /home/arpit/anaconda3/envs/IA/lib/python3.7/site-packages/networkx/drawing/layout.py:950: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   pos = np.row_stack((pos[x] for x in node_list))

# %% [markdown]
# # TODO
#
# 1. Create a simple train class with all the parameters                                                Done
# 2. Implement the resource facility with the track and the station                                     Done
# 3. Run the single train on the track (without getting worried wether the resource is free or not)     Done
# 4. Simulate whole thing on graph (single train only)                                                  Done
# 5. Run multiple instances of the train without worrying about the deadlock                            Done
#    Create action for each train                                                                       Done
# 6. Try to simulate as you want to do in the project i.e. take action from the user.                   Done
#    Also able to order the train for which to take the action at a particular time
#
#
#
# 7. Try to create deadlock with the trains                                                             Done
# 8. Create the graph for resource usage.                                                               Done
# 9. Use the standard deadlock detection algorithm for the detection of the algorithm                   Done
#    Implement the Bank's algorithm for deadlock detection.

# %% [markdown]
# # List of reasons of creating events
# 1. If a train is standing at a station, the event processing time            Can be done by implementing timeout if train arrive early before depart time
#     corresponds to the earliest time at which the train can depart,          occupancy of next track.
#     as defined by its minimum halt time at the station and by any           Done
#     departure time constraints enforced for passenger convenience.
#
# 2. `If it is running between two stations, the event processing time         Already done
#     corresponds to the earliest time at which it can arrive at the          occupancy of next station if move.
#     next station, as defined by the length of the track and the train       Done
#     running speed.
#
# 3. If the train is yet to start, the event processing                       Done
#     time is the time at which it is expected at the starting station.

# %% [markdown]
# # TODO
#
# Create the actions properly and implement deadlock Avoidance heuristic
#
# 1. Code the proper list of events. All the three listed above.                                      Done
# 2. Create the proper time table with arrival and departure time of each train at each station.      Done
# 3. Create separate log file for each train.                                                         Done
# 3. Run simulation with the first toy environment (as in the paper).                                 Done
# 4. Label the current set of implementation under Simulation Phase.                                  Done
# 5. Implement the actions properly without actually waiting for the resource.                        Done
# 6. Understand Heuristic that can be used to avoid deadlock.                                         Done
# 7. Move that train that occupies the most congested resource first and then other.                  Done
#    If tie break it using priority of each train.
#
#
# 8. Implement the state vector when action need to be taken.                                       Note Done

# %% [markdown]
# # TODO
# 1. Implement the function to compute J      $\;\;\;\;\;\;\;\;\;\;\;$   Done
# 2. Implement the state space i.e. when taking action train should know what is the state space
# 3. Implement Proxy reward.
# 4. Implement the Q-learning algo given in the paper
# 5. Check for the first test case

# %%
# Each wait is accumulating too much reward
