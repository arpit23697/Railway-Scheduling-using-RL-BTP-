# %%
import config
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib
import random
import time
from network import *
from utility import *
from train import *
import simpy
import logging
import math
import copy

# %%
# %matplotlib notebook
plt.ion()

# %%
env = simpy.Environment()

# %%
N = Network(config.STATIONS_FILENAME, config.RAILWAY_FILENAME , env)

# %%
def create_statistic_proc(env , logger , stat_time , N , trains):
    '''
    Create statistic in the log file every stat_time
    @parameters:
    env : simpy environment
    logger : log file where need to create the log
    stat_time : time after which log is to be created
    N         : network
    trains    : trains in the network
    '''
    while True :
        yield env.timeout(20)

        #create statistics
        not_yet_started = 0
        running = 0
        Completed_resource_not_freed = 0
        Completed = 0

        for t in trains:
            status = t.status()
            if (status == 'not_yet_started'):
                not_yet_started += 1
            elif (status == 'running'):
                running += 1
            elif(status == 'Completed_resource_not_freed'):
                Completed_resource_not_freed += 1
            else:
                Completed += 1
        
        if (len(trains) == Completed):
            config.TRAINS_COMPLETED_JOURNEY = True

        logger.info("Time : {} Number of trains not yet started - {}".format(env.now , not_yet_started))
        logger.info("Time : {} Number of running trains - {}".format(env.now , running))
        logger.info("Time : {} Number of trains Completed but resource not freed - {}".format(env.now , Completed_resource_not_freed))
        logger.info("Time : {} Number of trains which have Completed journey - {}".format(env.now , Completed))

# %%
#utility function
def update_graph (env , interval , train_to_color = None):
    '''
    This function will simulate the whole process on a GUI
    This function is going to be used as the process
    @parameters
    env : simpy environment
    total_time : total time for the simulation
    '''
    fig = plt.figure(figsize = (6 , 6))
    ax = fig.add_subplot(111)
    fig.show()
    fig.canvas.draw()
    
    while True:
        #Draw graph
        
        N.draw_railway_network(ax  = ax , suppress_station_info= False , 
                               suppress_track_info= False , suppress_edge_label=False , 
                               train_to_color=train_to_color)


        #yield interval time
        yield env.timeout(interval)
        time.sleep(0.5)
        
        #log info
        plt.title("Time {}".format(env.now))
        
        #Paint the canvas
        fig.canvas.draw()

# %%
def deadlock_detection_process (env , deadlock_time):
    '''
    For creating deadlock detection process
    '''
    global DEADLOCK
    while True:
        
        #Invoke this deadlock process after every 20 iterations
        
        yield env.timeout(deadlock_time)
        logger.info("Time : {} Checking Deadlock".format(env.now))
        config.DEADLOCK , _ = deadlock_detection(N , trains)

# %%
def compute_loss_one_train (t):
    '''
    This function should be called after the successful completion of the train
    @Parameter : Name of the train 
    @Return : Loss for the train  
    '''
    p = t.priority
    loss = 0
    
    #for each station in the path
    for route , log in zip(t.route , t.log):
        d , t1 , t2 = route
        _ , t3 , t4 = log
        
        #Compute the loss, for the arrival (may arrive before the assigned time)
        #and departure (always after the assigned time)
        if t3 >= t1:
            loss += (t3 - t1)
        if (t4 >= t2):
            loss += (t4 - t2)

    return loss / p

# %%
def compute_loss (trains):
    '''
    Takes all the trains in the network after completing the journey and then computes the value of J
    '''
    total_loss = 0
    total_departures = 0

    #for each train compute the loss, and return the total loss
    for t in trains:
        total_departures += 2*len(t.route)
        total_loss += compute_loss_one_train(t)
        
    total_loss = total_loss / total_departures
    return total_loss

# %%
def get_state_vector (train_name , b = 2 , l= 6 , R = 3 , w_c = 1 , w_d = 1):
    #get the train
    t = name_train_map[train_name]
    
    #find the current position 
    current = t.current_index * 2;
    if (not t.station_or_not):
        current += 1
            
    #get the local neighbors
    res =t.all_resources[ max(0 , current - b) : min(current + l+1 , len(t.all_resources )) ]
    state_vector = [0 for _ in range(len(res))]
    res_to_index = {}
    for i in range(len(res)):
        res_to_index[res[i]] = i

    #position of the train in the local space
    if (t.current == '_'):
        t1_pos = 0 
    else:
        t1_pos = res_to_index[t.current]
    

    #go through each local resource
    for t2_pos , r in enumerate(res):
        #check if the resource is station or track and get the corresponding details
        if type(r) is not str:
            s = N.get_track_details(r[0],r[1])

        else:
            s = N.get_station_details(r)
        
        towards = 0                                          #train converging towards the given train  
        away = 0                                             #trains diverging from the given train
        total = len(s.train_running)                         #total number of trains
        
        #for each train in one of the local resource 
        for running_train in s.train_running:

            if not running_train == '_':
                
                #find the next position of the train and depict wether it is moving towards or away from the resource
                t2 = name_train_map[running_train]
                index = t2.current_index * 2 
                if not (t2.station_or_not):
                    index += 1
                
                #if train is not at the last destination
                if ( index + 1 < len(t2.all_resources) ):
                    #get the next resource and find it's position
                    next_res = t2.all_resources[index + 1]
                    
                    #depending on the position, check if the train is toward or away from the current trian.
                    if next_res in res_to_index:
                        t2_next_pos = res_to_index[t2.all_resources[index + 1]]
                        if abs(t2_next_pos - t1_pos) < abs(t2_pos - t1_pos):
                            towards+=1
                        else:
                            away+=1

                    elif type(next_res) is not str and (next_res[1] , next_res[0]) in res_to_index:
                        t2_next_pos = res_to_index[(next_res[1] , next_res[0]) ]
                        if abs(t2_next_pos - t1_pos) < abs(t2_pos - t1_pos):
                            towards+=1
                        else:
                            away+=1

                    else :
                        away+=1
                else :
                    away+=1
                    
        #construct the state vector
        state_vector[t2_pos] = int(R - 1 - min (R-1 , math.floor(total - w_c * towards - w_d * away)))
    
    #make it equal to the size of the state vector
    if (current - b < 0):
        temp_list = [0] * abs(current-b)
        temp_list.extend(state_vector)
        state_vector = temp_list

    if (current + l + 1 > len(t.all_resources)):
        state_vector.extend([0] * (current + l + 1 - len(t.all_resources)) )
        
    #include the priority of the train in the state vector
    state_vector.insert(0 , t.priority)
    
    return state_vector

# %%
def state_vector_to_index (state_vector , b = 2 , l = 6 , total_priority = 3 , R = 3):
    '''
    This function takes the state vector and convert it into index used for storing purpose
    state vector is a list
    '''
    temp = 1
    ans = 0
    for i in range(1 , len(state_vector)):
        ans += temp * state_vector[i]
        temp *= R
        
    x = R ** (l + b + 1)
    return ans + (state_vector[0]-1) * x

# %%
def index_to_state_vector (index , b = 2 , l = 6 , R = 3 , total_priority = 3):
    '''
    Given th index , it returns the state vector
    '''
    state_vector = [0]
    x = R ** (l + b + 1)
    state_vector[0] = index//x + 1
    index = index % x
    
    while index:
        index, r = divmod(index, 3)
        state_vector.append(r)
        
    state_vector.extend( [0] * (l + b + 2 - len(state_vector)) )
    return state_vector

# %%
trains = read_trains(config.TRAINS_FILENAME , N , env)

# %%
name_train_map = {}                #Map from train name to train object; note key can be changed to train_id 
for t in trains:
    name_train_map[t.name] = t

# %%
#Define a map from train to color to which it belongs 
#Note this feature considers only 10 trains into account
colors = ['red' , 'saddlebrown' , 'forestgreen','dimgray' , 'darkcyan' , 'royalblue' , 'magenta' , 'darkorange' ] 
permanent_color = 'lightcoral'

train_to_color = {}
if (len(trains) <= 8):
    for i,t in enumerate(trains):
        train_to_color[t.name] = colors[i]
else:
    for i,t in enumerate(trains):
        train_to_color[t.name] = permanent_color
        
print(train_to_color)
# Out:
# {'Train001': 'red', 'Train002': 'saddlebrown', 'Train003': 'forestgreen', 'Train004': 'dimgray', 'Train011': 'darkcyan', 'Train012': 'royalblue', 'Train013': 'magenta', 'Train014': 'darkorange'}

# %%
logger = setup_logger("main_log_file" ,"Logs/log.log")

# %% [markdown]
# # Simulation and Algorithm

# %%
#hyperparameters
pho = 0.25
minimum_J = 1000000
total_priority = 3
R = 3
l = 1
b = 1
w_c = 1
w_d = 1
total_episodes = 100
w = 0.25

tau = 0.9
alpha = 0.1

EPS_START = 1.0
EPS_END = 0.1
EPS_STEPS = 300

gamma = 0.9

CURRENT_EPISODE = 0
TERMINATE = False

TOTAL_STEPS = 0

# %%
#Variables
total_states = total_priority * (R ** (l + b + 1))

#map for the train most recent state space
train_state_space_map = {} 
train_action_terminated = {}
reward_for_train = {}

for key , value in  name_train_map.items():
    train_state_space_map[key] = '-'
    train_action_terminated[key] = False
    reward_for_train[key] = []
#for the Q-values
Q_values = np.zeros((total_states , 2))
Q_values_100 = None

# %%
def epsilon_greedy (state_space , epsilon = None):
    '''
    Given the state space, pick the action according to epsilon-greedy policy.    
    '''
   #given the state space, it will select the action according to epsilon greedy policy
    actions = ['move' , 'wait']
    
    #compute epsilon
    if (epsilon is None):
        if (CURRENT_EPISODE > EPS_STEPS):
            epsilon = EPS_END
        else:
            epsilon = ((EPS_END - EPS_START) / EPS_STEPS) * CURRENT_EPISODE + EPS_START
        
    #check if the action is random or greedy
    random = np.random.choice([True , False ] , 1 , p = [epsilon , 1 - epsilon])

    #pick the action at random
    if (random):
        action = np.random.choice(actions , 1 , p = [0.5 , 0.5])
        return action[0]
    else:
        
        #pick the action greedily
        if (Q_values_100 is None):
            q_1 = Q_values[state_vector_to_index(state_space) , 0]
            q_2 = Q_values[state_vector_to_index(state_space) , 1]
        else:
            q_1 = Q_values_100[state_vector_to_index(state_space) , 0]
            q_2 = Q_values_100[state_vector_to_index(state_space) , 1]
        
        if (q_1 >= q_2):
            return 'move'
        else:
            return 'wait'

# %%
def get_reward (train):
    #get the status of the train
    status = train.status()
    if (status == 'not_yet_started'):
        return 0

    else:
        #if the train is on the station, take the departure time
        current_index = train.current_index

        if (train.station_or_not):
            return min(0,-(train.log[current_index][1] - train.route[current_index][1]))
        else:
            return min(0,-(train.log[current_index][2] - train.route[current_index][2]))

# %%
total_reward = []
INVALID_MOVES = 0

# %%
def choose_action_algo (env ,N ,name_train_map):
    
    '''
    This function will choose the action for the trains that need action at the
    particular simulation time
    
    This will also check if the move is valid or not.
    '''
    
    actions = ['move' , 'wait']
    
    global TERMINATE , TOTAL_STEPS , total_reward , INVALID_MOVES
    
    while True :
        #This line is extremely important
        #As this line will wait for all the events upto this current simulation point to complete first
        #and then this will execute
        for _ in range(4*len(name_train_map)):
            yield env.timeout(0)
        
        #Check if the trains need action
        if (len(config.TRAINS_NEEDING_ACTION) == 0):
            yield env.timeout(1)
        
        else:
            
            #Pick the train that needs the action most
            time ,name = pick_most_suitable_action(name_train_map , N , env)
            t = name_train_map[name]

            #construct the state vector
            state_vector = get_state_vector(name , b = b , l = l , R = R , w_c = w_c , w_d = w_d)
            action = epsilon_greedy(state_vector , epsilon = 0.01 )
            
            action_index = 0
            if action == 'wait':
                action_index = 1
                
            if action == 'move' and not (t.is_move_valid(env)):
                INVALID_MOVES += 1
                TERMINATE = True
            else:
                TERMINATE = False
            
            reward = get_reward(t)

            if not (train_state_space_map[name] == '-'):
                #computing the Q_values
                if (train_action_terminated[name] == True):
                    reward = -100
                    
                reward_for_train[name].append((action , reward , state_vector 
                                               , Q_values[state_vector_to_index(state_vector) , 0]
                                               , Q_values[state_vector_to_index(state_vector) , 1]))
                    
                total_reward.append(reward)
                #update the Q-values
                prev_state_vector , prev_action = train_state_space_map[name]
                Q_t1 = Q_values[state_vector_to_index(prev_state_vector) , prev_action]
                Q_t2 = Q_values[state_vector_to_index(state_vector) , action_index]
                Q_t1 = Q_t1 +  alpha * ((reward + gamma * Q_t2  - Q_t1))
                Q_values[state_vector_to_index(prev_state_vector) , prev_action] = Q_t1
                
            
            train_state_space_map[name] = (state_vector , action_index)
            TOTAL_STEPS += 1
            if (TERMINATE):
                train_action_terminated[name] = True
                continue
            else:
                train_action_terminated[name] = False
                
                

            env.process(t.act_simulate(env , action))
            
            config.TRAINS_NEEDING_ACTION.remove((time,  name) )

# %%
# sim_proc = env.process(update_graph(env , 1 , train_to_color =train_to_color))
def start_episode():
    '''
    Reset everything at the start of the episode
    '''
    env = simpy.Environment()
    N.reset(env)
    for t in trains:
        t.reset(env , N)
    
        
    dead_proc = env.process(deadlock_detection_process(env , 20))
    stat_proc = env.process(create_statistic_proc(env , logger , 20 , N , trains))

    for t in trains:
        proc = env.process(t.put_train_on_track(env))

    proc_act = env.process(choose_action_algo(env , N, name_train_map))
    return env,N

# %%
#For plotting and storing info
J_plot = []
minimum_J_plot = []

#for logging about the total success, deadlock and completed episodes
total_deadlock = 0
completed_episodes = 0
terminated = 0

#Run for the required number of episodes
for episode in range(total_episodes):

    #reset the episode
    INVALID_MOVES = 0
    config.TRAINS_NEEDING_ACTION = []
    total_reward = []
    TOTAL_STEPS = 0
    env , N = start_episode()    
    config.DEADLOCK = True
    config.TRAINS_COMPLETED_JOURNEY = False
    config.CURRENT_SIMULATION_TIME = 0
    
    for key , value in reward_for_train.items():
        reward_for_train[key] = []
    
    TERMINATE = False
    CURRENT_EPISODE += 1

    #mark the seen to all zero for the current episode
    seen = np.zeros((total_states , 2))
    
    #This loop is not needed as such
    for time in range(0 , config.TOTAL_SIMULATION_TIME , 1):
            
        if (config.DEADLOCK== False):
            logger.warning("Time : {} Terminating Simulation. Deadlock detected".format(env.now))
#             print("Terminating Simulation : Deadlock detected")
            total_deadlock += 1 
            
            break

        if (config.TRAINS_COMPLETED_JOURNEY == True):
            logger.info("Time : {} All trains completed journey. Terminating Simulation".format(env.now))
            #print("Terminating Simulation : All trains completed journey")
            break

        config.CURRENT_SIMULATION_TIME += 1

        #Run the simulation
        env.run(until = config.CURRENT_SIMULATION_TIME)

    
    if (config.TRAINS_COMPLETED_JOURNEY):
        completed_episodes += 1
        J = compute_loss(trains)
        J_plot.append(J)
        minimum_J = min(J , minimum_J)
        minimum_J_plot.append(minimum_J)
        
    if (config.DEADLOCK == False):
        print("Episode : {} Ended in deadlock".format(episode))
    else:
        print('*' * 50)
        print ("Episode : {} , J : {:.5f} , total_time {} , total_deadlock - {}".format( episode ,J , 
                                                        config.CURRENT_SIMULATION_TIME,  total_deadlock ))

        reward_sum = np.sum(np.array(total_reward))
        temp = (reward_sum + INVALID_MOVES * 100)/(TOTAL_STEPS - INVALID_MOVES)
        print("Episode : {} Total reward {} , total_steps {}, average reward {:.2f} , invalid_moves {} , reward_step {:.2f}".format(
        episode, reward_sum , TOTAL_STEPS , reward_sum/TOTAL_STEPS, INVALID_MOVES , temp )   )
    
    
    
    
    if (episode == 900):
        Q_values_100 = copy.deepcopy(Q_values)
# Out:
# **************************************************
# Episode : 0 , J : 12.00000 , total_time 41 , total_deadlock - 0
# Episode : 0 Total reward -2440 , total_steps 220, average reward -11.09 , invalid_moves 11 , reward_step -6.41
# **************************************************
# Episode : 1 , J : 17.95000 , total_time 61 , total_deadlock - 0
# Episode : 1 Total reward -7322 , total_steps 340, average reward -21.54 , invalid_moves 41 , reward_step -10.78
# **************************************************
# Episode : 2 , J : 19.31250 , total_time 61 , total_deadlock - 0
# Episode : 2 Total reward -9013 , total_steps 400, average reward -22.53 , invalid_moves 41 , reward_step -13.69
# **************************************************
# Episode : 3 , J : 11.50000 , total_time 61 , total_deadlock - 0
# Episode : 3 Total reward -3511 , total_steps 242, average reward -14.51 , invalid_moves 14 , reward_step -9.26
# **************************************************
# Episode : 4 , J : 13.63750 , total_time 41 , total_deadlock - 0
# Episode : 4 Total reward -4661 , total_steps 257, average reward -18.14 , invalid_moves 27 , reward_step -8.53
# **************************************************
# Episode : 5 , J : 8.46250 , total_time 41 , total_deadlock - 0
# Episode : 5 Total reward -1967 , total_steps 185, average reward -10.63 , invalid_moves 9 , reward_step -6.06
# **************************************************
# Episode : 6 , J : 19.30000 , total_time 61 , total_deadlock - 0
# Episode : 6 Total reward -7848 , total_steps 370, average reward -21.21 , invalid_moves 39 , reward_step -11.93
# **************************************************
# Episode : 7 , J : 13.45000 , total_time 41 , total_deadlock - 0
# Episode : 7 Total reward -4313 , total_steps 260, average reward -16.59 , invalid_moves 22 , reward_step -8.88
# **************************************************
# Episode : 8 , J : 13.18750 , total_time 61 , total_deadlock - 0
# Episode : 8 Total reward -4710 , total_steps 297, average reward -15.86 , invalid_moves 18 , reward_step -10.43
# **************************************************
# Episode : 9 , J : 20.61250 , total_time 61 , total_deadlock - 0
# Episode : 9 Total reward -8468 , total_steps 386, average reward -21.94 , invalid_moves 45 , reward_step -11.64
# **************************************************
# Episode : 10 , J : 11.78750 , total_time 61 , total_deadlock - 0
# Episode : 10 Total reward -3875 , total_steps 256, average reward -15.14 , invalid_moves 17 , reward_step -9.10
# **************************************************
# Episode : 11 , J : 21.32500 , total_time 61 , total_deadlock - 0
# Episode : 11 Total reward -8366 , total_steps 389, average reward -21.51 , invalid_moves 29 , reward_step -15.18
# **************************************************
# Episode : 12 , J : 12.66250 , total_time 61 , total_deadlock - 0
# Episode : 12 Total reward -3128 , total_steps 225, average reward -13.90 , invalid_moves 14 , reward_step -8.19
# Episode : 13 Ended in deadlock
# **************************************************
# Episode : 14 , J : 11.32500 , total_time 41 , total_deadlock - 1
# Episode : 14 Total reward -4545 , total_steps 257, average reward -17.68 , invalid_moves 27 , reward_step -8.02
# **************************************************
# Episode : 15 , J : 14.61250 , total_time 61 , total_deadlock - 1
# Episode : 15 Total reward -5212 , total_steps 282, average reward -18.48 , invalid_moves 30 , reward_step -8.78
# **************************************************
# Episode : 16 , J : 16.37500 , total_time 61 , total_deadlock - 1
# Episode : 16 Total reward -6366 , total_steps 314, average reward -20.27 , invalid_moves 32 , reward_step -11.23
# **************************************************
# Episode : 17 , J : 10.88750 , total_time 41 , total_deadlock - 1
# Episode : 17 Total reward -2326 , total_steps 207, average reward -11.24 , invalid_moves 8 , reward_step -7.67
# **************************************************
# Episode : 18 , J : 9.52500 , total_time 41 , total_deadlock - 1
# Episode : 18 Total reward -1863 , total_steps 197, average reward -9.46 , invalid_moves 6 , reward_step -6.61
# **************************************************
# Episode : 19 , J : 14.28750 , total_time 61 , total_deadlock - 1
# Episode : 19 Total reward -6170 , total_steps 317, average reward -19.46 , invalid_moves 30 , reward_step -11.05
# **************************************************
# Episode : 20 , J : 7.21250 , total_time 41 , total_deadlock - 1
# Episode : 20 Total reward -2471 , total_steps 183, average reward -13.50 , invalid_moves 16 , reward_step -5.22
# **************************************************
# Episode : 21 , J : 12.82500 , total_time 41 , total_deadlock - 1
# Episode : 21 Total reward -4807 , total_steps 281, average reward -17.11 , invalid_moves 26 , reward_step -8.65
# **************************************************
# Episode : 22 , J : 14.66250 , total_time 61 , total_deadlock - 1
# Episode : 22 Total reward -5489 , total_steps 298, average reward -18.42 , invalid_moves 28 , reward_step -9.96
# Episode : 23 Ended in deadlock
# **************************************************
# Episode : 24 , J : 16.76250 , total_time 61 , total_deadlock - 2
# Episode : 24 Total reward -5755 , total_steps 300, average reward -19.18 , invalid_moves 30 , reward_step -10.20
# **************************************************
# Episode : 25 , J : 23.72500 , total_time 61 , total_deadlock - 2
# Episode : 25 Total reward -8767 , total_steps 392, average reward -22.36 , invalid_moves 35 , reward_step -14.75
# **************************************************
# Episode : 26 , J : 15.50000 , total_time 61 , total_deadlock - 2
# Episode : 26 Total reward -5136 , total_steps 284, average reward -18.08 , invalid_moves 32 , reward_step -7.68
# **************************************************
# Episode : 27 , J : 14.32500 , total_time 61 , total_deadlock - 2
# Episode : 27 Total reward -5298 , total_steps 304, average reward -17.43 , invalid_moves 24 , reward_step -10.35
# **************************************************
# Episode : 28 , J : 13.48750 , total_time 61 , total_deadlock - 2
# Episode : 28 Total reward -4018 , total_steps 263, average reward -15.28 , invalid_moves 16 , reward_step -9.79
# **************************************************
# Episode : 29 , J : 20.36250 , total_time 81 , total_deadlock - 2
# Episode : 29 Total reward -7334 , total_steps 359, average reward -20.43 , invalid_moves 32 , reward_step -12.64
# **************************************************
# Episode : 30 , J : 15.27500 , total_time 61 , total_deadlock - 2
# Episode : 30 Total reward -6481 , total_steps 330, average reward -19.64 , invalid_moves 32 , reward_step -11.01
# **************************************************
# Episode : 31 , J : 17.01250 , total_time 61 , total_deadlock - 2
# Episode : 31 Total reward -5605 , total_steps 294, average reward -19.06 , invalid_moves 20 , reward_step -13.16
# **************************************************
# Episode : 32 , J : 8.85000 , total_time 41 , total_deadlock - 2
# Episode : 32 Total reward -1455 , total_steps 180, average reward -8.08 , invalid_moves 5 , reward_step -5.46
# **************************************************
# Episode : 33 , J : 10.16250 , total_time 41 , total_deadlock - 2
# Episode : 33 Total reward -3799 , total_steps 214, average reward -17.75 , invalid_moves 25 , reward_step -6.87
# **************************************************
# Episode : 34 , J : 16.13750 , total_time 61 , total_deadlock - 2
# Episode : 34 Total reward -5324 , total_steps 325, average reward -16.38 , invalid_moves 19 , reward_step -11.19
# **************************************************
# Episode : 35 , J : 14.22500 , total_time 41 , total_deadlock - 2
# Episode : 35 Total reward -5346 , total_steps 290, average reward -18.43 , invalid_moves 27 , reward_step -10.06
# **************************************************
# Episode : 36 , J : 18.61250 , total_time 61 , total_deadlock - 2
# Episode : 36 Total reward -8594 , total_steps 371, average reward -23.16 , invalid_moves 42 , reward_step -13.36
# **************************************************
# Episode : 37 , J : 10.85000 , total_time 41 , total_deadlock - 2
# Episode : 37 Total reward -2192 , total_steps 219, average reward -10.01 , invalid_moves 6 , reward_step -7.47
# **************************************************
# Episode : 38 , J : 10.35000 , total_time 41 , total_deadlock - 2
# Episode : 38 Total reward -3310 , total_steps 206, average reward -16.07 , invalid_moves 22 , reward_step -6.03
# **************************************************
# Episode : 39 , J : 10.22500 , total_time 61 , total_deadlock - 2
# Episode : 39 Total reward -3623 , total_steps 233, average reward -15.55 , invalid_moves 20 , reward_step -7.62
# **************************************************
# Episode : 40 , J : 13.91250 , total_time 61 , total_deadlock - 2
# Episode : 40 Total reward -5013 , total_steps 277, average reward -18.10 , invalid_moves 27 , reward_step -9.25
# **************************************************
# Episode : 41 , J : 14.45000 , total_time 61 , total_deadlock - 2
# Episode : 41 Total reward -4246 , total_steps 270, average reward -15.73 , invalid_moves 18 , reward_step -9.71
# **************************************************
# Episode : 42 , J : 11.75000 , total_time 41 , total_deadlock - 2
# Episode : 42 Total reward -2449 , total_steps 217, average reward -11.29 , invalid_moves 11 , reward_step -6.55
# **************************************************
# Episode : 43 , J : 15.35000 , total_time 61 , total_deadlock - 2
# Episode : 43 Total reward -7042 , total_steps 326, average reward -21.60 , invalid_moves 37 , reward_step -11.56
# **************************************************
# Episode : 44 , J : 7.36250 , total_time 41 , total_deadlock - 2
# Episode : 44 Total reward -1078 , total_steps 162, average reward -6.65 , invalid_moves 3 , reward_step -4.89
# **************************************************
# Episode : 45 , J : 16.43750 , total_time 61 , total_deadlock - 2
# Episode : 45 Total reward -5836 , total_steps 303, average reward -19.26 , invalid_moves 26 , reward_step -11.68
# **************************************************
# Episode : 46 , J : 17.71250 , total_time 61 , total_deadlock - 2
# Episode : 46 Total reward -4962 , total_steps 289, average reward -17.17 , invalid_moves 20 , reward_step -11.01
# **************************************************
# Episode : 47 , J : 12.50000 , total_time 41 , total_deadlock - 2
# Episode : 47 Total reward -4935 , total_steps 273, average reward -18.08 , invalid_moves 28 , reward_step -8.71
# **************************************************
# Episode : 48 , J : 12.91250 , total_time 61 , total_deadlock - 2
# Episode : 48 Total reward -4965 , total_steps 265, average reward -18.74 , invalid_moves 25 , reward_step -10.27
# **************************************************
# Episode : 49 , J : 23.02500 , total_time 61 , total_deadlock - 2
# Episode : 49 Total reward -8910 , total_steps 398, average reward -22.39 , invalid_moves 39 , reward_step -13.96
# **************************************************
# Episode : 50 , J : 6.47500 , total_time 41 , total_deadlock - 2
# Episode : 50 Total reward -830 , total_steps 147, average reward -5.65 , invalid_moves 2 , reward_step -4.34
# **************************************************
# Episode : 51 , J : 8.73750 , total_time 41 , total_deadlock - 2
# Episode : 51 Total reward -1372 , total_steps 174, average reward -7.89 , invalid_moves 4 , reward_step -5.72
# **************************************************
# Episode : 52 , J : 12.98750 , total_time 61 , total_deadlock - 2
# Episode : 52 Total reward -4788 , total_steps 268, average reward -17.87 , invalid_moves 24 , reward_step -9.79
# **************************************************
# Episode : 53 , J : 14.65000 , total_time 61 , total_deadlock - 2
# Episode : 53 Total reward -6137 , total_steps 296, average reward -20.73 , invalid_moves 37 , reward_step -9.41
# **************************************************
# Episode : 54 , J : 10.85000 , total_time 41 , total_deadlock - 2
# Episode : 54 Total reward -1842 , total_steps 198, average reward -9.30 , invalid_moves 5 , reward_step -6.95
# **************************************************
# Episode : 55 , J : 13.73750 , total_time 61 , total_deadlock - 2
# Episode : 55 Total reward -5725 , total_steps 278, average reward -20.59 , invalid_moves 34 , reward_step -9.53
# **************************************************
# Episode : 56 , J : 28.22500 , total_time 81 , total_deadlock - 2
# Episode : 56 Total reward -14351 , total_steps 490, average reward -29.29 , invalid_moves 68 , reward_step -17.89
# **************************************************
# Episode : 57 , J : 17.21250 , total_time 61 , total_deadlock - 2
# Episode : 57 Total reward -5816 , total_steps 302, average reward -19.26 , invalid_moves 29 , reward_step -10.68
# **************************************************
# Episode : 58 , J : 14.97500 , total_time 61 , total_deadlock - 2
# Episode : 58 Total reward -4584 , total_steps 291, average reward -15.75 , invalid_moves 18 , reward_step -10.20
# **************************************************
# Episode : 59 , J : 14.66250 , total_time 61 , total_deadlock - 2
# Episode : 59 Total reward -6644 , total_steps 324, average reward -20.51 , invalid_moves 32 , reward_step -11.79
# **************************************************
# Episode : 60 , J : 12.71250 , total_time 41 , total_deadlock - 2
# Episode : 60 Total reward -4189 , total_steps 259, average reward -16.17 , invalid_moves 20 , reward_step -9.16
# **************************************************
# Episode : 61 , J : 9.13750 , total_time 41 , total_deadlock - 2
# Episode : 61 Total reward -1284 , total_steps 187, average reward -6.87 , invalid_moves 1 , reward_step -6.37
# **************************************************
# Episode : 62 , J : 11.20000 , total_time 41 , total_deadlock - 2
# Episode : 62 Total reward -4116 , total_steps 248, average reward -16.60 , invalid_moves 22 , reward_step -8.48
# **************************************************
# Episode : 63 , J : 15.55000 , total_time 61 , total_deadlock - 2
# Episode : 63 Total reward -4902 , total_steps 303, average reward -16.18 , invalid_moves 19 , reward_step -10.57
# **************************************************
# Episode : 64 , J : 15.12500 , total_time 61 , total_deadlock - 2
# Episode : 64 Total reward -5278 , total_steps 301, average reward -17.53 , invalid_moves 25 , reward_step -10.07
# **************************************************
# Episode : 65 , J : 16.92500 , total_time 61 , total_deadlock - 2
# Episode : 65 Total reward -7357 , total_steps 341, average reward -21.57 , invalid_moves 39 , reward_step -11.45
# **************************************************
# Episode : 66 , J : 8.65000 , total_time 41 , total_deadlock - 2
# Episode : 66 Total reward -1990 , total_steps 185, average reward -10.76 , invalid_moves 10 , reward_step -5.66
# **************************************************
# Episode : 67 , J : 8.17500 , total_time 41 , total_deadlock - 2
# Episode : 67 Total reward -1353 , total_steps 173, average reward -7.82 , invalid_moves 4 , reward_step -5.64
# **************************************************
# Episode : 68 , J : 16.40000 , total_time 61 , total_deadlock - 2
# Episode : 68 Total reward -7369 , total_steps 321, average reward -22.96 , invalid_moves 43 , reward_step -11.04
# **************************************************
# Episode : 69 , J : 16.72500 , total_time 61 , total_deadlock - 2
# Episode : 69 Total reward -7317 , total_steps 339, average reward -21.58 , invalid_moves 39 , reward_step -11.39
# **************************************************
# Episode : 70 , J : 18.41250 , total_time 61 , total_deadlock - 2
# Episode : 70 Total reward -9271 , total_steps 374, average reward -24.79 , invalid_moves 52 , reward_step -12.64
# **************************************************
# Episode : 71 , J : 9.45000 , total_time 41 , total_deadlock - 2
# Episode : 71 Total reward -2100 , total_steps 207, average reward -10.14 , invalid_moves 8 , reward_step -6.53
# **************************************************
# Episode : 72 , J : 15.63750 , total_time 61 , total_deadlock - 2
# Episode : 72 Total reward -5979 , total_steps 318, average reward -18.80 , invalid_moves 33 , reward_step -9.40
# **************************************************
# Episode : 73 , J : 13.48750 , total_time 41 , total_deadlock - 2
# Episode : 73 Total reward -3744 , total_steps 254, average reward -14.74 , invalid_moves 14 , reward_step -9.77
# **************************************************
# Episode : 74 , J : 19.56250 , total_time 61 , total_deadlock - 2
# Episode : 74 Total reward -4545 , total_steps 314, average reward -14.47 , invalid_moves 15 , reward_step -10.18
# **************************************************
# Episode : 75 , J : 18.01250 , total_time 61 , total_deadlock - 2
# Episode : 75 Total reward -6958 , total_steps 337, average reward -20.65 , invalid_moves 39 , reward_step -10.26
# **************************************************
# Episode : 76 , J : 11.47500 , total_time 61 , total_deadlock - 2
# Episode : 76 Total reward -4065 , total_steps 254, average reward -16.00 , invalid_moves 19 , reward_step -9.21
# **************************************************
# Episode : 77 , J : 18.97500 , total_time 61 , total_deadlock - 2
# Episode : 77 Total reward -7329 , total_steps 348, average reward -21.06 , invalid_moves 39 , reward_step -11.10
# **************************************************
# Episode : 78 , J : 11.51250 , total_time 41 , total_deadlock - 2
# Episode : 78 Total reward -1597 , total_steps 200, average reward -7.99 , invalid_moves 2 , reward_step -7.06
# **************************************************
# Episode : 79 , J : 17.45000 , total_time 61 , total_deadlock - 2
# Episode : 79 Total reward -5806 , total_steps 316, average reward -18.37 , invalid_moves 24 , reward_step -11.66
# **************************************************
# Episode : 80 , J : 16.25000 , total_time 61 , total_deadlock - 2
# Episode : 80 Total reward -4758 , total_steps 293, average reward -16.24 , invalid_moves 19 , reward_step -10.43
# **************************************************
# Episode : 81 , J : 22.82500 , total_time 81 , total_deadlock - 2
# Episode : 81 Total reward -7554 , total_steps 361, average reward -20.93 , invalid_moves 29 , reward_step -14.02
# **************************************************
# Episode : 82 , J : 8.88750 , total_time 41 , total_deadlock - 2
# Episode : 82 Total reward -1519 , total_steps 173, average reward -8.78 , invalid_moves 6 , reward_step -5.50
# **************************************************
# Episode : 83 , J : 12.22500 , total_time 41 , total_deadlock - 2
# Episode : 83 Total reward -1430 , total_steps 196, average reward -7.30 , invalid_moves 0 , reward_step -7.30
# **************************************************
# Episode : 84 , J : 10.70000 , total_time 41 , total_deadlock - 2
# Episode : 84 Total reward -1273 , total_steps 184, average reward -6.92 , invalid_moves 1 , reward_step -6.41
# **************************************************
# Episode : 85 , J : 22.56250 , total_time 61 , total_deadlock - 2
# Episode : 85 Total reward -9266 , total_steps 390, average reward -23.76 , invalid_moves 38 , reward_step -15.53
# **************************************************
# Episode : 86 , J : 13.77500 , total_time 41 , total_deadlock - 2
# Episode : 86 Total reward -6155 , total_steps 289, average reward -21.30 , invalid_moves 37 , reward_step -9.74
# **************************************************
# Episode : 87 , J : 24.11250 , total_time 61 , total_deadlock - 2
# Episode : 87 Total reward -8823 , total_steps 387, average reward -22.80 , invalid_moves 49 , reward_step -11.61
# **************************************************
# Episode : 88 , J : 26.75000 , total_time 81 , total_deadlock - 2
# Episode : 88 Total reward -12263 , total_steps 457, average reward -26.83 , invalid_moves 54 , reward_step -17.03
# **************************************************
# Episode : 89 , J : 16.83750 , total_time 61 , total_deadlock - 2
# Episode : 89 Total reward -4692 , total_steps 296, average reward -15.85 , invalid_moves 14 , reward_step -11.67
# **************************************************
# Episode : 90 , J : 10.37500 , total_time 41 , total_deadlock - 2
# Episode : 90 Total reward -2585 , total_steps 210, average reward -12.31 , invalid_moves 14 , reward_step -6.05
# **************************************************
# Episode : 91 , J : 14.35000 , total_time 41 , total_deadlock - 2
# Episode : 91 Total reward -2333 , total_steps 225, average reward -10.37 , invalid_moves 3 , reward_step -9.16
# **************************************************
# Episode : 92 , J : 13.75000 , total_time 61 , total_deadlock - 2
# Episode : 92 Total reward -5730 , total_steps 287, average reward -19.97 , invalid_moves 27 , reward_step -11.65
# **************************************************
# Episode : 93 , J : 16.73750 , total_time 61 , total_deadlock - 2
# Episode : 93 Total reward -6119 , total_steps 305, average reward -20.06 , invalid_moves 31 , reward_step -11.02
# **************************************************
# Episode : 94 , J : 17.65000 , total_time 61 , total_deadlock - 2
# Episode : 94 Total reward -5592 , total_steps 310, average reward -18.04 , invalid_moves 21 , reward_step -12.08
# **************************************************
# Episode : 95 , J : 16.58750 , total_time 61 , total_deadlock - 2
# Episode : 95 Total reward -6351 , total_steps 314, average reward -20.23 , invalid_moves 30 , reward_step -11.80
# **************************************************
# Episode : 96 , J : 15.66250 , total_time 61 , total_deadlock - 2
# Episode : 96 Total reward -4170 , total_steps 275, average reward -15.16 , invalid_moves 17 , reward_step -9.57
# **************************************************
# Episode : 97 , J : 11.35000 , total_time 41 , total_deadlock - 2
# Episode : 97 Total reward -4899 , total_steps 270, average reward -18.14 , invalid_moves 28 , reward_step -8.67
# **************************************************
# Episode : 98 , J : 15.62500 , total_time 61 , total_deadlock - 2
# Episode : 98 Total reward -5903 , total_steps 308, average reward -19.17 , invalid_moves 31 , reward_step -10.12
# **************************************************
# Episode : 99 , J : 8.97500 , total_time 41 , total_deadlock - 2
# Episode : 99 Total reward -1613 , total_steps 183, average reward -8.81 , invalid_moves 4 , reward_step -6.78

# %%
reward_for_train
# Out:
# {'Train001': [('move',
#    0,
#    [1, 0, 0, 0],
#    -241.02324930533692,
#    -197.34389115311728),
#   ('wait', 0, [1, 0, 2, 1], -268.0175845691447, -212.43449015567828),
#   ('move', 0, [1, 0, 2, 1], -268.0175845691447, -212.43449015567828),
#   ('wait', -1, [1, 1, 2, 0], -210.49427654667397, -205.06475315344804),
#   ('wait', -1, [1, 1, 2, 0], -208.6347902115888, -205.06475315344804),
#   ('wait', -1, [1, 1, 2, 0], -208.6347902115888, -203.11410562191355),
#   ('wait', -1, [1, 1, 2, 0], -208.6347902115888, -201.18296456569442),
#   ('wait', -1, [1, 1, 2, 0], -208.6347902115888, -199.27113492003747),
#   ('wait', -1, [1, 1, 2, 0], -208.6347902115888, -197.3784235708371),
#   ('wait', -1, [1, 1, 2, 0], -208.6347902115888, -195.50463933512873),
#   ('move', -1, [1, 1, 2, 0], -208.6347902115888, -193.64959294177743),
#   ('wait', -8, [1, 2, 0, 2], -384.98028461049216, -272.0845545001389),
#   ('move', -8, [1, 1, 2, 1], -196.79819849474308, -223.72766796103312),
#   ('wait', -9, [1, 0, 2, 0], -252.88188875837082, -216.9132237436956),
#   ('move', -9, [1, 0, 2, 0], -263.241925497478, -216.9132237436956),
#   ('move', -10, [1, 2, 0, 1], -218.05064392960583, -223.49726627181644),
#   ('move', -10, [1, 0, 2, 0], -250.24000347432914, -223.6432727559056),
#   ('wait', -10, [1, 2, 0, 1], -219.76717984933487, -223.49726627181644),
#   ('move', -10, [1, 2, 0, 1], -219.1183564124329, -223.49726627181644),
#   ('move', -11, [1, 0, 2, 0], -240.81055792606102, -221.8777716280631),
#   ('wait', -11, [1, 1, 0, 0], -202.2639304414288, -185.3085261167905),
#   ('move', -11, [1, 1, 0, 0], -202.2639304414288, -185.3085261167905)],
#  'Train002': [('move',
#    0,
#    [1, 0, 0, 0],
#    -241.02324930533692,
#    -197.34389115311728),
#   ('wait', 0, [1, 0, 2, 1], -268.0175845691447, -212.43449015567828),
#   ('move', 0, [1, 0, 1, 2], -348.2634599646946, -217.70931277203232),
#   ('wait', -100, [1, 0, 1, 2], -348.2634599646946, -217.70931277203232),
#   ('wait', 0, [1, 0, 1, 2], -355.8830689774569, -217.70931277203232),
#   ('wait', 0, [1, 0, 1, 2], -373.30364302966467, -224.0686839110531),
#   ('wait', 0, [1, 0, 1, 2], -373.30364302966467, -217.4136199302109),
#   ('move', 0, [1, 0, 1, 2], -371.8973596483531, -225.37570787690956),
#   ('move', -100, [1, 0, 1, 2], -371.8973596483531, -236.3088994575704),
#   ('move', -100, [1, 0, 1, 2], -378.17838605186955, -236.3088994575704),
#   ('wait', -100, [1, 0, 1, 2], -384.39660219135084, -236.3088994575704),
#   ('move', 0, [1, 0, 1, 2], -371.5073996962395, -244.50145627980098),
#   ('move', -100, [1, 0, 1, 2], -371.5073996962395, -253.48697662448242),
#   ('wait', -100, [1, 0, 1, 2], -377.79232569927706, -253.48697662448242),
#   ('wait', 0, [1, 0, 1, 2], -385.8614729466456, -259.07577483579064),
#   ('move', 0, [1, 0, 1, 2], -387.64508779025607, -274.3034211382799),
#   ('move', -100, [1, 0, 1, 2], -387.64508779025607, -281.76113692557493),
#   ('move', -100, [1, 0, 1, 2], -393.7686369123535, -281.76113692557493),
#   ('wait', -100, [1, 0, 1, 2], -399.83095054322996, -281.76113692557493),
#   ('wait', 0, [1, 0, 1, 1], -200.10154745647114, -227.1441181903948),
#   ('wait', 0, [1, 0, 0, 2], -349.8227332870218, -211.8028826817561),
#   ('move', 0, [1, 0, 0, 2], -349.8227332870218, -209.68485385493855),
#   ('wait', -100, [1, 0, 0, 2], -349.8227332870218, -220.20041446527665),
#   ('move', 0, [1, 0, 0, 2], -352.55778124773997, -229.19963777216648),
#   ('wait', -100, [1, 0, 0, 2], -352.55778124773997, -238.00987430724643),
#   ('move', 0, [1, 0, 1, 1], -200.31677808636826, -223.49196581271337),
#   ('wait', -13, [1, 0, 2, 0], -255.12827280073847, -222.0240804924622),
#   ('move', -13, [1, 0, 2, 0], -250.24000347432914, -222.0240804924622),
#   ('move', -14, [1, 2, 1, 1], -214.04701521833778, -251.49729781839838),
#   ('move', -14, [1, 0, 2, 0], -240.81055792606102, -223.6432727559056),
#   ('wait', -14, [1, 1, 0, 2], -441.98921885109473, -299.2873768516202),
#   ('move', -14, [1, 1, 0, 2], -441.98921885109473, -299.2873768516202),
#   ('wait', -100, [1, 1, 0, 2], -441.98921885109473, -310.5376688630567),
#   ('move', -14, [1, 2, 0, 1], -220.9344740994271, -221.86819172175376),
#   ('wait', -16, [1, 0, 2, 0], -240.41249942307195, -223.87440112945816),
#   ('move', -16, [1, 0, 2, 0], -237.72432453196697, -222.50630054698195),
#   ('move', -17, [1, 1, 0, 1], -229.04162769274842, -239.44228533480083),
#   ('wait', -17, [1, 0, 2, 0], -230.73870238850122, -222.91023664964004),
#   ('wait', -17, [1, 0, 2, 0], -230.1757769096258, -221.98113428314363),
#   ('move', -17, [1, 0, 2, 0], -230.1757769096258, -220.54670971090906),
#   ('move', -19, [1, 1, 0, 0], -202.2639304414288, -186.08142724484003)],
#  'Train003': [('move',
#    0,
#    [1, 0, 0, 0],
#    -241.02324930533692,
#    -197.34389115311728),
#   ('wait', 0, [1, 0, 2, 1], -268.0175845691447, -212.43449015567828),
#   ('move', 0, [1, 0, 1, 2], -343.03095211770807, -217.70931277203232),
#   ('move', -100, [1, 0, 1, 2], -343.03095211770807, -217.70931277203232),
#   ('move', -100, [1, 0, 1, 2], -349.600642596531, -217.70931277203232),
#   ('move', -100, [1, 0, 1, 2], -356.10463617056564, -217.70931277203232),
#   ('wait', -100, [1, 0, 1, 2], -362.54358980885996, -217.70931277203232),
#   ('wait', 0, [1, 0, 1, 2], -355.8830689774569, -215.532219644312),
#   ('wait', 0, [1, 0, 1, 2], -373.30364302966467, -221.82799707194258),
#   ('wait', 0, [1, 0, 1, 2], -373.30364302966467, -215.2394837309088),
#   ('wait', 0, [1, 0, 1, 2], -377.2247429233971, -236.3088994575704),
#   ('move', 0, [1, 0, 1, 2], -372.8269210255528, -253.48697662448242),
#   ('move', -100, [1, 0, 1, 2], -372.8269210255528, -261.69270185433396),
#   ('move', -100, [1, 0, 1, 2], -379.0986518152973, -261.69270185433396),
#   ('move', -100, [1, 0, 1, 2], -385.3076652971443, -261.69270185433396),
#   ('wait', -100, [1, 0, 1, 2], -391.4545886441729, -261.69270185433396),
#   ('move', 0, [1, 0, 1, 2], -385.8614729466456, -256.4850170874327),
#   ('move', -100, [1, 0, 1, 2], -385.8614729466456, -265.56404794388754),
#   ('move', -100, [1, 0, 1, 2], -392.00285821717915, -265.56404794388754),
#   ('wait', -100, [1, 0, 1, 2], -398.0828296350074, -265.56404794388754),
#   ('wait', 0, [1, 0, 1, 2], -395.2063578122087, -281.76113692557493),
#   ('move', 0, [1, 0, 1, 1], -200.10154745647114, -227.1441181903948),
#   ('wait', -9, [1, 0, 2, 0], -237.84694860357342, -214.7265041727136),
#   ('move', -9, [1, 0, 2, 0], -252.88188875837082, -214.7265041727136),
#   ('move', -10, [1, 2, 0, 2], -384.98028461049216, -263.3879369146519),
#   ('move', -100, [1, 2, 0, 2], -384.98028461049216, -263.3879369146519),
#   ('move', -100, [1, 2, 0, 2], -391.13048176438724, -263.3879369146519),
#   ('move', -100, [1, 2, 0, 2], -397.21917694674335, -263.3879369146519),
#   ('move', -100, [1, 2, 0, 2], -403.2469851772759, -263.3879369146519),
#   ('move', -100, [1, 2, 0, 2], -409.21451532550316, -263.3879369146519),
#   ('move', -100, [1, 2, 0, 2], -415.1223701722481, -263.3879369146519),
#   ('wait', -100, [1, 2, 0, 2], -420.97114647052564, -263.3879369146519),
#   ('wait', -10, [1, 2, 0, 2], -412.57894614579175, -263.3879369146519),
#   ('move', -10, [1, 2, 1, 1], -215.31841839476274, -251.49729781839838),
#   ('move', -12, [1, 1, 2, 0], -211.7826518116812, -193.16176476664268),
#   ('move', -12, [1, 2, 0, 1], -219.76717984933487, -223.49726627181644),
#   ('wait', -12, [1, 0, 2, 0], -240.81055792606102, -223.6432727559056),
#   ('wait', -12, [1, 0, 2, 0], -240.81055792606102, -222.90684002834655),
#   ('wait', -12, [1, 0, 2, 0], -238.33659679560182, -224.41894071984476),
#   ('move', -12, [1, 0, 2, 0], -240.41249942307195, -223.3747513126463),
#   ('move', -15, [1, 2, 0, 1], -220.5897227911356, -221.86819172175376),
#   ('wait', -15, [1, 0, 2, 0], -237.72432453196697, -223.2508597001608),
#   ('move', -15, [1, 0, 2, 0], -237.72432453196697, -223.2817052007203),
#   ('wait', -16, [1, 2, 0, 0], -195.67266503342523, -183.32919638328184),
#   ('wait', -16, [1, 2, 0, 0], -195.67266503342523, -183.32919638328184),
#   ('wait', -16, [1, 2, 0, 0], -195.67266503342523, -183.09590441944903),
#   ('wait', -16, [1, 1, 0, 0], -202.2639304414288, -186.08142724484003),
#   ('move', -16, [1, 2, 0, 0], -195.67266503342523, -182.92577928976468)],
#  'Train004': [('move',
#    0,
#    [1, 0, 0, 1],
#    -222.79023424942406,
#    -191.07545956766268),
#   ('wait', 0, [1, 0, 2, 1], -268.0175845691447, -212.43449015567828),
#   ('wait', 0, [1, 0, 1, 2], -355.8830689774569, -217.70931277203232),
#   ('move', 0, [1, 0, 1, 2], -355.8830689774569, -213.37689744786888),
#   ('move', -100, [1, 0, 1, 2], -355.8830689774569, -224.0686839110531),
#   ('move', -100, [1, 0, 1, 2], -362.3242382876823, -224.0686839110531),
#   ('move', -100, [1, 0, 1, 2], -368.7009959048055, -224.0686839110531),
#   ('move', -100, [1, 0, 1, 2], -375.01398594575744, -224.0686839110531),
#   ('wait', -100, [1, 0, 1, 2], -381.26384608629985, -224.0686839110531),
#   ('wait', 0, [1, 0, 1, 2], -373.30364302966467, -219.60971710122314),
#   ('move', 0, [1, 0, 1, 2], -373.30364302966467, -213.0870888935997),
#   ('move', -100, [1, 0, 1, 2], -373.30364302966467, -225.37570787690956),
#   ('wait', -100, [1, 0, 1, 2], -379.57060659936803, -225.37570787690956),
#   ('move', 0, [1, 0, 1, 2], -377.2247429233971, -233.9458104629947),
#   ('wait', -100, [1, 0, 1, 2], -377.2247429233971, -244.50145627980098),
#   ('wait', 0, [1, 0, 1, 2], -385.8614729466456, -261.69270185433396),
#   ('move', 0, [1, 0, 1, 2], -392.1753109864565, -265.56404794388754),
#   ('wait', -100, [1, 0, 1, 2], -392.1753109864565, -274.3034211382799),
#   ('move', 0, [1, 0, 1, 2], -395.2063578122087, -278.9435255563192),
#   ('wait', -100, [1, 0, 1, 2], -395.2063578122087, -286.61774520378606),
#   ('wait', 0, [1, 0, 0, 2], -349.8227332870218, -211.8028826817561),
#   ('wait', 0, [1, 0, 0, 2], -349.8227332870218, -211.8028826817561),
#   ('move', 0, [1, 0, 0, 2], -344.6584972601945, -220.20041446527665),
#   ('move', -100, [1, 0, 0, 2], -344.6584972601945, -229.19963777216648),
#   ('move', -100, [1, 0, 0, 2], -351.21191228759255, -229.19963777216648),
#   ('wait', -100, [1, 0, 0, 2], -357.69979316471665, -229.19963777216648),
#   ('move', 0, [1, 0, 0, 2], -348.72289181061814, -238.00987430724643),
#   ('wait', -100, [1, 0, 0, 2], -348.72289181061814, -245.59394713947742),
#   ('wait', 0, [1, 0, 0, 2], -345.9540578721093, -239.06306245330282),
#   ('move', 0, [1, 0, 0, 2], -345.9540578721093, -236.6724318287698),
#   ('move', -100, [1, 0, 0, 2], -345.9540578721093, -244.14105385438265),
#   ('move', -100, [1, 0, 0, 2], -352.4945172933882, -244.14105385438265),
#   ('move', -100, [1, 0, 0, 2], -358.9695721204543, -244.14105385438265),
#   ('move', -100, [1, 0, 0, 2], -365.3798763992498, -244.14105385438265),
#   ('move', -100, [1, 0, 0, 2], -371.7260776352573, -244.14105385438265),
#   ('move', -100, [1, 0, 0, 2], -378.0088168589047, -244.14105385438265),
#   ('wait', -100, [1, 0, 0, 2], -384.2287286903157, -244.14105385438265),
#   ('move', 0, [1, 0, 0, 1], -217.17323726522096, -191.8031406357158),
#   ('wait', -15, [1, 0, 2, 1], -258.0994028287551, -229.73065421716558),
#   ('wait', -15, [1, 0, 2, 0], -240.81055792606102, -223.6432727559056),
#   ('wait', -15, [1, 0, 2, 0], -240.81055792606102, -223.6432727559056),
#   ('move', -15, [1, 0, 2, 1], -258.0994028287551, -228.38548334348053),
#   ('move', -18, [1, 2, 1, 1], -215.71526390984948, -251.49729781839838),
#   ('wait', -18, [1, 0, 2, 0], -240.41249942307195, -223.87440112945816),
#   ('wait', -18, [1, 0, 2, 0], -237.72432453196697, -222.9356571181636),
#   ('move', -18, [1, 0, 2, 0], -237.72432453196697, -222.3183511031592),
#   ('move', -20, [1, 1, 0, 1], -227.89938622194117, -239.44228533480083),
#   ('wait', -20, [1, 0, 2, 0], -230.1757769096258, -221.4613229403122),
#   ('move', -20, [1, 0, 2, 0], -230.1757769096258, -220.9078586616845),
#   ('move', -21, [1, 1, 0, 1], -227.04096666437516, -239.44228533480083),
#   ('wait', -21, [1, 0, 2, 0], -227.0694446623464, -219.71138815230645),
#   ('move', -21, [1, 0, 2, 0], -227.0694446623464, -219.476499356687),
#   ('wait', -22, [1, 1, 0, 0], -202.2639304414288, -186.6838243733643),
#   ('move', -22, [1, 1, 0, 0], -202.2639304414288, -186.6838243733643)],
#  'Train011': [('wait',
#    0,
#    [1, 0, 0, 0],
#    -241.02324930533692,
#    -197.34389115311728),
#   ('wait', 0, [1, 0, 0, 0], -241.02324930533692, -197.34389115311728),
#   ('move', 0, [1, 0, 0, 0], -221.1959582264762, -197.52549945490784),
#   ('move', -2, [1, 0, 0, 2], -350.9005196663809, -206.04776174924615),
#   ('move', -100, [1, 0, 0, 2], -350.9005196663809, -206.04776174924615),
#   ('move', -100, [1, 0, 0, 2], -357.3915144697171, -206.04776174924615),
#   ('wait', -100, [1, 0, 0, 2], -363.81759932501996, -206.04776174924615),
#   ('wait', -2, [1, 0, 0, 2], -355.9801379499501, -206.04776174924615),
#   ('move', -2, [1, 0, 0, 2], -355.9801379499501, -204.1872841317537),
#   ('wait', -100, [1, 0, 0, 2], -355.9801379499501, -216.00676813407384),
#   ('wait', -2, [1, 0, 0, 1], -218.1691891646598, -191.07545956766268),
#   ('move', -2, [1, 0, 0, 1], -218.1691891646598, -191.07545956766268),
#   ('move', -6, [1, 0, 2, 0], -224.67741130030157, -219.28100230490526),
#   ('move', -6, [1, 1, 0, 1], -230.15049692227572, -222.31608092167318),
#   ('move', -6, [1, 0, 2, 0], -236.73533847444753, -217.38819228185622),
#   ('move', -6, [1, 1, 0, 2], -424.6626112794971, -283.56489432403674),
#   ('wait', -100, [1, 1, 0, 2], -424.6626112794971, -283.56489432403674),
#   ('move', -6, [1, 1, 0, 2], -422.77142237670125, -293.302952049297),
#   ('wait', -100, [1, 1, 0, 2], -422.77142237670125, -302.6220848582704),
#   ('wait', -6, [1, 1, 0, 2], -413.89824504115563, -310.45560047230816),
#   ('wait', -6, [1, 1, 0, 2], -413.89824504115563, -297.9609917175191),
#   ('move', -6, [1, 1, 0, 2], -413.89824504115563, -295.58138180034393),
#   ('move', -100, [1, 1, 0, 2], -413.89824504115563, -303.87408567401354),
#   ('move', -100, [1, 1, 0, 2], -419.7592625907441, -303.87408567401354),
#   ('move', -100, [1, 1, 0, 2], -425.56166996483665, -303.87408567401354),
#   ('move', -100, [1, 1, 0, 2], -431.30605326518827, -303.87408567401354),
#   ('wait', -100, [1, 1, 0, 2], -436.9929927325364, -303.87408567401354),
#   ('wait', -6, [1, 1, 0, 1], -229.04162769274842, -222.31608092167318),
#   ('move', -6, [1, 1, 0, 2], -430.64236116994397, -294.0951243895628),
#   ('move', -100, [1, 1, 0, 2], -430.64236116994397, -294.0951243895628),
#   ('move', -100, [1, 1, 0, 2], -436.33593755824455, -294.0951243895628),
#   ('move', -100, [1, 1, 0, 2], -441.9725781826621, -294.0951243895628),
#   ('move', -100, [1, 1, 0, 2], -447.5528524008355, -294.0951243895628),
#   ('move', -100, [1, 1, 0, 2], -453.0773238768271, -294.0951243895628),
#   ('wait', -100, [1, 1, 0, 2], -458.5465506380588, -294.0951243895628),
#   ('move', -6, [1, 2, 0, 1], -219.1183564124329, -223.49726627181644),
#   ('move', -13, [1, 0, 2, 0], -240.81055792606102, -221.8777716280631),
#   ('wait', -13, [1, 1, 1, 2], -403.79762011986975, -273.4395811892255),
#   ('wait', -13, [1, 1, 1, 2], -403.79762011986975, -273.4395811892255),
#   ('wait', -13, [1, 2, 0, 2], -410.3441684498747, -272.3510524562449),
#   ('move', -13, [1, 2, 0, 2], -404.74797461828706, -282.6469223711091),
#   ('wait', -100, [1, 2, 0, 2], -404.74797461828706, -292.109547849644),
#   ('wait', -13, [1, 1, 0, 2], -435.73868716366036, -300.7680046456995),
#   ('wait', -13, [1, 1, 0, 2], -430.1105101896216, -310.50768602585896),
#   ('wait', -13, [1, 1, 0, 2], -430.1105101896216, -306.2155830739444),
#   ('wait', -13, [1, 1, 0, 2], -425.29808190989496, -313.3180304359504),
#   ('move', -13, [1, 1, 0, 2], -425.29808190989496, -308.97000163027496),
#   ('wait', -100, [1, 1, 0, 2], -425.29808190989496, -317.649828839138),
#   ('move', -13, [1, 1, 0, 2], -428.78120881989076, -324.40695420352273),
#   ('move', -100, [1, 1, 0, 2], -428.78120881989076, -331.85656757696063),
#   ('wait', -100, [1, 1, 0, 2], -434.49339673169186, -331.85656757696063),
#   ('move', -13, [1, 1, 0, 1], -226.2108949316452, -239.44228533480083),
#   ('move', -23, [1, 0, 2, 0], -219.72478249257432, -220.06509944062947),
#   ('wait', -23, [1, 2, 0, 0], -195.67266503342523, -183.29652149686703),
#   ('wait', -23, [1, 1, 0, 0], -202.2639304414288, -188.41919567575647),
#   ('wait', -23, [1, 1, 0, 0], -202.2639304414288, -188.41919567575647),
#   ('wait', -23, [1, 1, 0, 0], -202.2639304414288, -188.8350037189989),
#   ('wait', -23, [1, 1, 0, 0], -202.2639304414288, -189.2466536818089),
#   ('wait', -23, [1, 1, 0, 0], -202.2639304414288, -189.65418714499083),
#   ('move', -23, [1, 1, 0, 0], -202.2639304414288, -190.0576452735409)],
#  'Train012': [('move',
#    0,
#    [1, 0, 0, 0],
#    -241.02324930533692,
#    -197.34389115311728),
#   ('wait', 0, [1, 0, 1, 1], -200.8980050050673, -232.40708460550698),
#   ('move', 0, [1, 0, 1, 1], -199.75268939376122, -232.40708460550698),
#   ('move', -1, [1, 0, 2, 0], -224.71252224540052, -225.5767302224043),
#   ('wait', -1, [1, 2, 0, 1], -222.11223696460937, -211.08935451540452),
#   ('move', -1, [1, 2, 0, 2], -382.48664355783774, -279.8298355606523),
#   ('move', -100, [1, 2, 0, 2], -382.48664355783774, -279.8298355606523),
#   ('wait', -100, [1, 2, 0, 2], -388.66177712225937, -279.8298355606523),
#   ('wait', -1, [1, 1, 0, 2], -431.9718180497228, -295.90294881068314),
#   ('move', -1, [1, 1, 0, 1], -235.9057013680585, -222.31608092167318),
#   ('move', -4, [1, 0, 2, 0], -224.67741130030157, -219.28100230490526),
#   ('move', -4, [1, 1, 0, 2], -431.9718180497228, -287.6441670527401),
#   ('wait', -100, [1, 1, 0, 2], -431.9718180497228, -287.6441670527401),
#   ('wait', -4, [1, 1, 1, 2], -393.4031672853254, -269.83493307300705),
#   ('move', -4, [1, 1, 1, 1], -224.03581852018021, -246.1458600291663),
#   ('move', -6, [1, 0, 2, 1], -259.7716538960405, -229.73065421716558),
#   ('wait', -6, [1, 2, 0, 2], -412.57894614579175, -263.3879369146519),
#   ('move', -6, [1, 2, 0, 2], -412.57894614579175, -261.75405754550536),
#   ('move', -100, [1, 2, 0, 2], -412.57894614579175, -273.3107569440761),
#   ('wait', -100, [1, 2, 0, 2], -418.4531566843338, -273.3107569440761),
#   ('move', -6, [1, 2, 0, 2], -411.20580914086725, -266.3583389051971),
#   ('move', -100, [1, 2, 0, 2], -411.20580914086725, -277.33102783735546),
#   ('wait', -100, [1, 2, 0, 2], -417.09375104945855, -277.33102783735546),
#   ('wait', -6, [1, 1, 1, 1], -226.91206151899172, -246.1458600291663),
#   ('wait', -6, [1, 1, 1, 2], -393.4031672853254, -263.0940375784336),
#   ('move', -6, [1, 1, 0, 2], -449.1604567693136, -294.0951243895628),
#   ('move', -100, [1, 1, 0, 2], -449.1604567693136, -294.0951243895628),
#   ('move', -100, [1, 1, 0, 2], -454.6688522016205, -294.0951243895628),
#   ('wait', -100, [1, 1, 0, 2], -460.1221636796043, -294.0951243895628),
#   ('move', -6, [1, 1, 1, 2], -393.4031672853254, -291.480233202449),
#   ('wait', -100, [1, 1, 1, 2], -393.4031672853254, -291.480233202449),
#   ('wait', -6, [1, 1, 2, 1], -197.54056878220138, -223.72766796103312),
#   ('wait', -6, [1, 1, 1, 2], -403.79762011986975, -273.4395811892255),
#   ('wait', -6, [1, 2, 0, 2], -410.3441684498747, -272.3510524562449),
#   ('move', -6, [1, 2, 0, 2], -410.3441684498747, -272.3510524562449),
#   ('wait', -100, [1, 2, 0, 2], -410.3441684498747, -282.6469223711091),
#   ('wait', -6, [1, 1, 0, 2], -435.73868716366036, -300.7680046456995),
#   ('move', -6, [1, 1, 0, 2], -435.73868716366036, -300.7680046456995),
#   ('wait', -100, [1, 1, 0, 2], -435.73868716366036, -310.50768602585896),
#   ('wait', -6, [1, 1, 0, 2], -430.1105101896216, -308.7026091656004),
#   ('move', -6, [1, 1, 0, 2], -430.1105101896216, -304.45342724320494),
#   ('wait', -100, [1, 1, 0, 2], -430.1105101896216, -313.3180304359504),
#   ('wait', -6, [1, 1, 0, 2], -425.29808190989496, -311.48485013159086),
#   ('move', -6, [1, 1, 0, 2], -421.3567583144279, -317.649828839138),
#   ('move', -100, [1, 1, 0, 2], -421.3567583144279, -324.40695420352273),
#   ('move', -100, [1, 1, 0, 2], -427.14319073128365, -324.40695420352273),
#   ('wait', -100, [1, 1, 0, 2], -432.8717588239708, -324.40695420352273),
#   ('wait', -6, [1, 1, 0, 1], -226.2108949316452, -239.44228533480083),
#   ('move', -6, [1, 1, 0, 1], -225.66503586281237, -239.44228533480083),
#   ('move', -24, [1, 0, 2, 0], -216.54899117803492, -220.06509944062947),
#   ('move', -24, [1, 1, 0, 0], -202.2639304414288, -188.41919567575647)],
#  'Train013': [('move',
#    0,
#    [1, 0, 0, 0],
#    -241.02324930533692,
#    -197.34389115311728),
#   ('move', 0, [1, 0, 1, 1], -200.8980050050673, -232.40708460550698),
#   ('move', 0, [1, 1, 2, 0], -210.49427654667397, -205.06475315344804),
#   ('wait', 0, [1, 2, 0, 1], -222.11223696460937, -213.22157021758034),
#   ('wait', 0, [1, 2, 0, 1], -222.11223696460937, -213.22157021758034),
#   ('move', 0, [1, 2, 0, 1], -222.11223696460937, -211.08935451540452),
#   ('wait', -2, [1, 0, 2, 0], -221.33931192724688, -221.28940470161447),
#   ('move', -2, [1, 0, 2, 0], -221.33931192724688, -221.28940470161447),
#   ('move', -3, [1, 2, 0, 1], -220.01705969129372, -223.49726627181644),
#   ('wait', -3, [1, 0, 2, 0], -222.31120554248784, -219.28100230490526),
#   ('wait', -3, [1, 0, 2, 0], -236.73533847444753, -219.28100230490526),
#   ('move', -3, [1, 1, 2, 0], -208.6347902115888, -193.16176476664268),
#   ('move', -5, [1, 2, 1, 1], -216.99580917536682, -251.49729781839838),
#   ('wait', -5, [1, 0, 2, 0], -252.88188875837082, -216.9132237436956),
#   ('move', -5, [1, 0, 2, 0], -263.241925497478, -219.81367466409907),
#   ('move', -6, [1, 2, 0, 0], -195.67266503342523, -183.32919638328184)],
#  'Train014': [('wait',
#    0,
#    [1, 0, 0, 0],
#    -241.02324930533692,
#    -197.34389115311728),
#   ('move', 0, [1, 0, 0, 0], -241.02324930533692, -195.37045224158612),
#   ('wait', -1, [1, 0, 0, 2], -350.9005196663809, -206.867814894202),
#   ('move', -1, [1, 0, 0, 1], -219.6303149384927, -191.07545956766268),
#   ('wait', -2, [1, 0, 2, 0], -224.71252224540052, -225.5767302224043),
#   ('wait', -2, [1, 0, 2, 0], -221.33931192724688, -225.5767302224043),
#   ('move', -2, [1, 0, 2, 0], -221.33931192724688, -223.52096292018027),
#   ('wait', -4, [1, 2, 0, 2], -384.98028461049216, -278.57811739754857),
#   ('move', -4, [1, 1, 0, 1], -232.9360982482798, -222.31608092167318),
#   ('move', -5, [1, 0, 2, 0], -222.31120554248784, -219.28100230490526),
#   ('wait', -5, [1, 1, 1, 2], -393.4031672853254, -269.83493307300705),
#   ('wait', -5, [1, 1, 0, 2], -424.6626112794971, -283.56489432403674),
#   ('move', -5, [1, 1, 0, 2], -417.7171906407107, -283.56489432403674),
#   ('move', -100, [1, 1, 0, 2], -417.7171906407107, -293.302952049297),
#   ('move', -100, [1, 1, 0, 2], -423.5400187343036, -293.302952049297),
#   ('wait', -100, [1, 1, 0, 2], -429.30461854696057, -293.302952049297),
#   ('move', -5, [1, 1, 0, 2], -417.73026777627547, -302.6220848582704),
#   ('wait', -100, [1, 1, 0, 2], -417.73026777627547, -310.45560047230816),
#   ('move', -5, [1, 1, 1, 1], -225.61168551880584, -246.1458600291663),
#   ('move', -9, [1, 0, 2, 0], -255.12827280073847, -222.0240804924622),
#   ('wait', -9, [1, 1, 1, 1], -226.91206151899172, -246.1458600291663),
#   ('wait', -9, [1, 1, 1, 2], -393.4031672853254, -263.0940375784336),
#   ('move', -9, [1, 1, 0, 2], -450.5785085067045, -294.0951243895628),
#   ('wait', -100, [1, 1, 0, 2], -450.5785085067045, -294.0951243895628),
#   ('move', -9, [1, 1, 1, 2], -390.2960715450133, -291.480233202449),
#   ('move', -100, [1, 1, 1, 2], -390.2960715450133, -291.480233202449),
#   ('move', -100, [1, 1, 1, 2], -396.39311082956317, -291.480233202449),
#   ('move', -100, [1, 1, 1, 2], -402.42917972126753, -291.480233202449),
#   ('wait', -100, [1, 1, 1, 2], -408.40488792405483, -291.480233202449),
#   ('move', -9, [1, 1, 2, 1], -197.54056878220138, -223.72766796103312),
#   ('wait', -13, [1, 1, 2, 0], -211.58343281695323, -193.16176476664268),
#   ('wait', -13, [1, 0, 2, 0], -240.41249942307195, -223.87440112945816),
#   ('wait', -13, [1, 0, 2, 0], -237.72432453196697, -223.87440112945816),
#   ('wait', -13, [1, 0, 2, 0], -237.72432453196697, -223.2508597001608),
#   ('wait', -13, [1, 0, 2, 0], -230.73870238850122, -223.84872388852529),
#   ('wait', -13, [1, 0, 2, 0], -230.1757769096258, -222.91023664964004),
#   ('wait', -13, [1, 0, 2, 0], -230.1757769096258, -221.4613229403122),
#   ('wait', -13, [1, 0, 2, 0], -227.26195295839182, -221.53289271738237),
#   ('wait', -13, [1, 0, 2, 0], -227.0694446623464, -220.61756379020855),
#   ('move', -13, [1, 0, 2, 0], -227.0694446623464, -219.71138815230645),
#   ('wait', -22, [1, 2, 0, 0], -195.67266503342523, -182.92577928976468),
#   ('wait', -22, [1, 2, 0, 0], -195.67266503342523, -182.92577928976468),
#   ('move', -22, [1, 1, 1, 0], -56.68520418362, -17.259594017644087)]}

# %%
for i in range(9):
    print(index_to_state_vector(i, b=b , l=l, R = R , total_priority = total_priority) , Q_values[i , :])

# %%
for t in trains:
    t.print_details()

# %% [markdown]
# # Resource Usage

# %%
G,train_nodes , station_nodes , track_nodes = create_resource_usage_graph(trains , N)

# %%
fig = plt.figure(figsize = (6 , 6))
ax = fig.add_subplot(111)
draw_network_usage_graph(G,train_nodes , station_nodes , track_nodes, N,ax)
# Out:
# <img src="data:image/png;base64,..." width="600">
# /home/arpit/anaconda3/envs/IA/lib/python3.7/site-packages/networkx/drawing/layout.py:950: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   pos = np.row_stack((pos[x] for x in node_list))

# %% [markdown]
# # TODO
#
# 1. Create a simple train class with all the parameters                                                Done
# 2. Implement the resource facility with the track and the station                                     Done
# 3. Run the single train on the track (without getting worried wether the resource is free or not)     Done
# 4. Simulate whole thing on graph (single train only)                                                  Done
# 5. Run multiple instances of the train without worrying about the deadlock                            Done
#    Create action for each train                                                                       Done
# 6. Try to simulate as you want to do in the project i.e. take action from the user.                   Done
#    Also able to order the train for which to take the action at a particular time
#
#
#
# 7. Try to create deadlock with the trains                                                             Done
# 8. Create the graph for resource usage.                                                               Done
# 9. Use the standard deadlock detection algorithm for the detection of the algorithm                   Done
#    Implement the Bank's algorithm for deadlock detection.

# %% [markdown]
# # List of reasons of creating events
# 1. If a train is standing at a station, the event processing time            Can be done by implementing timeout if train arrive early before depart time
#     corresponds to the earliest time at which the train can depart,          occupancy of next track.
#     as defined by its minimum halt time at the station and by any           Done
#     departure time constraints enforced for passenger convenience.
#
# 2. `If it is running between two stations, the event processing time         Already done
#     corresponds to the earliest time at which it can arrive at the          occupancy of next station if move.
#     next station, as defined by the length of the track and the train       Done
#     running speed.
#
# 3. If the train is yet to start, the event processing                       Done
#     time is the time at which it is expected at the starting station.

# %% [markdown]
# # TODO
#
# Create the actions properly and implement deadlock Avoidance heuristic
#
# 1. Code the proper list of events. All the three listed above.                                      Done
# 2. Create the proper time table with arrival and departure time of each train at each station.      Done
# 3. Create separate log file for each train.                                                         Done
# 3. Run simulation with the first toy environment (as in the paper).                                 Done
# 4. Label the current set of implementation under Simulation Phase.                                  Done
# 5. Implement the actions properly without actually waiting for the resource.                        Done
# 6. Understand Heuristic that can be used to avoid deadlock.                                         Done
# 7. Move that train that occupies the most congested resource first and then other.                  Done
#    If tie break it using priority of each train.
#
#
# 8. Implement the state vector when action need to be taken.                                       Note Done

# %% [markdown]
# # TODO
# 1. Implement the function to compute J      $\;\;\;\;\;\;\;\;\;\;\;$   Done
# 2. Implement the state space i.e. when taking action train should know what is the state space
# 3. Implement Proxy reward.
# 4. Implement the Q-learning algo given in the paper
# 5. Check for the first test case

# %%
# Each wait is accumulating too much reward
