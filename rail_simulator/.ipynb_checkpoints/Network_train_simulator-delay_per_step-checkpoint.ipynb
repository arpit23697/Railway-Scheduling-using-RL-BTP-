# %%
import config
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib
import random
import time
from network import *
from utility import *
from train import *
import simpy
import logging
import math
import copy

# %%
# %matplotlib notebook
plt.ion()

# %%
env = simpy.Environment()

# %%
N = Network(config.STATIONS_FILENAME, config.RAILWAY_FILENAME , env)

# %%
def create_statistic_proc(env , logger , stat_time , N , trains):
    '''
    Create statistic in the log file every stat_time
    @parameters:
    env : simpy environment
    logger : log file where need to create the log
    stat_time : time after which log is to be created
    N         : network
    trains    : trains in the network
    '''
    while True :
        yield env.timeout(20)

        #create statistics
        not_yet_started = 0
        running = 0
        Completed_resource_not_freed = 0
        Completed = 0

        for t in trains:
            status = t.status()
            if (status == 'not_yet_started'):
                not_yet_started += 1
            elif (status == 'running'):
                running += 1
            elif(status == 'Completed_resource_not_freed'):
                Completed_resource_not_freed += 1
            else:
                Completed += 1
        
        if (len(trains) == Completed):
            config.TRAINS_COMPLETED_JOURNEY = True

        logger.info("Time : {} Number of trains not yet started - {}".format(env.now , not_yet_started))
        logger.info("Time : {} Number of running trains - {}".format(env.now , running))
        logger.info("Time : {} Number of trains Completed but resource not freed - {}".format(env.now , Completed_resource_not_freed))
        logger.info("Time : {} Number of trains which have Completed journey - {}".format(env.now , Completed))

# %%
#utility function
def update_graph (env , interval , train_to_color = None):
    '''
    This function will simulate the whole process on a GUI
    This function is going to be used as the process
    @parameters
    env : simpy environment
    total_time : total time for the simulation
    '''
    fig = plt.figure(figsize = (6 , 6))
    ax = fig.add_subplot(111)
    fig.show()
    fig.canvas.draw()
    
    while True:
        #Draw graph
        
        N.draw_railway_network(ax  = ax , suppress_station_info= False , 
                               suppress_track_info= False , suppress_edge_label=False , 
                               train_to_color=train_to_color)


        #yield interval time
        yield env.timeout(interval)
        time.sleep(0.5)
        
        #log info
        plt.title("Time {}".format(env.now))
        
        #Paint the canvas
        fig.canvas.draw()

# %%
def deadlock_detection_process (env , deadlock_time):
    '''
    For creating deadlock detection process
    '''
    global DEADLOCK
    while True:
        
        #Invoke this deadlock process after every 20 iterations
        
        yield env.timeout(deadlock_time)
        logger.info("Time : {} Checking Deadlock".format(env.now))
        config.DEADLOCK , _ = deadlock_detection(N , trains)

# %%
def compute_loss_one_train (t):
    '''
    This function should be called after the successful completion of the train
    @Parameter : Name of the train 
    @Return : Loss for the train  
    '''
    p = t.priority
    loss = 0
    
    #for each station in the path
    for route , log in zip(t.route , t.log):
        d , t1 , t2 = route
        _ , t3 , t4 = log
        
        #Compute the loss, for the arrival (may arrive before the assigned time)
        #and departure (always after the assigned time)
        if t3 >= t1:
            loss += (t3 - t1)
        if (t4 >= t2):
            loss += (t4 - t2)

    return loss / p

# %%
def compute_loss (trains):
    '''
    Takes all the trains in the network after completing the journey and then computes the value of J
    '''
    total_loss = 0
    total_departures = 0

    #for each train compute the loss, and return the total loss
    for t in trains:
        total_departures += 2*len(t.route)
        total_loss += compute_loss_one_train(t)
        
    total_loss = total_loss / total_departures
    return total_loss

# %%
def get_state_vector (train_name , b = 2 , l= 6 , R = 3 , w_c = 1 , w_d = 1):
    #get the train
    t = name_train_map[train_name]
    
    #find the current position 
    current = t.current_index * 2;
    if (not t.station_or_not):
        current += 1
            
    #get the local neighbors
    res =t.all_resources[ max(0 , current - b) : min(current + l+1 , len(t.all_resources )) ]
    state_vector = [0 for _ in range(len(res))]
    res_to_index = {}
    for i in range(len(res)):
        res_to_index[res[i]] = i

    #position of the train in the local space
    if (t.current == '_'):
        t1_pos = 0 
    else:
        t1_pos = res_to_index[t.current]
    

    #go through each local resource
    for t2_pos , r in enumerate(res):
        #check if the resource is station or track and get the corresponding details
        if type(r) is not str:
            s = N.get_track_details(r[0],r[1])

        else:
            s = N.get_station_details(r)
        
        towards = 0                                          #train converging towards the given train  
        away = 0                                             #trains diverging from the given train
        total = len(s.train_running)                         #total number of trains
        
        #for each train in one of the local resource 
        for running_train in s.train_running:

            if not running_train == '_':
                
                #find the next position of the train and depict wether it is moving towards or away from the resource
                t2 = name_train_map[running_train]
                index = t2.current_index * 2 
                if not (t2.station_or_not):
                    index += 1
                
                #if train is not at the last destination
                if ( index + 1 < len(t2.all_resources) ):
                    #get the next resource and find it's position
                    next_res = t2.all_resources[index + 1]
                    
                    #depending on the position, check if the train is toward or away from the current trian.
                    if next_res in res_to_index:
                        t2_next_pos = res_to_index[t2.all_resources[index + 1]]
                        if abs(t2_next_pos - t1_pos) < abs(t2_pos - t1_pos):
                            towards+=1
                        else:
                            away+=1

                    elif type(next_res) is not str and (next_res[1] , next_res[0]) in res_to_index:
                        t2_next_pos = res_to_index[(next_res[1] , next_res[0]) ]
                        if abs(t2_next_pos - t1_pos) < abs(t2_pos - t1_pos):
                            towards+=1
                        else:
                            away+=1

                    else :
                        away+=1
                else :
                    away+=1
                    
        #construct the state vector
        state_vector[t2_pos] = int(R - 1 - min (R-1 , math.floor(total - w_c * towards - w_d * away)))
    
    #make it equal to the size of the state vector
    if (current - b < 0):
        temp_list = [0] * abs(current-b)
        temp_list.extend(state_vector)
        state_vector = temp_list

    if (current + l + 1 > len(t.all_resources)):
        state_vector.extend([0] * (current + l + 1 - len(t.all_resources)) )
        
    #include the priority of the train in the state vector
    state_vector.insert(0 , t.priority)
    
    return state_vector

# %%
def state_vector_to_index (state_vector , b = 2 , l = 6 , total_priority = 3 , R = 3):
    '''
    This function takes the state vector and convert it into index used for storing purpose
    state vector is a list
    '''
    temp = 1
    ans = 0
    for i in range(1 , len(state_vector)):
        ans += temp * state_vector[i]
        temp *= R
        
    x = R ** (l + b + 1)
    return ans + (state_vector[0]-1) * x

# %%
def index_to_state_vector (index , b = 2 , l = 6 , R = 3 , total_priority = 3):
    '''
    Given th index , it returns the state vector
    '''
    state_vector = [0]
    x = R ** (l + b + 1)
    state_vector[0] = index//x + 1
    index = index % x
    
    while index:
        index, r = divmod(index, 3)
        state_vector.append(r)
        
    state_vector.extend( [0] * (l + b + 2 - len(state_vector)) )
    return state_vector

# %%
trains = read_trains(config.TRAINS_FILENAME , N , env)

# %%
name_train_map = {}                #Map from train name to train object; note key can be changed to train_id 
for t in trains:
    name_train_map[t.name] = t

# %%
#Define a map from train to color to which it belongs 
#Note this feature considers only 10 trains into account
colors = ['red' , 'saddlebrown' , 'forestgreen','dimgray' , 'darkcyan' , 'royalblue' , 'magenta' , 'darkorange' ] 
permanent_color = 'lightcoral'

train_to_color = {}
if (len(trains) <= 8):
    for i,t in enumerate(trains):
        train_to_color[t.name] = colors[i]
else:
    for i,t in enumerate(trains):
        train_to_color[t.name] = permanent_color
        
print(train_to_color)
# Out:
# {'Train001': 'red', 'Train002': 'saddlebrown', 'Train003': 'forestgreen', 'Train004': 'dimgray', 'Train011': 'darkcyan', 'Train012': 'royalblue', 'Train013': 'magenta', 'Train014': 'darkorange'}

# %%
logger = setup_logger("main_log_file" ,"Logs/log.log")

# %% [markdown]
# # Simulation and Algorithm

# %%
#hyperparameters
pho = 0.25
minimum_J = 1000000
total_priority = 3
R = 3
l = 6
b = 2
w_c = 0.9
w_d = 1
total_episodes = 1000
w = 0.25

tau = 0.9
alpha = 0.9

EPS_START = 1.0
EPS_END = 0.1
EPS_STEPS = 300

gamma = 0.9

CURRENT_EPISODE = 0
TERMINATE = False

TOTAL_STEPS = 0

# %%
#Variables
total_states = total_priority * (R ** (l + b + 1))

# success_freq = np.zeros (( total_states , 2 ))
# pass_freq = np.zeros ((total_states , 2))
# success_prob = 0.5 * np.ones ((total_states , 2))
# seen = np.zeros((total_states , 2))

#map for the train most recent state space
train_state_space_map = {} 
train_action_terminated = {}
for key , value in  name_train_map.items():
    train_state_space_map[key] = '-'
    train_action_terminated[key] = False
#for the Q-values
Q_values = np.zeros((total_states , 2))
Q_values_100 = None

#total_neighbors and running mean
# state_vector_neighbors = np.zeros((total_states , 2))
# state_vector_running_mean = np.zeros((total_states , 2))

# %%
def epsilon_greedy (state_space , epsilon = None):
    '''
    Given the state space, pick the action according to epsilon-greedy policy.    
    '''
   #given the state space, it will select the action according to epsilon greedy policy
    actions = ['move' , 'wait']
    
    #compute epsilon
    if (epsilon is None):
        if (CURRENT_EPISODE > EPS_STEPS):
            epsilon = EPS_END
        else:
            epsilon = ((EPS_END - EPS_START) / EPS_STEPS) * CURRENT_EPISODE + EPS_START
        
    #check if the action is random or greedy
    random = np.random.choice([True , False ] , 1 , p = [epsilon , 1 - epsilon])

    #pick the action at random
    if (random):
        action = np.random.choice(actions , 1 , p = [0.5 , 0.5])
        return action[0]
    else:
        
        #pick the action greedily
        if (Q_values_100 is None):
            q_1 = Q_values[state_vector_to_index(state_space) , 0]
            q_2 = Q_values[state_vector_to_index(state_space) , 1]
        else:
            q_1 = Q_values_100[state_vector_to_index(state_space) , 0]
            q_2 = Q_values_100[state_vector_to_index(state_space) , 1]
        
        if (q_1 >= q_2):
            return 'move'
        else:
            return 'wait'

# %%
def modified_epsilon_greedy(state_space):
    '''
    given the state space, it will select the action according to the epsilon greedy policy
    as mentioned in the paper
    '''
    actions = ['move' , 'wait']
    
    #compute the epsilon
    epsilon = 0
    if (CURRENT_EPISODE > EPS_STEPS):
        epsilon = EPS_END
    else:
        epsilon = ((EPS_END - EPS_START) / EPS_STEPS) * CURRENT_EPISODE + EPS_START

    #computing Q-values for each action
    q0 = Q_values[state_vector_to_index(state_space) , 0]
    q1 = Q_values[state_vector_to_index(state_space) , 1]
  
    random = np.random.choice([True , False ] , 1 , p = [epsilon , 1 - epsilon])
    if (random):
        #choose the action based on the toss of a biased coin
        if (q0 + q1 == 0):
            return np.random.choice(actions , 1 , p = [0.5 , 0.5 ])
        else:
            return np.random.choice(actions , 1 , p = [q0/(q0+q1) , q1/(q0+q1)])
    else:
        #choose action greedily if there is sufficient difference between Q-values
        if (min(q0,q1) / max(q0 , q1) < tau):
            if (q0>q1):
                return actions[0]
            else:
                return actions[1]
        
        #else choose accorind to alpha
        else:
            return np.random.choice(actions , 1 , p = [alpha , 1-alpha])

# %%
def get_reward (train):
    #get the status of the train
    status = train.status()
    if (status == 'not_yet_started'):
        return 0

    else:
        #if the train is on the station, take the departure time
        current_index = train.current_index
#         print(train.name , train.route[current_index])

        if (train.station_or_not):
            return -(train.log[current_index][1] - train.route[current_index][1])
        else:
            return -(train.log[current_index][2] - train.route[current_index][2])

# %%
def choose_action_algo (env ,N ,name_train_map):
    
    '''
    This function will choose the action for the trains that need action at the
    particular simulation time
    
    This will also check if the move is valid or not.
    '''
    
    actions = ['move' , 'wait']
    
    global TERMINATE , TOTAL_STEPS
    
    while True :
        #This line is extremely important
        #As this line will wait for all the events upto this current simulation point to complete first
        #and then this will execute
        for _ in range(4*len(name_train_map)):
            yield env.timeout(0)
        
        #Check if the trains need action
        if (len(config.TRAINS_NEEDING_ACTION) == 0):
            yield env.timeout(1)
        
        else:
            
            #Pick the train that needs the action most
            time ,name = pick_most_suitable_action(name_train_map , N , env)
            t = name_train_map[name]
            #construct the state vector
            state_vector = get_state_vector(name , b = b , l = l , R = R , w_c = w_c , w_d = w_d)
            action = epsilon_greedy(state_vector , epsilon = 0.1)
            
            action_index = 0
            if action == 'wait':
                action_index = 1

            if action == 'move' and not (t.is_move_valid(env)):
                TERMINATE = True
            else:
                TERMINATE = False
            
            reward = get_reward(name_train_map[name])
            
            if not (train_state_space_map[name] == '-' and train_action_terminated[name] == False):
                #computing the Q_values
                prev_state_vector , prev_action = train_state_space_map[name]
                Q_values[state_vector_to_index(prev_state_vector) , prev_action] = reward + gamma * Q_values[state_vector_to_index(state_vector) , action_index]

            if (TERMINATE):
                Q_values[state_vector_to_index(state_vector) , action_index] = -100
                train_action_terminated[name] = True
                continue
            else:
                train_action_terminated[name] = False
                
            train_state_space_map[name] = (state_vector , action_index)    
            TOTAL_STEPS += 1
            env.process(t.act_simulate(env , action))
            
            config.TRAINS_NEEDING_ACTION.remove((time,  name) )

# %%
# sim_proc = env.process(update_graph(env , 1 , train_to_color =train_to_color))
def start_episode():
    '''
    Reset everything at the start of the episode
    '''
    env = simpy.Environment()
    N.reset(env)
    for t in trains:
        t.reset(env , N)
    
        
    dead_proc = env.process(deadlock_detection_process(env , 20))
    stat_proc = env.process(create_statistic_proc(env , logger , 20 , N , trains))

    for t in trains:
        proc = env.process(t.put_train_on_track(env))

    proc_act = env.process(choose_action_algo(env , N, name_train_map))
    return env,N

# %%
#this cell runs the main algo

#For plotting and storing info
J_plot = []
minimum_J_plot = []
# cumsum , moving_aves = [0] ,[]
# Q_values_plot = []
# Q_values_plot.append(copy.deepcopy(Q_values))
# deadlock_plot = []

#for logging about the total success, deadlock and completed episodes
total_deadlock = 0
completed_episodes = 0
terminated = 0

#For plotting
# fig= plt.subplot(1,1,figsize = (6 , 12))
# fig.show()
# fig.canvas.draw()

#Run for the required number of episodes
for episode in range(total_episodes):

    #reset the episode
    config.TRAINS_NEEDING_ACTION = []
    env , N = start_episode()    
    config.DEADLOCK = True
    config.TRAINS_COMPLETED_JOURNEY = False
    config.CURRENT_SIMULATION_TIME = 0
    
    TERMINATE = False
    CURRENT_EPISODE += 1

    #mark the seen to all zero for the current episode
    seen = np.zeros((total_states , 2))
    
    #This loop is not needed as such
    for time in range(0 , config.TOTAL_SIMULATION_TIME , 1):
#         if (TERMINATE):
#             break
            
        if (config.DEADLOCK== False):
            logger.warning("Time : {} Terminating Simulation. Deadlock detected".format(env.now))
#             print("Terminating Simulation : Deadlock detected")
            total_deadlock += 1 
            
            break

        if (config.TRAINS_COMPLETED_JOURNEY == True):
            logger.info("Time : {} All trains completed journey. Terminating Simulation".format(env.now))
            #print("Terminating Simulation : All trains completed journey")
            break

        config.CURRENT_SIMULATION_TIME += 1

        #Run the simulation
        env.run(until = config.CURRENT_SIMULATION_TIME)

    
    if (config.TRAINS_COMPLETED_JOURNEY):
        completed_episodes += 1
        J = compute_loss(trains)
        J_plot.append(J)
        minimum_J = min(J , minimum_J)
        minimum_J_plot.append(minimum_J)
    
    print ("Episode : {} , J : {:.5f} ,mean_J : {:.5f} ,minimum_J : {:.5f} , total_completed : {} total_deadlock : {}".format( 
                            episode ,J ,minimum_J, np.mean(np.array(J_plot)) ,completed_episodes, total_deadlock ))

    if (episode == 100):
        Q_values_100 = copy.deepcopy(Q_values)
#     plt.plot(J_plot)
# Out:
# Episode : 0 , J : 3.17500 ,minimum_J : 3.17500 , total_completed : 1 total_deadlock : 0
# Episode : 1 , J : 13.71250 ,minimum_J : 3.17500 , total_completed : 2 total_deadlock : 0
# Episode : 2 , J : 14.37500 ,minimum_J : 3.17500 , total_completed : 3 total_deadlock : 0
# Episode : 3 , J : 16.51250 ,minimum_J : 3.17500 , total_completed : 4 total_deadlock : 0
# Episode : 4 , J : 16.92500 ,minimum_J : 3.17500 , total_completed : 5 total_deadlock : 0
# Episode : 5 , J : 18.76250 ,minimum_J : 3.17500 , total_completed : 6 total_deadlock : 0
# Episode : 6 , J : 11.71250 ,minimum_J : 3.17500 , total_completed : 7 total_deadlock : 0
# Episode : 7 , J : 27.25000 ,minimum_J : 3.17500 , total_completed : 8 total_deadlock : 0
# Episode : 8 , J : 25.02500 ,minimum_J : 3.17500 , total_completed : 9 total_deadlock : 0
# Episode : 9 , J : 25.90000 ,minimum_J : 3.17500 , total_completed : 10 total_deadlock : 0
# Episode : 10 , J : 26.97500 ,minimum_J : 3.17500 , total_completed : 11 total_deadlock : 0
# Episode : 11 , J : 18.15000 ,minimum_J : 3.17500 , total_completed : 12 total_deadlock : 0
# Episode : 12 , J : 18.15000 ,minimum_J : 3.17500 , total_completed : 12 total_deadlock : 1
# Episode : 13 , J : 35.35000 ,minimum_J : 3.17500 , total_completed : 13 total_deadlock : 1
# Episode : 14 , J : 29.10000 ,minimum_J : 3.17500 , total_completed : 14 total_deadlock : 1
# Episode : 15 , J : 29.10000 ,minimum_J : 3.17500 , total_completed : 14 total_deadlock : 2
# Episode : 16 , J : 24.05000 ,minimum_J : 3.17500 , total_completed : 15 total_deadlock : 2
# Episode : 17 , J : 14.86250 ,minimum_J : 3.17500 , total_completed : 16 total_deadlock : 2
# Episode : 18 , J : 14.76250 ,minimum_J : 3.17500 , total_completed : 17 total_deadlock : 2
# Episode : 19 , J : 25.85000 ,minimum_J : 3.17500 , total_completed : 18 total_deadlock : 2
# Episode : 20 , J : 15.87500 ,minimum_J : 3.17500 , total_completed : 19 total_deadlock : 2
# Episode : 21 , J : 15.87500 ,minimum_J : 3.17500 , total_completed : 19 total_deadlock : 3
# Episode : 22 , J : 47.62500 ,minimum_J : 3.17500 , total_completed : 20 total_deadlock : 3
# Episode : 23 , J : 34.51250 ,minimum_J : 3.17500 , total_completed : 21 total_deadlock : 3
# Episode : 24 , J : 24.06250 ,minimum_J : 3.17500 , total_completed : 22 total_deadlock : 3
# Episode : 25 , J : 13.66250 ,minimum_J : 3.17500 , total_completed : 23 total_deadlock : 3
# Episode : 26 , J : 46.35000 ,minimum_J : 3.17500 , total_completed : 24 total_deadlock : 3
# Episode : 27 , J : 22.37500 ,minimum_J : 3.17500 , total_completed : 25 total_deadlock : 3
# Episode : 28 , J : 19.07500 ,minimum_J : 3.17500 , total_completed : 26 total_deadlock : 3
# Episode : 29 , J : 33.03750 ,minimum_J : 3.17500 , total_completed : 27 total_deadlock : 3
# Episode : 30 , J : 35.08750 ,minimum_J : 3.17500 , total_completed : 28 total_deadlock : 3
# Episode : 31 , J : 27.43750 ,minimum_J : 3.17500 , total_completed : 29 total_deadlock : 3
# Episode : 32 , J : 27.43750 ,minimum_J : 3.17500 , total_completed : 29 total_deadlock : 4
# Episode : 33 , J : 18.95000 ,minimum_J : 3.17500 , total_completed : 30 total_deadlock : 4
# Episode : 34 , J : 18.95000 ,minimum_J : 3.17500 , total_completed : 30 total_deadlock : 5
# Episode : 35 , J : 14.17500 ,minimum_J : 3.17500 , total_completed : 31 total_deadlock : 5
# Episode : 36 , J : 8.33750 ,minimum_J : 3.17500 , total_completed : 32 total_deadlock : 5
# Episode : 37 , J : 7.73750 ,minimum_J : 3.17500 , total_completed : 33 total_deadlock : 5
# Episode : 38 , J : 14.48750 ,minimum_J : 3.17500 , total_completed : 34 total_deadlock : 5
# Episode : 39 , J : 27.43750 ,minimum_J : 3.17500 , total_completed : 35 total_deadlock : 5
# Episode : 40 , J : 27.43750 ,minimum_J : 3.17500 , total_completed : 35 total_deadlock : 6
# Episode : 41 , J : 29.42500 ,minimum_J : 3.17500 , total_completed : 36 total_deadlock : 6
# Episode : 42 , J : 29.43750 ,minimum_J : 3.17500 , total_completed : 37 total_deadlock : 6
# Episode : 43 , J : 24.92500 ,minimum_J : 3.17500 , total_completed : 38 total_deadlock : 6
# Episode : 44 , J : 12.51250 ,minimum_J : 3.17500 , total_completed : 39 total_deadlock : 6
# Episode : 45 , J : 22.42500 ,minimum_J : 3.17500 , total_completed : 40 total_deadlock : 6
# Episode : 46 , J : 27.37500 ,minimum_J : 3.17500 , total_completed : 41 total_deadlock : 6
# Episode : 47 , J : 25.65000 ,minimum_J : 3.17500 , total_completed : 42 total_deadlock : 6
# Episode : 48 , J : 16.52500 ,minimum_J : 3.17500 , total_completed : 43 total_deadlock : 6
# Episode : 49 , J : 30.83750 ,minimum_J : 3.17500 , total_completed : 44 total_deadlock : 6
# Episode : 50 , J : 11.92500 ,minimum_J : 3.17500 , total_completed : 45 total_deadlock : 6
# Episode : 51 , J : 23.35000 ,minimum_J : 3.17500 , total_completed : 46 total_deadlock : 6
# Episode : 52 , J : 16.01250 ,minimum_J : 3.17500 , total_completed : 47 total_deadlock : 6
# Episode : 53 , J : 12.95000 ,minimum_J : 3.17500 , total_completed : 48 total_deadlock : 6
# Episode : 54 , J : 20.63750 ,minimum_J : 3.17500 , total_completed : 49 total_deadlock : 6
# Episode : 55 , J : 21.50000 ,minimum_J : 3.17500 , total_completed : 50 total_deadlock : 6
# Episode : 56 , J : 28.98750 ,minimum_J : 3.17500 , total_completed : 51 total_deadlock : 6
# Episode : 57 , J : 23.17500 ,minimum_J : 3.17500 , total_completed : 52 total_deadlock : 6
# Episode : 58 , J : 23.17500 ,minimum_J : 3.17500 , total_completed : 52 total_deadlock : 7
# Episode : 59 , J : 29.85000 ,minimum_J : 3.17500 , total_completed : 53 total_deadlock : 7
# Episode : 60 , J : 14.15000 ,minimum_J : 3.17500 , total_completed : 54 total_deadlock : 7
# Episode : 61 , J : 15.66250 ,minimum_J : 3.17500 , total_completed : 55 total_deadlock : 7
# Episode : 62 , J : 38.62500 ,minimum_J : 3.17500 , total_completed : 56 total_deadlock : 7
# Episode : 63 , J : 33.81250 ,minimum_J : 3.17500 , total_completed : 57 total_deadlock : 7
# Episode : 64 , J : 38.66250 ,minimum_J : 3.17500 , total_completed : 58 total_deadlock : 7
# Episode : 65 , J : 32.47500 ,minimum_J : 3.17500 , total_completed : 59 total_deadlock : 7
# Episode : 66 , J : 61.41250 ,minimum_J : 3.17500 , total_completed : 60 total_deadlock : 7
# Episode : 67 , J : 16.87500 ,minimum_J : 3.17500 , total_completed : 61 total_deadlock : 7
# Episode : 68 , J : 28.93750 ,minimum_J : 3.17500 , total_completed : 62 total_deadlock : 7
# Episode : 69 , J : 17.46250 ,minimum_J : 3.17500 , total_completed : 63 total_deadlock : 7
# Episode : 70 , J : 12.31250 ,minimum_J : 3.17500 , total_completed : 64 total_deadlock : 7
# Episode : 71 , J : 18.03750 ,minimum_J : 3.17500 , total_completed : 65 total_deadlock : 7
# Episode : 72 , J : 23.15000 ,minimum_J : 3.17500 , total_completed : 66 total_deadlock : 7
# Episode : 73 , J : 30.36250 ,minimum_J : 3.17500 , total_completed : 67 total_deadlock : 7
# Episode : 74 , J : 33.41250 ,minimum_J : 3.17500 , total_completed : 68 total_deadlock : 7
# Episode : 75 , J : 38.47500 ,minimum_J : 3.17500 , total_completed : 69 total_deadlock : 7
# Episode : 76 , J : 36.50000 ,minimum_J : 3.17500 , total_completed : 70 total_deadlock : 7
# Episode : 77 , J : 30.48750 ,minimum_J : 3.17500 , total_completed : 71 total_deadlock : 7
# Episode : 78 , J : 25.53750 ,minimum_J : 3.17500 , total_completed : 72 total_deadlock : 7
# Episode : 79 , J : 25.53750 ,minimum_J : 3.17500 , total_completed : 72 total_deadlock : 8
# Episode : 80 , J : 12.75000 ,minimum_J : 3.17500 , total_completed : 73 total_deadlock : 8
# Episode : 81 , J : 30.13750 ,minimum_J : 3.17500 , total_completed : 74 total_deadlock : 8
# Episode : 82 , J : 20.42500 ,minimum_J : 3.17500 , total_completed : 75 total_deadlock : 8
# Episode : 83 , J : 31.53750 ,minimum_J : 3.17500 , total_completed : 76 total_deadlock : 8
# Episode : 84 , J : 26.10000 ,minimum_J : 3.17500 , total_completed : 77 total_deadlock : 8
# Episode : 85 , J : 43.80000 ,minimum_J : 3.17500 , total_completed : 78 total_deadlock : 8
# Episode : 86 , J : 30.76250 ,minimum_J : 3.17500 , total_completed : 79 total_deadlock : 8
# Episode : 87 , J : 40.60000 ,minimum_J : 3.17500 , total_completed : 80 total_deadlock : 8
# Episode : 88 , J : 28.95000 ,minimum_J : 3.17500 , total_completed : 81 total_deadlock : 8
# Episode : 89 , J : 24.97500 ,minimum_J : 3.17500 , total_completed : 82 total_deadlock : 8
# Episode : 90 , J : 31.02500 ,minimum_J : 3.17500 , total_completed : 83 total_deadlock : 8
# Episode : 91 , J : 31.02500 ,minimum_J : 3.17500 , total_completed : 83 total_deadlock : 9
# Episode : 92 , J : 21.61250 ,minimum_J : 3.17500 , total_completed : 84 total_deadlock : 9
# Episode : 93 , J : 11.70000 ,minimum_J : 3.17500 , total_completed : 85 total_deadlock : 9
# Episode : 94 , J : 22.46250 ,minimum_J : 3.17500 , total_completed : 86 total_deadlock : 9
# Episode : 95 , J : 17.87500 ,minimum_J : 3.17500 , total_completed : 87 total_deadlock : 9
# Episode : 96 , J : 38.82500 ,minimum_J : 3.17500 , total_completed : 88 total_deadlock : 9
# Episode : 97 , J : 27.85000 ,minimum_J : 3.17500 , total_completed : 89 total_deadlock : 9
# Episode : 98 , J : 17.02500 ,minimum_J : 3.17500 , total_completed : 90 total_deadlock : 9
# Episode : 99 , J : 13.68750 ,minimum_J : 3.17500 , total_completed : 91 total_deadlock : 9
# Episode : 100 , J : 41.90000 ,minimum_J : 3.17500 , total_completed : 92 total_deadlock : 9
# Episode : 101 , J : 56.27500 ,minimum_J : 3.17500 , total_completed : 93 total_deadlock : 9
# Episode : 102 , J : 37.58750 ,minimum_J : 3.17500 , total_completed : 94 total_deadlock : 9
# Episode : 103 , J : 57.51250 ,minimum_J : 3.17500 , total_completed : 95 total_deadlock : 9
# Episode : 104 , J : 51.57500 ,minimum_J : 3.17500 , total_completed : 96 total_deadlock : 9
# Episode : 105 , J : 51.50000 ,minimum_J : 3.17500 , total_completed : 97 total_deadlock : 9
# Episode : 106 , J : 26.91250 ,minimum_J : 3.17500 , total_completed : 98 total_deadlock : 9
# Episode : 107 , J : 27.21250 ,minimum_J : 3.17500 , total_completed : 99 total_deadlock : 9
# Episode : 108 , J : 56.56250 ,minimum_J : 3.17500 , total_completed : 100 total_deadlock : 9
# Episode : 109 , J : 38.07500 ,minimum_J : 3.17500 , total_completed : 101 total_deadlock : 9
# Episode : 110 , J : 46.92500 ,minimum_J : 3.17500 , total_completed : 102 total_deadlock : 9
# Episode : 111 , J : 41.98750 ,minimum_J : 3.17500 , total_completed : 103 total_deadlock : 9
# Episode : 112 , J : 56.86250 ,minimum_J : 3.17500 , total_completed : 104 total_deadlock : 9
# Episode : 113 , J : 43.41250 ,minimum_J : 3.17500 , total_completed : 105 total_deadlock : 9
# Episode : 114 , J : 81.63750 ,minimum_J : 3.17500 , total_completed : 106 total_deadlock : 9
# Episode : 115 , J : 41.91250 ,minimum_J : 3.17500 , total_completed : 107 total_deadlock : 9
# Episode : 116 , J : 41.03750 ,minimum_J : 3.17500 , total_completed : 108 total_deadlock : 9
# Episode : 117 , J : 41.02500 ,minimum_J : 3.17500 , total_completed : 109 total_deadlock : 9
# Episode : 118 , J : 47.87500 ,minimum_J : 3.17500 , total_completed : 110 total_deadlock : 9
# Episode : 119 , J : 32.41250 ,minimum_J : 3.17500 , total_completed : 111 total_deadlock : 9
# Episode : 120 , J : 47.05000 ,minimum_J : 3.17500 , total_completed : 112 total_deadlock : 9
# Episode : 121 , J : 49.47500 ,minimum_J : 3.17500 , total_completed : 113 total_deadlock : 9
# Episode : 122 , J : 44.56250 ,minimum_J : 3.17500 , total_completed : 114 total_deadlock : 9
# Episode : 123 , J : 25.58750 ,minimum_J : 3.17500 , total_completed : 115 total_deadlock : 9
# Episode : 124 , J : 56.77500 ,minimum_J : 3.17500 , total_completed : 116 total_deadlock : 9
# Episode : 125 , J : 57.73750 ,minimum_J : 3.17500 , total_completed : 117 total_deadlock : 9
# Episode : 126 , J : 27.12500 ,minimum_J : 3.17500 , total_completed : 118 total_deadlock : 9
# Episode : 127 , J : 38.11250 ,minimum_J : 3.17500 , total_completed : 119 total_deadlock : 9
# Episode : 128 , J : 83.86250 ,minimum_J : 3.17500 , total_completed : 120 total_deadlock : 9
# Episode : 129 , J : 71.46250 ,minimum_J : 3.17500 , total_completed : 121 total_deadlock : 9
# Episode : 130 , J : 48.70000 ,minimum_J : 3.17500 , total_completed : 122 total_deadlock : 9
# Episode : 131 , J : 37.03750 ,minimum_J : 3.17500 , total_completed : 123 total_deadlock : 9
# Episode : 132 , J : 55.98750 ,minimum_J : 3.17500 , total_completed : 124 total_deadlock : 9
# Episode : 133 , J : 35.93750 ,minimum_J : 3.17500 , total_completed : 125 total_deadlock : 9
# Episode : 134 , J : 35.93750 ,minimum_J : 3.17500 , total_completed : 125 total_deadlock : 10
# Episode : 135 , J : 35.03750 ,minimum_J : 3.17500 , total_completed : 126 total_deadlock : 10
# Episode : 136 , J : 73.52500 ,minimum_J : 3.17500 , total_completed : 127 total_deadlock : 10
# Episode : 137 , J : 39.27500 ,minimum_J : 3.17500 , total_completed : 128 total_deadlock : 10
# Episode : 138 , J : 48.93750 ,minimum_J : 3.17500 , total_completed : 129 total_deadlock : 10
# Episode : 139 , J : 38.01250 ,minimum_J : 3.17500 , total_completed : 130 total_deadlock : 10
# Episode : 140 , J : 35.67500 ,minimum_J : 3.17500 , total_completed : 131 total_deadlock : 10
# Episode : 141 , J : 30.12500 ,minimum_J : 3.17500 , total_completed : 132 total_deadlock : 10
# Episode : 142 , J : 44.82500 ,minimum_J : 3.17500 , total_completed : 133 total_deadlock : 10
# Episode : 143 , J : 68.43750 ,minimum_J : 3.17500 , total_completed : 134 total_deadlock : 10
# Episode : 144 , J : 25.15000 ,minimum_J : 3.17500 , total_completed : 135 total_deadlock : 10
# Episode : 145 , J : 38.88750 ,minimum_J : 3.17500 , total_completed : 136 total_deadlock : 10
# Episode : 146 , J : 38.88750 ,minimum_J : 3.17500 , total_completed : 136 total_deadlock : 11
# Episode : 147 , J : 63.58750 ,minimum_J : 3.17500 , total_completed : 137 total_deadlock : 11
# Episode : 148 , J : 20.93750 ,minimum_J : 3.17500 , total_completed : 138 total_deadlock : 11
# Episode : 149 , J : 36.76250 ,minimum_J : 3.17500 , total_completed : 139 total_deadlock : 11
# Episode : 150 , J : 58.55000 ,minimum_J : 3.17500 , total_completed : 140 total_deadlock : 11
# Episode : 151 , J : 49.85000 ,minimum_J : 3.17500 , total_completed : 141 total_deadlock : 11
# Episode : 152 , J : 39.92500 ,minimum_J : 3.17500 , total_completed : 142 total_deadlock : 11
# Episode : 153 , J : 39.92500 ,minimum_J : 3.17500 , total_completed : 142 total_deadlock : 12
# Episode : 154 , J : 32.00000 ,minimum_J : 3.17500 , total_completed : 143 total_deadlock : 12
# Episode : 155 , J : 46.92500 ,minimum_J : 3.17500 , total_completed : 144 total_deadlock : 12
# Episode : 156 , J : 30.65000 ,minimum_J : 3.17500 , total_completed : 145 total_deadlock : 12
# Episode : 157 , J : 25.05000 ,minimum_J : 3.17500 , total_completed : 146 total_deadlock : 12
# Episode : 158 , J : 40.13750 ,minimum_J : 3.17500 , total_completed : 147 total_deadlock : 12
# Episode : 159 , J : 23.40000 ,minimum_J : 3.17500 , total_completed : 148 total_deadlock : 12
# Episode : 160 , J : 26.40000 ,minimum_J : 3.17500 , total_completed : 149 total_deadlock : 12
# Episode : 161 , J : 63.47500 ,minimum_J : 3.17500 , total_completed : 150 total_deadlock : 12
# Episode : 162 , J : 39.67500 ,minimum_J : 3.17500 , total_completed : 151 total_deadlock : 12
# Episode : 163 , J : 39.71250 ,minimum_J : 3.17500 , total_completed : 152 total_deadlock : 12
# Episode : 164 , J : 45.01250 ,minimum_J : 3.17500 , total_completed : 153 total_deadlock : 12
# Episode : 165 , J : 46.48750 ,minimum_J : 3.17500 , total_completed : 154 total_deadlock : 12
# Episode : 166 , J : 47.13750 ,minimum_J : 3.17500 , total_completed : 155 total_deadlock : 12
# Episode : 167 , J : 34.61250 ,minimum_J : 3.17500 , total_completed : 156 total_deadlock : 12
# Episode : 168 , J : 46.88750 ,minimum_J : 3.17500 , total_completed : 157 total_deadlock : 12
# Episode : 169 , J : 70.43750 ,minimum_J : 3.17500 , total_completed : 158 total_deadlock : 12
# Episode : 170 , J : 70.43750 ,minimum_J : 3.17500 , total_completed : 158 total_deadlock : 13
# Episode : 171 , J : 38.96250 ,minimum_J : 3.17500 , total_completed : 159 total_deadlock : 13
# Episode : 172 , J : 67.87500 ,minimum_J : 3.17500 , total_completed : 160 total_deadlock : 13
# Episode : 173 , J : 67.87500 ,minimum_J : 3.17500 , total_completed : 160 total_deadlock : 14
# Episode : 174 , J : 23.06250 ,minimum_J : 3.17500 , total_completed : 161 total_deadlock : 14
# Episode : 175 , J : 65.87500 ,minimum_J : 3.17500 , total_completed : 162 total_deadlock : 14
# Episode : 176 , J : 57.23750 ,minimum_J : 3.17500 , total_completed : 163 total_deadlock : 14
# Episode : 177 , J : 38.71250 ,minimum_J : 3.17500 , total_completed : 164 total_deadlock : 14
# Episode : 178 , J : 54.62500 ,minimum_J : 3.17500 , total_completed : 165 total_deadlock : 14
# Episode : 179 , J : 94.68750 ,minimum_J : 3.17500 , total_completed : 166 total_deadlock : 14
# Episode : 180 , J : 60.03750 ,minimum_J : 3.17500 , total_completed : 167 total_deadlock : 14
# Episode : 181 , J : 43.88750 ,minimum_J : 3.17500 , total_completed : 168 total_deadlock : 14
# Episode : 182 , J : 38.00000 ,minimum_J : 3.17500 , total_completed : 169 total_deadlock : 14
# Episode : 183 , J : 57.43750 ,minimum_J : 3.17500 , total_completed : 170 total_deadlock : 14
# Episode : 184 , J : 65.75000 ,minimum_J : 3.17500 , total_completed : 171 total_deadlock : 14
# Episode : 185 , J : 45.45000 ,minimum_J : 3.17500 , total_completed : 172 total_deadlock : 14
# Episode : 186 , J : 42.33750 ,minimum_J : 3.17500 , total_completed : 173 total_deadlock : 14
# Episode : 187 , J : 49.87500 ,minimum_J : 3.17500 , total_completed : 174 total_deadlock : 14
# Episode : 188 , J : 30.31250 ,minimum_J : 3.17500 , total_completed : 175 total_deadlock : 14
# Episode : 189 , J : 53.51250 ,minimum_J : 3.17500 , total_completed : 176 total_deadlock : 14
# Episode : 190 , J : 53.61250 ,minimum_J : 3.17500 , total_completed : 177 total_deadlock : 14
# Episode : 191 , J : 72.55000 ,minimum_J : 3.17500 , total_completed : 178 total_deadlock : 14
# Episode : 192 , J : 51.32500 ,minimum_J : 3.17500 , total_completed : 179 total_deadlock : 14
# Episode : 193 , J : 78.78750 ,minimum_J : 3.17500 , total_completed : 180 total_deadlock : 14
# Episode : 194 , J : 54.60000 ,minimum_J : 3.17500 , total_completed : 181 total_deadlock : 14
# Episode : 195 , J : 39.30000 ,minimum_J : 3.17500 , total_completed : 182 total_deadlock : 14
# Episode : 196 , J : 46.85000 ,minimum_J : 3.17500 , total_completed : 183 total_deadlock : 14
# Episode : 197 , J : 45.27500 ,minimum_J : 3.17500 , total_completed : 184 total_deadlock : 14
# Episode : 198 , J : 90.00000 ,minimum_J : 3.17500 , total_completed : 185 total_deadlock : 14
# Episode : 199 , J : 55.10000 ,minimum_J : 3.17500 , total_completed : 186 total_deadlock : 14
# Episode : 200 , J : 28.36250 ,minimum_J : 3.17500 , total_completed : 187 total_deadlock : 14
# Episode : 201 , J : 62.27500 ,minimum_J : 3.17500 , total_completed : 188 total_deadlock : 14
# Episode : 202 , J : 49.30000 ,minimum_J : 3.17500 , total_completed : 189 total_deadlock : 14
# Episode : 203 , J : 69.43750 ,minimum_J : 3.17500 , total_completed : 190 total_deadlock : 14
# Episode : 204 , J : 47.01250 ,minimum_J : 3.17500 , total_completed : 191 total_deadlock : 14
# Episode : 205 , J : 47.15000 ,minimum_J : 3.17500 , total_completed : 192 total_deadlock : 14
# Episode : 206 , J : 31.83750 ,minimum_J : 3.17500 , total_completed : 193 total_deadlock : 14
# Episode : 207 , J : 40.37500 ,minimum_J : 3.17500 , total_completed : 194 total_deadlock : 14
# Episode : 208 , J : 41.77500 ,minimum_J : 3.17500 , total_completed : 195 total_deadlock : 14
# Episode : 209 , J : 24.43750 ,minimum_J : 3.17500 , total_completed : 196 total_deadlock : 14
# Episode : 210 , J : 43.02500 ,minimum_J : 3.17500 , total_completed : 197 total_deadlock : 14
# Episode : 211 , J : 46.86250 ,minimum_J : 3.17500 , total_completed : 198 total_deadlock : 14
# Episode : 212 , J : 58.71250 ,minimum_J : 3.17500 , total_completed : 199 total_deadlock : 14
# Episode : 213 , J : 49.35000 ,minimum_J : 3.17500 , total_completed : 200 total_deadlock : 14
# Episode : 214 , J : 58.83750 ,minimum_J : 3.17500 , total_completed : 201 total_deadlock : 14
# Episode : 215 , J : 55.17500 ,minimum_J : 3.17500 , total_completed : 202 total_deadlock : 14
# Episode : 216 , J : 47.61250 ,minimum_J : 3.17500 , total_completed : 203 total_deadlock : 14
# Episode : 217 , J : 58.81250 ,minimum_J : 3.17500 , total_completed : 204 total_deadlock : 14
# Episode : 218 , J : 36.73750 ,minimum_J : 3.17500 , total_completed : 205 total_deadlock : 14
# Episode : 219 , J : 58.08750 ,minimum_J : 3.17500 , total_completed : 206 total_deadlock : 14
# Episode : 220 , J : 44.61250 ,minimum_J : 3.17500 , total_completed : 207 total_deadlock : 14
# Episode : 221 , J : 52.40000 ,minimum_J : 3.17500 , total_completed : 208 total_deadlock : 14
# Episode : 222 , J : 47.15000 ,minimum_J : 3.17500 , total_completed : 209 total_deadlock : 14
# Episode : 223 , J : 26.87500 ,minimum_J : 3.17500 , total_completed : 210 total_deadlock : 14
# Episode : 224 , J : 77.28750 ,minimum_J : 3.17500 , total_completed : 211 total_deadlock : 14
# Episode : 225 , J : 57.50000 ,minimum_J : 3.17500 , total_completed : 212 total_deadlock : 14
# Episode : 226 , J : 43.46250 ,minimum_J : 3.17500 , total_completed : 213 total_deadlock : 14
# Episode : 227 , J : 50.92500 ,minimum_J : 3.17500 , total_completed : 214 total_deadlock : 14
# Episode : 228 , J : 58.52500 ,minimum_J : 3.17500 , total_completed : 215 total_deadlock : 14
# Episode : 229 , J : 42.73750 ,minimum_J : 3.17500 , total_completed : 216 total_deadlock : 14
# Episode : 230 , J : 42.73750 ,minimum_J : 3.17500 , total_completed : 216 total_deadlock : 15
# Episode : 231 , J : 46.30000 ,minimum_J : 3.17500 , total_completed : 217 total_deadlock : 15
# Episode : 232 , J : 54.40000 ,minimum_J : 3.17500 , total_completed : 218 total_deadlock : 15
# Episode : 233 , J : 41.32500 ,minimum_J : 3.17500 , total_completed : 219 total_deadlock : 15
# Episode : 234 , J : 65.47500 ,minimum_J : 3.17500 , total_completed : 220 total_deadlock : 15
# Episode : 235 , J : 78.57500 ,minimum_J : 3.17500 , total_completed : 221 total_deadlock : 15
# Episode : 236 , J : 30.22500 ,minimum_J : 3.17500 , total_completed : 222 total_deadlock : 15
# Episode : 237 , J : 41.18750 ,minimum_J : 3.17500 , total_completed : 223 total_deadlock : 15
# Episode : 238 , J : 39.23750 ,minimum_J : 3.17500 , total_completed : 224 total_deadlock : 15
# Episode : 239 , J : 29.03750 ,minimum_J : 3.17500 , total_completed : 225 total_deadlock : 15
# Episode : 240 , J : 63.43750 ,minimum_J : 3.17500 , total_completed : 226 total_deadlock : 15
# Episode : 241 , J : 28.08750 ,minimum_J : 3.17500 , total_completed : 227 total_deadlock : 15
# Episode : 242 , J : 47.22500 ,minimum_J : 3.17500 , total_completed : 228 total_deadlock : 15
# Episode : 243 , J : 38.61250 ,minimum_J : 3.17500 , total_completed : 229 total_deadlock : 15
# Episode : 244 , J : 36.75000 ,minimum_J : 3.17500 , total_completed : 230 total_deadlock : 15
# Episode : 245 , J : 28.40000 ,minimum_J : 3.17500 , total_completed : 231 total_deadlock : 15
# Episode : 246 , J : 24.73750 ,minimum_J : 3.17500 , total_completed : 232 total_deadlock : 15
# Episode : 247 , J : 54.78750 ,minimum_J : 3.17500 , total_completed : 233 total_deadlock : 15
# Episode : 248 , J : 34.91250 ,minimum_J : 3.17500 , total_completed : 234 total_deadlock : 15
# Episode : 249 , J : 67.66250 ,minimum_J : 3.17500 , total_completed : 235 total_deadlock : 15
# Episode : 250 , J : 62.58750 ,minimum_J : 3.17500 , total_completed : 236 total_deadlock : 15
# Episode : 251 , J : 43.77500 ,minimum_J : 3.17500 , total_completed : 237 total_deadlock : 15
# Episode : 252 , J : 52.26250 ,minimum_J : 3.17500 , total_completed : 238 total_deadlock : 15
# Episode : 253 , J : 31.76250 ,minimum_J : 3.17500 , total_completed : 239 total_deadlock : 15
# Episode : 254 , J : 45.87500 ,minimum_J : 3.17500 , total_completed : 240 total_deadlock : 15
# Episode : 255 , J : 45.87500 ,minimum_J : 3.17500 , total_completed : 240 total_deadlock : 16
# Episode : 256 , J : 69.66250 ,minimum_J : 3.17500 , total_completed : 241 total_deadlock : 16
# Episode : 257 , J : 50.53750 ,minimum_J : 3.17500 , total_completed : 242 total_deadlock : 16
# Episode : 258 , J : 47.26250 ,minimum_J : 3.17500 , total_completed : 243 total_deadlock : 16
# Episode : 259 , J : 31.38750 ,minimum_J : 3.17500 , total_completed : 244 total_deadlock : 16
# Episode : 260 , J : 84.75000 ,minimum_J : 3.17500 , total_completed : 245 total_deadlock : 16
# Episode : 261 , J : 41.60000 ,minimum_J : 3.17500 , total_completed : 246 total_deadlock : 16
# Episode : 262 , J : 64.98750 ,minimum_J : 3.17500 , total_completed : 247 total_deadlock : 16
# Episode : 263 , J : 33.26250 ,minimum_J : 3.17500 , total_completed : 248 total_deadlock : 16
# Episode : 264 , J : 36.90000 ,minimum_J : 3.17500 , total_completed : 249 total_deadlock : 16
# Episode : 265 , J : 52.35000 ,minimum_J : 3.17500 , total_completed : 250 total_deadlock : 16
# Episode : 266 , J : 47.97500 ,minimum_J : 3.17500 , total_completed : 251 total_deadlock : 16
# Episode : 267 , J : 46.10000 ,minimum_J : 3.17500 , total_completed : 252 total_deadlock : 16
# Episode : 268 , J : 52.91250 ,minimum_J : 3.17500 , total_completed : 253 total_deadlock : 16
# Episode : 269 , J : 58.05000 ,minimum_J : 3.17500 , total_completed : 254 total_deadlock : 16
# Episode : 270 , J : 49.01250 ,minimum_J : 3.17500 , total_completed : 255 total_deadlock : 16
# Episode : 271 , J : 55.30000 ,minimum_J : 3.17500 , total_completed : 256 total_deadlock : 16
# Episode : 272 , J : 29.95000 ,minimum_J : 3.17500 , total_completed : 257 total_deadlock : 16
# Episode : 273 , J : 62.01250 ,minimum_J : 3.17500 , total_completed : 258 total_deadlock : 16
# Episode : 274 , J : 36.57500 ,minimum_J : 3.17500 , total_completed : 259 total_deadlock : 16
# Episode : 275 , J : 55.20000 ,minimum_J : 3.17500 , total_completed : 260 total_deadlock : 16
# Episode : 276 , J : 31.41250 ,minimum_J : 3.17500 , total_completed : 261 total_deadlock : 16
# Episode : 277 , J : 44.13750 ,minimum_J : 3.17500 , total_completed : 262 total_deadlock : 16
# Episode : 278 , J : 51.27500 ,minimum_J : 3.17500 , total_completed : 263 total_deadlock : 16
# Episode : 279 , J : 38.50000 ,minimum_J : 3.17500 , total_completed : 264 total_deadlock : 16
# Episode : 280 , J : 55.97500 ,minimum_J : 3.17500 , total_completed : 265 total_deadlock : 16
# Episode : 281 , J : 45.65000 ,minimum_J : 3.17500 , total_completed : 266 total_deadlock : 16
# Episode : 282 , J : 23.30000 ,minimum_J : 3.17500 , total_completed : 267 total_deadlock : 16
# Episode : 283 , J : 40.47500 ,minimum_J : 3.17500 , total_completed : 268 total_deadlock : 16
# Episode : 284 , J : 39.27500 ,minimum_J : 3.17500 , total_completed : 269 total_deadlock : 16
# Episode : 285 , J : 48.60000 ,minimum_J : 3.17500 , total_completed : 270 total_deadlock : 16
# Episode : 286 , J : 52.17500 ,minimum_J : 3.17500 , total_completed : 271 total_deadlock : 16
# Episode : 287 , J : 25.83750 ,minimum_J : 3.17500 , total_completed : 272 total_deadlock : 16
# Episode : 288 , J : 30.02500 ,minimum_J : 3.17500 , total_completed : 273 total_deadlock : 16
# Episode : 289 , J : 42.00000 ,minimum_J : 3.17500 , total_completed : 274 total_deadlock : 16
# Episode : 290 , J : 40.62500 ,minimum_J : 3.17500 , total_completed : 275 total_deadlock : 16
# Episode : 291 , J : 62.60000 ,minimum_J : 3.17500 , total_completed : 276 total_deadlock : 16
# Episode : 292 , J : 41.58750 ,minimum_J : 3.17500 , total_completed : 277 total_deadlock : 16
# Episode : 293 , J : 49.35000 ,minimum_J : 3.17500 , total_completed : 278 total_deadlock : 16
# Episode : 294 , J : 59.52500 ,minimum_J : 3.17500 , total_completed : 279 total_deadlock : 16
# Episode : 295 , J : 24.61250 ,minimum_J : 3.17500 , total_completed : 280 total_deadlock : 16
# Episode : 296 , J : 37.08750 ,minimum_J : 3.17500 , total_completed : 281 total_deadlock : 16
# Episode : 297 , J : 45.55000 ,minimum_J : 3.17500 , total_completed : 282 total_deadlock : 16
# Episode : 298 , J : 70.23750 ,minimum_J : 3.17500 , total_completed : 283 total_deadlock : 16
# Episode : 299 , J : 55.55000 ,minimum_J : 3.17500 , total_completed : 284 total_deadlock : 16
# Episode : 300 , J : 23.60000 ,minimum_J : 3.17500 , total_completed : 285 total_deadlock : 16
# Episode : 301 , J : 39.82500 ,minimum_J : 3.17500 , total_completed : 286 total_deadlock : 16
# Episode : 302 , J : 34.81250 ,minimum_J : 3.17500 , total_completed : 287 total_deadlock : 16
# Episode : 303 , J : 53.40000 ,minimum_J : 3.17500 , total_completed : 288 total_deadlock : 16
# Episode : 304 , J : 62.47500 ,minimum_J : 3.17500 , total_completed : 289 total_deadlock : 16
# Episode : 305 , J : 36.23750 ,minimum_J : 3.17500 , total_completed : 290 total_deadlock : 16
# Episode : 306 , J : 63.56250 ,minimum_J : 3.17500 , total_completed : 291 total_deadlock : 16
# Episode : 307 , J : 53.43750 ,minimum_J : 3.17500 , total_completed : 292 total_deadlock : 16
# Episode : 308 , J : 56.26250 ,minimum_J : 3.17500 , total_completed : 293 total_deadlock : 16
# Episode : 309 , J : 36.61250 ,minimum_J : 3.17500 , total_completed : 294 total_deadlock : 16
# Episode : 310 , J : 27.30000 ,minimum_J : 3.17500 , total_completed : 295 total_deadlock : 16
# Episode : 311 , J : 52.26250 ,minimum_J : 3.17500 , total_completed : 296 total_deadlock : 16
# Episode : 312 , J : 37.40000 ,minimum_J : 3.17500 , total_completed : 297 total_deadlock : 16
# Episode : 313 , J : 52.30000 ,minimum_J : 3.17500 , total_completed : 298 total_deadlock : 16
# Episode : 314 , J : 41.20000 ,minimum_J : 3.17500 , total_completed : 299 total_deadlock : 16
# Episode : 315 , J : 33.27500 ,minimum_J : 3.17500 , total_completed : 300 total_deadlock : 16
# Episode : 316 , J : 58.16250 ,minimum_J : 3.17500 , total_completed : 301 total_deadlock : 16
# Episode : 317 , J : 60.97500 ,minimum_J : 3.17500 , total_completed : 302 total_deadlock : 16
# Episode : 318 , J : 62.06250 ,minimum_J : 3.17500 , total_completed : 303 total_deadlock : 16
# Episode : 319 , J : 38.55000 ,minimum_J : 3.17500 , total_completed : 304 total_deadlock : 16
# Episode : 320 , J : 76.03750 ,minimum_J : 3.17500 , total_completed : 305 total_deadlock : 16
# Episode : 321 , J : 40.15000 ,minimum_J : 3.17500 , total_completed : 306 total_deadlock : 16
# Episode : 322 , J : 54.80000 ,minimum_J : 3.17500 , total_completed : 307 total_deadlock : 16
# Episode : 323 , J : 71.90000 ,minimum_J : 3.17500 , total_completed : 308 total_deadlock : 16
# Episode : 324 , J : 69.25000 ,minimum_J : 3.17500 , total_completed : 309 total_deadlock : 16
# Episode : 325 , J : 50.23750 ,minimum_J : 3.17500 , total_completed : 310 total_deadlock : 16
# Episode : 326 , J : 36.25000 ,minimum_J : 3.17500 , total_completed : 311 total_deadlock : 16
# Episode : 327 , J : 38.70000 ,minimum_J : 3.17500 , total_completed : 312 total_deadlock : 16
# Episode : 328 , J : 33.37500 ,minimum_J : 3.17500 , total_completed : 313 total_deadlock : 16
# Episode : 329 , J : 35.38750 ,minimum_J : 3.17500 , total_completed : 314 total_deadlock : 16
# Episode : 330 , J : 55.56250 ,minimum_J : 3.17500 , total_completed : 315 total_deadlock : 16
# Episode : 331 , J : 36.33750 ,minimum_J : 3.17500 , total_completed : 316 total_deadlock : 16
# Episode : 332 , J : 34.55000 ,minimum_J : 3.17500 , total_completed : 317 total_deadlock : 16
# Episode : 333 , J : 77.60000 ,minimum_J : 3.17500 , total_completed : 318 total_deadlock : 16
# Episode : 334 , J : 45.11250 ,minimum_J : 3.17500 , total_completed : 319 total_deadlock : 16
# Episode : 335 , J : 36.13750 ,minimum_J : 3.17500 , total_completed : 320 total_deadlock : 16
# Episode : 336 , J : 44.11250 ,minimum_J : 3.17500 , total_completed : 321 total_deadlock : 16
# Episode : 337 , J : 41.35000 ,minimum_J : 3.17500 , total_completed : 322 total_deadlock : 16
# Episode : 338 , J : 34.02500 ,minimum_J : 3.17500 , total_completed : 323 total_deadlock : 16
# Episode : 339 , J : 41.05000 ,minimum_J : 3.17500 , total_completed : 324 total_deadlock : 16
# Episode : 340 , J : 36.86250 ,minimum_J : 3.17500 , total_completed : 325 total_deadlock : 16
# Episode : 341 , J : 52.12500 ,minimum_J : 3.17500 , total_completed : 326 total_deadlock : 16
# Episode : 342 , J : 50.17500 ,minimum_J : 3.17500 , total_completed : 327 total_deadlock : 16
# Episode : 343 , J : 41.75000 ,minimum_J : 3.17500 , total_completed : 328 total_deadlock : 16
# Episode : 344 , J : 60.13750 ,minimum_J : 3.17500 , total_completed : 329 total_deadlock : 16
# Episode : 345 , J : 60.13750 ,minimum_J : 3.17500 , total_completed : 329 total_deadlock : 17
# Episode : 346 , J : 40.90000 ,minimum_J : 3.17500 , total_completed : 330 total_deadlock : 17
# Episode : 347 , J : 66.87500 ,minimum_J : 3.17500 , total_completed : 331 total_deadlock : 17
# Episode : 348 , J : 38.20000 ,minimum_J : 3.17500 , total_completed : 332 total_deadlock : 17
# Episode : 349 , J : 53.27500 ,minimum_J : 3.17500 , total_completed : 333 total_deadlock : 17
# Episode : 350 , J : 63.02500 ,minimum_J : 3.17500 , total_completed : 334 total_deadlock : 17
# Episode : 351 , J : 73.22500 ,minimum_J : 3.17500 , total_completed : 335 total_deadlock : 17
# Episode : 352 , J : 95.88750 ,minimum_J : 3.17500 , total_completed : 336 total_deadlock : 17
# Episode : 353 , J : 44.65000 ,minimum_J : 3.17500 , total_completed : 337 total_deadlock : 17
# Episode : 354 , J : 75.10000 ,minimum_J : 3.17500 , total_completed : 338 total_deadlock : 17
# Episode : 355 , J : 42.63750 ,minimum_J : 3.17500 , total_completed : 339 total_deadlock : 17
# Episode : 356 , J : 51.72500 ,minimum_J : 3.17500 , total_completed : 340 total_deadlock : 17
# Episode : 357 , J : 58.08750 ,minimum_J : 3.17500 , total_completed : 341 total_deadlock : 17
# Episode : 358 , J : 26.60000 ,minimum_J : 3.17500 , total_completed : 342 total_deadlock : 17
# Episode : 359 , J : 25.86250 ,minimum_J : 3.17500 , total_completed : 343 total_deadlock : 17
# Episode : 360 , J : 38.30000 ,minimum_J : 3.17500 , total_completed : 344 total_deadlock : 17
# Episode : 361 , J : 51.47500 ,minimum_J : 3.17500 , total_completed : 345 total_deadlock : 17
# Episode : 362 , J : 73.08750 ,minimum_J : 3.17500 , total_completed : 346 total_deadlock : 17
# Episode : 363 , J : 49.43750 ,minimum_J : 3.17500 , total_completed : 347 total_deadlock : 17
# Episode : 364 , J : 40.18750 ,minimum_J : 3.17500 , total_completed : 348 total_deadlock : 17
# Episode : 365 , J : 38.88750 ,minimum_J : 3.17500 , total_completed : 349 total_deadlock : 17
# Episode : 366 , J : 32.01250 ,minimum_J : 3.17500 , total_completed : 350 total_deadlock : 17
# Episode : 367 , J : 50.90000 ,minimum_J : 3.17500 , total_completed : 351 total_deadlock : 17
# Episode : 368 , J : 51.88750 ,minimum_J : 3.17500 , total_completed : 352 total_deadlock : 17
# Episode : 369 , J : 66.61250 ,minimum_J : 3.17500 , total_completed : 353 total_deadlock : 17
# Episode : 370 , J : 51.01250 ,minimum_J : 3.17500 , total_completed : 354 total_deadlock : 17
# Episode : 371 , J : 61.12500 ,minimum_J : 3.17500 , total_completed : 355 total_deadlock : 17
# Episode : 372 , J : 34.06250 ,minimum_J : 3.17500 , total_completed : 356 total_deadlock : 17
# Episode : 373 , J : 46.21250 ,minimum_J : 3.17500 , total_completed : 357 total_deadlock : 17
# Episode : 374 , J : 42.22500 ,minimum_J : 3.17500 , total_completed : 358 total_deadlock : 17
# Episode : 375 , J : 42.02500 ,minimum_J : 3.17500 , total_completed : 359 total_deadlock : 17
# Episode : 376 , J : 68.12500 ,minimum_J : 3.17500 , total_completed : 360 total_deadlock : 17
# Episode : 377 , J : 62.88750 ,minimum_J : 3.17500 , total_completed : 361 total_deadlock : 17
# Episode : 378 , J : 31.35000 ,minimum_J : 3.17500 , total_completed : 362 total_deadlock : 17
# Episode : 379 , J : 28.55000 ,minimum_J : 3.17500 , total_completed : 363 total_deadlock : 17
# Episode : 380 , J : 53.32500 ,minimum_J : 3.17500 , total_completed : 364 total_deadlock : 17
# Episode : 381 , J : 36.75000 ,minimum_J : 3.17500 , total_completed : 365 total_deadlock : 17

# %%
plot_bool= np.where(pass_freq > 0)

# %%
for i in range(len(Q_values_plot)):
    plot_Q_values = Q_values_plot[i][plot_bool]
    hist , bin_edges = np.histogram(plot_Q_values , bins = np.linspace(0 ,  1 , 101))
    plt.plot(bin_edges[:-1],  np.cumsum(hist) , label = 'Episode - {}'.format(i * 100) )
    
plt.legend()
plt.xlabel('Q-value')
plt.ylabel('Cumulative percentage')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Cumulative percentage')

# %% [markdown]
# # Resource Usage

# %%
G,train_nodes , station_nodes , track_nodes = create_resource_usage_graph(trains , N)

# %%
fig = plt.figure(figsize = (6 , 6))
ax = fig.add_subplot(111)
draw_network_usage_graph(G,train_nodes , station_nodes , track_nodes, N,ax)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# # TODO
#
# 1. Create a simple train class with all the parameters                                                Done
# 2. Implement the resource facility with the track and the station                                     Done
# 3. Run the single train on the track (without getting worried wether the resource is free or not)     Done
# 4. Simulate whole thing on graph (single train only)                                                  Done
# 5. Run multiple instances of the train without worrying about the deadlock                            Done
#    Create action for each train                                                                       Done
# 6. Try to simulate as you want to do in the project i.e. take action from the user.                   Done
#    Also able to order the train for which to take the action at a particular time
#
#
#
# 7. Try to create deadlock with the trains                                                             Done
# 8. Create the graph for resource usage.                                                               Done
# 9. Use the standard deadlock detection algorithm for the detection of the algorithm                   Done
#    Implement the Bank's algorithm for deadlock detection.

# %% [markdown]
# # List of reasons of creating events
# 1. If a train is standing at a station, the event processing time            Can be done by implementing timeout if train arrive early before depart time
#     corresponds to the earliest time at which the train can depart,          occupancy of next track.
#     as defined by its minimum halt time at the station and by any           Done
#     departure time constraints enforced for passenger convenience.
#
# 2. `If it is running between two stations, the event processing time         Already done
#     corresponds to the earliest time at which it can arrive at the          occupancy of next station if move.
#     next station, as defined by the length of the track and the train       Done
#     running speed.
#
# 3. If the train is yet to start, the event processing                       Done
#     time is the time at which it is expected at the starting station.

# %% [markdown]
# # TODO
#
# Create the actions properly and implement deadlock Avoidance heuristic
#
# 1. Code the proper list of events. All the three listed above.                                      Done
# 2. Create the proper time table with arrival and departure time of each train at each station.      Done
# 3. Create separate log file for each train.                                                         Done
# 3. Run simulation with the first toy environment (as in the paper).                                 Done
# 4. Label the current set of implementation under Simulation Phase.                                  Done
# 5. Implement the actions properly without actually waiting for the resource.                        Done
# 6. Understand Heuristic that can be used to avoid deadlock.                                         Done
# 7. Move that train that occupies the most congested resource first and then other.                  Done
#    If tie break it using priority of each train.
#
#
# 8. Implement the state vector when action need to be taken.                                       Note Done

# %% [markdown]
# # TODO
# 1. Implement the function to compute J      $\;\;\;\;\;\;\;\;\;\;\;$   Done
# 2. Implement the state space i.e. when taking action train should know what is the state space
# 3. Implement Proxy reward.
# 4. Implement the Q-learning algo given in the paper
# 5. Check for the first test case
